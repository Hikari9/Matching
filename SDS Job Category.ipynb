# %%
# %matplotlib inline
import pylab as plt
from mpltools import style
style.use('ggplot')
from abelian import db
from abelian.models import User, Job, SDSCategory, SDSJob, SDSSkill, CandidateSDSJob
from abelian.services.education_industry_data_cleaner import clean, D_TYPE_INDUSTRY, D_TYPE_JOB_TITLE, D_TYPE_EDUC

from collections import defaultdict, Counter

db.configure("main", "postgresql://kalibrr:password@localhost/kalibrr")
session = db.get_session()

# %%
sds_job = session.query(SDSJob).all()#first()

# %%
u = session.query(User).first()
u.sds_skills
# Out:
# []

# %%
q = sds_job[1121]#.name
q
# Out:
# {'name': u'CodeIgniter Developer', 'created_at': '2015-05-09T17:52:31.846749+00:00', 'updated_at': '2015-05-09T17:52:31.846749+00:00', 'sds_category_id': None, 'custom': True, 'id': 1223}

# %%
q
# Out:
# {'name': u'tourism hospitality', 'created_at': '2015-05-03T20:36:41.617975+00:00', 'updated_at': '2015-05-03T20:36:41.617975+00:00', 'sds_category_id': None, 'custom': True, 'id': 174}

# %%
sds_job_name = session.query(SDSJob.name).filter(SDSJob.id==CandidateSDSJob.sds_job_id, CandidateSDSJob.candidate_id==User.id).all()
sds_job_name = [x for x, in sds_job_name]

# %%
sds_job_counts = Counter(clean(sds_job_name, D_TYPE_JOB_TITLE))

# %%
sds_job_counts
# Out:
# Counter({u'ADMINISTRATIVE ASSISTANT': 688, u'CUSTOMER SERVICE REPRESENTATIVE': 441, u'DATA ENTRY CLERK': 349, u'SALES ASSOCIATE': 321, u'INFORMATION TECHNOLOGY STAFF': 278, u'BACKOFFICE AGENT': 235, u'MARKETING MANAGER': 212, u'GRAPHIC DESIGNER': 163, u'BRAND MANAGER': 161, u'ACCOUNTANT': 154, u'WAITER': 151, u'FRONT DESK CLERK': 150, u'FOOD SERVER': 150, u'HOTEL RESERVATION ASSISTANT': 149, u'CASHIER': 149, u'CONTENT WRITER': 126, u'CREATIVE WRITER': 112, u'BOOKKEEPER': 95, u'TECHNICAL SERVICE REPRESENTATIVE': 87, u'RECRUITMENT SPECIALIST': 86, u'PRODUCTION WORKER MANUFACTURING': 82, u'HOUSEKEEPING STAFF': 78, u'COMPUTER CONTROLLED MACHINE TOOL OPERATOR': 77, u'EMPLOYEE RELATIONS SPECIALIST': 75, u'RECEPTIONIST': 73, u'': 72, u'COPYWRITER': 72, u'SYSTEM ADMINISTRATOR': 69, u'OFFICE STAFF': 67, u'FRONTEND DEVELOPER': 66, u'RESTAURANT LOUNGE OR COFFEESHOP HOST': 65, u'OUTBOUND SALES AGENT': 65, u'FOOD SERVICE MANAGER': 61, u'AUDITOR': 61, u'PRODUCT QUALITY INSPECTOR': 61, u'MEDICAL SA
# ...
