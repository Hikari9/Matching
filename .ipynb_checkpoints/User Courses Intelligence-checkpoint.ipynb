# %% [markdown]
# c/o Rico

# %%
from abelian import db
from abelian.models import User, Job, ProfilerAnswer, Profiler
from collections import defaultdict

db.configure("postgresql://kalibrr:password@localhost/kalibrr", False)
session = db.get_session()

# %%
# gather data
db_course_data = \
    session.query(ProfilerAnswer.data).filter(
        ProfilerAnswer.profiler_code==Profiler.code,
        Profiler.type=='EducationProfiler',
        ProfilerAnswer.user_id==User.id,
        ~User.is_test
    ).all()

# %%
db_course_data[0][0]
# Out:
# {u'education': {u'date_last_in_school': u'2005-02-28T16:00:00.000Z',
#   u'fields_of_study': [u'Alternative Education'],
#   u'level': u'Graduated from college',
#   u'status': 300}}

# %%
# gather courses
courses = [
    item[0]['education']['fields_of_study']
    for item in db_course_data
    if len(item) > 0
    and 'education' in item[0]
    and 'fields_of_study' in item[0]['education']
    and len(item[0]['education']['fields_of_study'])
]

# %%
courses
# Out:
# [[u'Alternative Education'],
#  [u'Business Administration'],
#  [u'Information Technology (IT)'],
#  [u'Industrial Engineering (IE)'],
#  [u'Applied Physics Major in Instrumentation'],
#  [u'Marketing Management'],
#  [u'Nursing'],
#  [u'Psychology'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'Business Administration'],
#  [u'Accounting'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'Information Technology (IT)'],
#  [u'Nursing'],
#  [u'Bilingual Education'],
#  [u'Business Administration'],
#  [u'Biology'],
#  [u'Elementary Education'],
#  [],
#  [u'Mathematics'],
#  [u'Information technology'],
#  [u'Pharmacy'],
#  [u'Hotel and Restaurant Management'],
#  [],
#  [u'Banking And Finance'],
#  [u'Computer Science\xa0with Specialization in Software Technology'],
#  [u'Civil Engineering'],
#  [],
#  [u'Tourism'],
#  [u'Hospitality Management', u'Tourism'],
#  [],
#  [u'Accounting'],
#  [],
#  [u'Hotel and Restaurant Management'],
#  [],
#  [u'Communication Arts / Mass Communication'],
#  [],
#  [u'Business Administration'],
#  [u'Interdisciplinary Business Studies'],
#  [u'Elementary Education Major in Special Education (SPED)'],
#  [u'Marketing Management'],
#  [],
#  [u'Information Technology'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'Fine Arts'],
#  [u'Food Technology'],
#  [],
#  [u'Commerce'],
#  [u'Agriculture'],
#  [u'Architecture'],
#  [],
#  [u'Information Technology'],
#  [u'Education'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [u'Advertising'],
#  [u'Business Administration & Accountancy'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'Diplomacy and International Relations with specialization in East and Southeast Asian Studies',
#   u'International Relations',
#   u'Political Science \u2013 Global Politics'],
#  [u'Art Education'],
#  [u'Speech Communication'],
#  [u'Computer Science'],
#  [u'Information Technology'],
#  [u'Electronics and Communications Engineering'],
#  [u'Hospitality Management'],
#  [u'Nursing'],
#  [u'Computer Science'],
#  [],
#  [u'Information technology'],
#  [],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'Marketing'],
#  [u'Elementary Education'],
#  [u'Education'],
#  [u'Communication Arts / Mass Communication'],
#  [u'Computer Science'],
#  [u'Financial Management'],
#  [u'Business Administration'],
#  [u'Banking And Finance'],
#  [],
#  [u'Psychology'],
#  [u'Information Technology (IT)'],
#  [u'Computer Secretarial'],
#  [u'Education'],
#  [u'Philosophy'],
#  [u'Industrial Engineering (IE)'],
#  [u'Accountancy'],
#  [u'Applied Mathematics'],
#  [u'Education'],
#  [u'Information Technology (IT)'],
#  [u'Hospitality Management'],
#  [],
#  [u'Business Administration'],
#  [u'Information Technology (IT)'],
#  [u'Speech Communication'],
#  [],
#  [u'Entrepreneurship'],
#  [u'Computer Science'],
#  [u'Information Technology'],
#  [],
#  [u'Financial Management'],
#  [u'Business Management'],
#  [u'Accountancy'],
#  [u'Marketing'],
#  [],
#  [],
#  [],
#  [u'Linguistics'],
#  [u'Computer Engineering'],
#  [],
#  [u'Information Technology (IT)'],
#  [u'Accountancy'],
#  [],
#  [u'Accounting', u'Business Management'],
#  [],
#  [],
#  [u'Chemistry'],
#  [u'Electronics and Communications Engineering'],
#  [u'Management Accounting'],
#  [u'Civil Engineering', u'Computer Technology'],
#  [u'Business Administration'],
#  [u'Accountancy'],
#  [u'Information Technology'],
#  [u'Tourism'],
#  [],
#  [],
#  [u'Civil Engineering'],
#  [u'Hospitality Management', u'Tourism'],
#  [],
#  [u'Legal Management'],
#  [u'Criminology/Criminal Justice'],
#  [u'Education'],
#  [],
#  [u'Political Science'],
#  [u'Electrical Engineering'],
#  [u'Tourism'],
#  [u'Computer Technician'],
#  [u'Information Technology'],
#  [],
#  [u'Culinary Arts'],
#  [u'Financial Management'],
#  [u'Communication Arts / Mass Communication'],
#  [u'Computer Science'],
#  [u'Information Technology'],
#  [u'Financial Management'],
#  [u'Electrical Engineering'],
#  [u'Commerce'],
#  [],
#  [u'Nursing'],
#  [u'Nursing'],
#  [u'Hotel and Restaurant Services'],
#  [u'Information Technology (IT)'],
#  [u'Visual Communication'],
#  [],
#  [u'Automotive Engineering'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'Information Technology (IT)'],
#  [u'Hotel and Restaurant Management'],
#  [u'Information Technology (IT)'],
#  [u'Information Technology (IT)'],
#  [u'Communication Arts / Mass Communication'],
#  [u'Art Management'],
#  [u'Entrepreneurship'],
#  [u'Business Management'],
#  [u'Chemistry with Materials Science and Engineering'],
#  [u'Information Technology (IT)'],
#  [u'Marketing'],
#  [u'Elementary Education'],
#  [u'Hospitality Management'],
#  [u'Information Technology'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [],
#  [u'Information Technology'],
#  [u'Marketing Management'],
#  [u'Business Administration'],
#  [],
#  [u'Information Technology (IT)'],
#  [u'Marketing Management'],
#  [u'Business Information Management'],
#  [u'Information Technology (IT)'],
#  [u'Business Administration'],
#  [u'Computer Secretarial'],
#  [u'Computer Technology'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'Accounting'],
#  [u'Information Technology'],
#  [u'International Studies'],
#  [u'Computer Science'],
#  [],
#  [u'Marketing Management'],
#  [u'Nursing'],
#  [u'Accountancy'],
#  [u'Hotel and Restaurant Management'],
#  [u'Business Administration'],
#  [u'Business Administration'],
#  [u'Computer Technology'],
#  [u'Education'],
#  [],
#  [u'Civil Engineering'],
#  [u'Accountancy'],
#  [u'Literature \u2013 English'],
#  [u'Electronics and Communications Engineering'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'BSIE'],
#  [u'Information Technology Entrepreneurship'],
#  [u'Accountancy'],
#  [u'Agriculture'],
#  [u'Office Administration'],
#  [u'Advertising'],
#  [u'Information Technology (IT)'],
#  [],
#  [u'Accountancy'],
#  [u'Public Administration'],
#  [u'Social Sciences'],
#  [u'Computer Science'],
#  [u'Applied Corporate Management'],
#  [u'Computer Programming'],
#  [u'Business Administration'],
#  [u'Education'],
#  [],
#  [u'Biology'],
#  [],
#  [u'Information Technology (IT)'],
#  [u'Information Technology (IT)'],
#  [u'Industrial Engineering (IE)'],
#  [u'Accountancy'],
#  [u'Accounting'],
#  [u'Office Administration'],
#  [u'Information Technology'],
#  [u'Elementary Education'],
#  [],
#  [u'Film', u'Photography'],
#  [u'CHEMICAL ENGINEERING'],
#  [u'Mathematics'],
#  [u'Entrepreneurship'],
#  [u'Accountancy'],
#  [u'Management Engineering'],
#  [u'Management Accounting'],
#  [u'Computer Engineering'],
#  [u'Nursing'],
#  [u'Accountancy'],
#  [u'English'],
#  [u'Business Administration'],
#  [],
#  [u'Philosophy'],
#  [],
#  [u'Hospitality Management'],
#  [u'Electrical Engineering'],
#  [u'Electronics and Communications Engineering'],
#  [],
#  [],
#  [u'Nursing'],
#  [u'Computer Secretarial'],
#  [],
#  [u'Communication Research'],
#  [u'Computer Engineering'],
#  [u'Mathematics'],
#  [u'Psychology'],
#  [u'Education'],
#  [],
#  [u'Political Science'],
#  [u'Education'],
#  [u'Accountancy'],
#  [u'Communication Arts / Mass Communication'],
#  [u'Interior design'],
#  [u'Hotel and Restaurant Management'],
#  [u'Business Administration'],
#  [],
#  [u'Chemistry'],
#  [u'Business Management'],
#  [u'Journalism', u'History', u'Anthropology'],
#  [u'Accountancy'],
#  [],
#  [u'Agribusiness Management'],
#  [u'Nursing'],
#  [u'Information Systems'],
#  [u'Civil Engineering'],
#  [],
#  [u'Information Technology (IT)'],
#  [],
#  [u'Computer Science'],
#  [u'Banking And Finance'],
#  [u'Marketing Management'],
#  [u'Business Administration', u'Marketing'],
#  [u'Office Administration'],
#  [u'Computer Science'],
#  [u'Advertising', u'Communication Arts / Mass Communication'],
#  [u'Information Technology (IT)'],
#  [u'Communication studies'],
#  [u'Computer Science'],
#  [u'Animation'],
#  [u'Financial Management'],
#  [u'Secondary Education'],
#  [],
#  [u'Business Administration', u'Business Management', u'Human Resources'],
#  [],
#  [],
#  [],
#  [u'Banking And Finance'],
#  [u'Communication Arts / Mass Communication'],
#  [u'Accountancy'],
#  [u'Information Technology (IT)'],
#  [],
#  [u'Mechanical Engineering'],
#  [u'Hotel and Restaurant Management'],
#  [],
#  [u'Computer Engineering'],
#  [u'Economics'],
#  [u'Information Technology (IT)'],
#  [u'Financial Management'],
#  [u'Information Technology'],
#  [u'Nursing'],
#  [],
#  [u'Computer Engineering'],
#  [u'Accounting'],
#  [u'Accounting'],
#  [],
#  [u'Film'],
#  [u'Nursing'],
#  [u'Hotel and Restaurant Management'],
#  [u'Accounting'],
#  [u'Information Technology (IT)'],
#  [u'Psychology'],
#  [u'Accountancy'],
#  [],
#  [u'Criminology/Criminal Justice'],
#  [u'Elementary Education'],
#  [u'Communication Arts / Mass Communication'],
#  [],
#  [u'Business Management'],
#  [u'Information Technology'],
#  [u'Elementary Education'],
#  [],
#  [u'Information Technology'],
#  [u'Computer Science'],
#  [],
#  [u'Elementary Education'],
#  [u'Computer Science\xa0with Specialization in Software Technology'],
#  [u'Business Administration'],
#  [u'Information Technology'],
#  [u'Information Technology (IT)'],
#  [],
#  [],
#  [],
#  [u'Computer Programming'],
#  [],
#  [u'Information Technology'],
#  [u'Business Management'],
#  [],
#  [u'Tourism'],
#  [],
#  [u'Accountancy'],
#  [],
#  [u'Applied Physics with Applied Computer Systems'],
#  [u'Tourism'],
#  [u'Information Technology'],
#  [u'Marine Transportation'],
#  [u'Criminology/Criminal Justice'],
#  [],
#  [],
#  [u'Food Technology'],
#  [u'Information Technology'],
#  [u'Chemistry'],
#  [],
#  [u'Marketing Management'],
#  [u'Nursing'],
#  [u'Secondary Education'],
#  [],
#  [],
#  [],
#  [u'Information Technology (IT)'],
#  [u'Computer Engineering'],
#  [u'Business Administration'],
#  [u'Computer Technology'],
#  [u'Organizational Communication'],
#  [],
#  [],
#  [],
#  [u'Electronics and Communications Engineering'],
#  [u'Psychology'],
#  [],
#  [u'Electronic Engineering'],
#  [u'Criminology/Criminal Justice'],
#  [u'Chemistry'],
#  [u'Accounting'],
#  [u'Biology'],
#  [u'Business Management'],
#  [u'Computer Science\xa0with Specialization in Software Technology'],
#  [u'Chemical Engineering'],
#  [u'Computer Technician'],
#  [u'Linguistics'],
#  [],
#  [],
#  [u'Mathematics'],
#  [u'Medical Technology'],
#  [],
#  [u'Business Administration'],
#  [u'Information Technology'],
#  [u'Computer Science\xa0with Specialization in Software Technology'],
#  [u'Computer Engineering'],
#  [],
#  [u'Business Administration'],
#  [u'Marketing Management'],
#  [u'Accountancy'],
#  [u'Civil Engineering'],
#  [u'Business Administration'],
#  [u'Chemistry'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'Information Technology'],
#  [u'Chemistry'],
#  [],
#  [u'Marine Transportation'],
#  [u'Chemistry'],
#  [u'Business Administration'],
#  [u'International Studies'],
#  [u'Information Technology (IT)'],
#  [u'Electronic Engineering'],
#  [u'Communication Arts / Mass Communication'],
#  [u'Mathematics'],
#  [],
#  [u'Information Technology (IT)'],
#  [u'Education'],
#  [],
#  [u'Information Technology'],
#  [u'Business Administration'],
#  [u'Information Technology (IT)'],
#  [u'Business Administration'],
#  [u'Information Technology'],
#  [],
#  [u'Mathematics'],
#  [u'Marketing'],
#  [u'Information Technology (IT)'],
#  [u'Accountancy'],
#  [u'Nursing'],
#  [u'Office Administration'],
#  [],
#  [u'Business Information Management'],
#  [u'Mining Engineering'],
#  [u'Civil Engineering'],
#  [u'Computer Science',
#   u'Computer Programming',
#   u'Computer Science\xa0with Specialization in Software Technology'],
#  [u'Business Administration'],
#  [u'Mathematics'],
#  [u'Information Design'],
#  [u'Business Administration'],
#  [u'Psychology'],
#  [u'Tourism'],
#  [],
#  [u'Mathematics'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'Hotel and Restaurant Services'],
#  [u'Business Administration'],
#  [u'Information Technology (IT)'],
#  [u'hotel and restaurant management'],
#  [u'Community Development'],
#  [u'Computer Science'],
#  [u'Computer Technology'],
#  [u'Accounting'],
#  [u'Psychology'],
#  [u'Industrial Management Engineering minor in Information Tehcnology'],
#  [u'Computer Programming'],
#  [u'Elementary Education'],
#  [u'Psychology'],
#  [u'Accountancy'],
#  [u'Secondary Education'],
#  [u'Education'],
#  [u'Civil Engineering'],
#  [u'Architecture'],
#  [u'Secondary Education'],
#  [u'Secondary Education'],
#  [u'Computer Science'],
#  [],
#  [u'Nursing'],
#  [u'Information Technology (IT)'],
#  [u'Business Management'],
#  [u'Communication Arts / Mass Communication'],
#  [u'Hotel and Restaurant Management'],
#  [],
#  [],
#  [u'Information Technology'],
#  [u'Social Sciences'],
#  [u'Social Sciences'],
#  [u'Hotel and Restaurant Services'],
#  [u'Business Management'],
#  [u'Business administration'],
#  [],
#  [u'Information Technology (IT)'],
#  [u'Nursing'],
#  [u'Marketing'],
#  [u'Business Management'],
#  [u'Journalism'],
#  [u'Psychology'],
#  [u'Computer Science'],
#  [u'Educational Psychology'],
#  [u'Electronics and Communications Engineering'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [],
#  [u'Management'],
#  [u'Business'],
#  [u'Information Technology'],
#  [u'Computer Science'],
#  [u'Computer Science'],
#  [u'Nursing'],
#  [u'Mathematics and Science Teaching'],
#  [u'Communication Arts / Mass Communication'],
#  [],
#  [u'Computer Science'],
#  [u'Accounting'],
#  [u'Asian Studies'],
#  [u'Banking And Finance'],
#  [u'Management'],
#  [u'Management\xa0(Honors)'],
#  [u'Creative Writing'],
#  [u'Computer Science'],
#  [u'Information Technology (IT)'],
#  [],
#  [],
#  [u'Business Administration'],
#  [u'Industrial Psychology'],
#  [u'Psychology'],
#  [u'Industrial Engineering'],
#  [u'Human Resources'],
#  [],
#  [u'Office Administration'],
#  [u'Psychology'],
#  [],
#  [u'Business Economics'],
#  [u'Dentistry'],
#  [u'Civil Engineering'],
#  [u'Social Sciences'],
#  [u'Business Management'],
#  [u'Marketing Management'],
#  [u'Criminology/Criminal Justice'],
#  [u'Financial Management'],
#  [],
#  [u'Food Technology'],
#  [],
#  [u'Business Administration'],
#  [u'Industrial Psychology'],
#  [u'Industrial Psychology'],
#  [u'Criminology/Criminal Justice'],
#  [u'Computer Science'],
#  [u'Banking And Finance'],
#  [u'Broadcast Communication'],
#  [u'Elementary Education Major in Pre-School Education'],
#  [u'Business Management'],
#  [u'Economics', u'Political Science'],
#  [u'Human Resources'],
#  [u'Computer Science'],
#  [u'Behavioral Science'],
#  [u'Commerce'],
#  [u'Elementary Education'],
#  [u'Information Technology'],
#  [u'Marketing Management'],
#  [u'Industrial Engineering'],
#  [u'Information Technology (IT)'],
#  [u'Hotel and Restaurant Management'],
#  [],
#  [u'Human Resources'],
#  [u'Broadcast Communication'],
#  [],
#  [],
#  [u'Secondary Education'],
#  [u'Information Technology'],
#  [],
#  [u'Hotel and Restaurant Services'],
#  [u'Electronics and Communications Engineering'],
#  [],
#  [u'Electro-Mechanical Technology'],
#  [u'Banking And Finance'],
#  [u'Biology'],
#  [],
#  [u'Information Design'],
#  [u'Industrial Engineering'],
#  [u'Information Technology (IT)'],
#  [u'Information Technology'],
#  [u'Tourism'],
#  [u'Secondary Education'],
#  [u'Electronics and Communications Engineering'],
#  [u'Nursing'],
#  [u'Elementary Education Major in Special Education (SPED)'],
#  [u'Business Administration'],
#  [u'Midwifery'],
#  [u'Information Technology (IT)'],
#  [u'Mass Communication',
#   u'Philippine Studies, major in Filipino in Mass Media'],
#  [u'Business Administration'],
#  [u'Business Administration'],
#  [u'Molecular Biology & Biotechnology'],
#  [u'Business Management', u'Entrepreneurship', u'Marketing'],
#  [u'Electrical Engineering'],
#  [u'Commerce'],
#  [u'Business Administration'],
#  [u'Computer Technology'],
#  [u'Information Technology'],
#  [u'Business Administration'],
#  [u'Accounting'],
#  [u'Interdisciplinary Studies'],
#  [u'International Relations'],
#  [u'Applied Corporate Management'],
#  [u'Computer Science'],
#  [u'Art Education'],
#  [u'Psychology'],
#  [u'Communications Technology Management'],
#  [u'Hotel and Restaurant Management'],
#  [u'Hotel and Restaurant Management'],
#  [u'Human Resources'],
#  [u'Information Technology'],
#  [],
#  [u'Information Design'],
#  [u'Civil Engineering'],
#  [u'Business Administration'],
#  [],
#  [],
#  [],
#  [u'Information Technology'],
#  [u'Psychology'],
#  [u'Agriculture'],
#  [u'Legal Management'],
#  [u'Communication Arts / Mass Communication'],
#  [u'Communication Arts / Mass Communication'],
#  [u'Hotel and Restaurant Management'],
#  [u'Marketing'],
#  [u'Management of Applied Chemistry'],
#  [u'Management Engineering'],
#  [u'Communications Technology Management'],
#  [u'Mechanical Engineering'],
#  [],
#  [u'Information Technology (IT)'],
#  [u'Computer Science'],
#  [u'Human Resources'],
#  [u'Information Technology (IT)'],
#  [u'Nursing'],
#  [],
#  [u'Computer Science'],
#  [u'Mathematics'],
#  [u'Psychology'],
#  [u'Agribusiness Management'],
#  [u'Animation'],
#  [u'Nursing'],
#  [u'Computer Science\xa0with Specialization in Software Technology'],
#  [u'International Relations'],
#  [],
#  [u'Nursing'],
#  [u'Business Administration'],
#  [u'Electronics and Communications Engineering'],
#  [u'Psychology'],
#  [u'Nursing'],
#  [u'Food Technology'],
#  [],
#  [u'Banking And Finance', u'Financial Management'],
#  [u'Computer Science'],
#  [u'Foodservice Management'],
#  [u'Computer Technology'],
#  [u'Information Technology'],
#  [u'Business Administration'],
#  [u'Communication Arts / Mass Communication'],
#  [u'Computer Engineering'],
#  [u'Computer Graphics',
#   u'Computer Programming',
#   u'Computer Science\xa0Major in Computer Systems Engineering',
#   u'Computer Science'],
#  [u'Information Technology'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'Human Resources'],
#  [u'Information Technology'],
#  [u'Human Resources'],
#  [u'Computer Science'],
#  [],
#  [],
#  [],
#  [u'Computer Science'],
#  [u'Information Systems'],
#  [u'Hospitality Management'],
#  [u'Banking And Finance'],
#  [u'Electrical Engineering'],
#  [u'Marketing Management'],
#  [u'Psychology'],
#  [u'Economics'],
#  [u'Computer Engineering'],
#  [u'Business Administration'],
#  [u'Computer Science'],
#  [u'Elementary Education'],
#  [u'Business Administration'],
#  [u'Information Technology (IT)'],
#  [u'Marine Transportation'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'Tourism'],
#  [u'Marketing Management'],
#  [u'Business Administration'],
#  [u'Marketing Management'],
#  [u'Information Technology'],
#  [u'Information Technology'],
#  [u'Information Technology'],
#  [u'Communication Arts / Mass Communication'],
#  [u'Hotel and Restaurant Services'],
#  [],
#  [u'Information technology'],
#  [u'Tourism'],
#  [u'Business Administration & Accountancy'],
#  [u'Accountancy'],
#  [u'Nursing'],
#  [],
#  [u'Computer Science'],
#  [],
#  [u'Accountancy'],
#  [u'Marketing Management'],
#  [u'Electronics and Communications Engineering'],
#  [u'Nursing'],
#  [u'Information Design'],
#  [u'Culinary Arts'],
#  [u'Psychology'],
#  [u'Accountancy'],
#  [u'Human Resources', u'Business Administration', u'Business Management'],
#  [],
#  [u'Financial Management'],
#  [u'Creative Writing'],
#  [u'Tourism'],
#  [u'Industrial Management Engineering minor in Information Tehcnology'],
#  [u'Accountancy'],
#  [u'Information Technology'],
#  [u'Business Administration'],
#  [],
#  [u'Accounting'],
#  [u'Accounting'],
#  [u'Business Administration'],
#  [u'Political Science \u2013 Global Politics'],
#  [u'Business Management'],
#  [u'Electronic Engineering'],
#  [u'Marketing Management'],
#  [u'Information Technology'],
#  [u'Accountancy'],
#  [],
#  [u'Civil engineering'],
#  [u'Human Resources'],
#  [u'Commerce'],
#  [u'Communication Research'],
#  [u'Human Resources'],
#  [u'Business Administration'],
#  [u'Business Management', u'Information Technology'],
#  [u'Psychology'],
#  [],
#  [u'Computer Engineering'],
#  [],
#  [u'Information Technology (IT)'],
#  [u'Civil Engineering'],
#  [u'Civil Engineering'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'Business Administration'],
#  [u'Business Administration'],
#  [],
#  [u'Nursing'],
#  [u'Multimedia Arts'],
#  [u'Business Administration', u'Finance'],
#  [u'Criminology/Criminal justice'],
#  [u'Information Technology (IT)'],
#  [u'Nursing'],
#  [u'Biology'],
#  [u'Healthcare Science'],
#  [u'Secondary Education'],
#  [u'Nursing'],
#  [u'Information Technology'],
#  [u'Business Administration'],
#  [u'Psychology'],
#  [u'Education',
#   u'Elementary Education',
#   u'Elementary Education Major in Pre-School Education',
#   u'English'],
#  [u'Agribusiness Management'],
#  [u'Geology'],
#  [u'Political Science'],
#  [u'Secondary Education'],
#  [],
#  [u'Biology'],
#  [u'Computer Science'],
#  [u'Political Science'],
#  [u'Computer Secretarial'],
#  [u'Biology'],
#  [u'Accountancy'],
#  [],
#  [u'Business Management'],
#  [u'Human Resources (HR)'],
#  [],
#  [u'Applied Physics'],
#  [u'Business Administration'],
#  [u'Business Management'],
#  [u'Computer Engineering'],
#  [],
#  [u'Hotel and Restaurant Management'],
#  [u'Marketing Management'],
#  [u'Criminology/Criminal Justice'],
#  [],
#  [u'Computer Programming'],
#  [u'Electronics and Communications Engineering'],
#  [u'Computer Programming'],
#  [u'Banking And Finance'],
#  [u'Banking And Finance'],
#  [u'Computer Engineering'],
#  [u'Human Resources'],
#  [u'Information Technology'],
#  [u'Information Technology (IT)'],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [],
#  [],
#  [u'Human Resources'],
#  [u'Electronics and Communications Engineering'],
#  [u'Computer Technology'],
#  [u'Business Administration'],
#  [u'Information Technology (IT)'],
#  [u'Elementary Education'],
#  [u'Economics'],
#  [],
#  [u'Business Administration'],
#  [u'Political Science'],
#  [u'Civil Engineering'],
#  [u'Information Technology'],
#  [],
#  [u'Economics'],
#  [u'Civil Engineering'],
#  [],
#  [u'Financial Management'],
#  [],
#  [u'Hotel and Restaurant Management (HRM)'],
#  [u'Pharmacy'],
#  [u'Information Technology'],
#  [u'Food Technology',
#   u'Hotel and Restaurant Management',
#   u'Foodservice Management'],
#  [u'Public Administration'],
#  [u'Office Administration'],
#  [u'Psychology'],
#  [u'Clinical Psychology'],
#  [u'Human Resources'],
#  [u'Applied Mathematics Major in Mathematical Finance'],
#  [u'Advertising Management'],
#  [u'Business Administration'],
#  [u'Business Management'],
#  [u'Communication studies'],
#  [u'Elementary Education'],
#  [u'Business Administration'],
#  [],
#  [u'Applied Physics'],
#  [u'Commerce Major in Entrepreneurship'],
#  [u'Business Management', u'Psychology'],
#  [],
#  [u'Financial Management'],
#  [u'Psychology'],
#  [u'Information technology'],
#  [u'Business Administration'],
#  [u'Marketing Management'],
#  [u'Information Technology'],
#  [u'Customs Administration'],
#  [u'Information Technology'],
#  [u'Accounting'],
#  [u'Political Science'],
#  [],
#  [u'Management'],
#  [u'Financial Management'],
#  [u'Psychology'],
#  [u'Computer Science'],
#  [u'Communication Arts / Mass Communication'],
#  [u'Foodservice Management'],
#  [u'Information Technology'],
#  [u'Information Technology Entrepreneurship'],
#  [u'Industrial Engineering'],
#  [u'Marketing Management'],
#  [u'Information Technology (IT)'],
#  [u'Mass Communication'],
#  [u'Elementary Education Major in Special Education (SPED)'],
#  [u'Human Resources'],
#  [],
#  [u'Communication Arts / Mass Communication'],
#  [],
#  [u'Computer Engineering'],
#  [u'Agribusiness Management'],
#  [u'Agribusiness Economics'],
#  [u'Hotel and Restaurant Services'],
#  [u'Information Technology'],
#  [],
#  [u'Computer Engineering'],
#  [],
#  [u'Industrial Management Engineering minor in Information Tehcnology'],
#  [u'Economics'],
#  [u'Tourism'],
#  [u'Business Administration'],
#  [u'Broadcast Communication'],
#  [u'Hotel and Restaurant Services'],
#  [u'Legal Management'],
#  [u'Education'],
#  [u'Computer Science'],
#  [u'Bachelor of Science in Commerce major in Management'],
#  [u'Marketing'],
#  [u'Computer Technology'],
#  [u'Business Administration'],
#  [],
#  [u'Pharmacy'],
#  [u'Secondary Education'],
#  [u'Computer Technology'],
#  [u'Information Technology'],
#  [u'Hotel, Restaurant & Institution Management'],
#  [u'Information Technology (IT)'],
#  [u'Business Administration'],
#  [u'Business Management'],
#  [],
#  [u'Information Technology (IT)'],
#  [u'Banking And Finance'],
#  [u'Information Technology (IT)'],
#  [u'Secondary Education'],
#  [u'Computer Programming'],
#  [u'Mathematics'],
#  [],
#  [u'Human Resources'],
#  [u'Computer Engineering'],
#  [u'Business Administration & Accountancy'],
#  [u'Human Resources (HR)'],
#  [],
#  [u'Information Technology (IT)'],
#  [u'Accountancy'],
#  [u'Pharmacy'],
#  [u'Banking And Finance'],
#  [u'Business Management'],
#  [u'Accounting'],
#  [u'Business Administration & Accountancy'],
#  [u'Accountancy'],
#  [u'Information Technology (IT)'],
#  [],
#  [u'Tourism'],
#  [u'Secondary Education'],
#  [],
#  [u'Business Administration & Accountancy'],
#  [u'Business Administration'],
#  [u'Business Economics'],
#  [u'Hotel and Restaurant Services'],
#  [u'Art Management'],
#  [u'Financial Management'],
#  [u'Banking And Finance'],
#  [u'Mechanical Engineering'],
#  [u'Accounting'],
#  [u'Community Development'],
#  [u'Accountancy'],
#  [u'Information Technology (IT)'],
#  [u'Commerce Major in Entrepreneurship'],
#  [],
#  [u'Chemical Engineering'],
#  [u'Midwifery-Obstetrics'],
#  [],
#  [u'Business Administration'],
#  [u'Management'],
#  [u'Advertising', u'Communication Arts / Mass Communication'],
#  [u'Computer Technology'],
#  [u'Nursing'],
#  [u'Applied Physics with Applied Computer Systems'],
#  [u'Mathematics'],
#  [u'Marketing Management'],
#  [u'Banking And Finance'],
#  [u'Electronics and Communications Engineering'],
#  [u'Criminology/Criminal Justice'],
#  [u'Applied Psychology'],
#  [u'Business Administration & Accountancy'],
#  [u'Banking And Finance'],
#  [u'Business Administration'],
#  [],
#  [u'Business Administration', u'Financial Management'],
#  [u'Art Studies'],
#  [],
#  [u'English'],
#  [u'Public Administration'],
#  [u'Computer Engineering'],
#  [u'Business Administration'],
#  [u'Public Administration', u'Economics'],
#  [u'Financial Management'],
#  [u'Information Technology (IT)'],
#  [u'Business Administration'],
#  [u'Computer Programming'],
#  [u'Nursing'],
#  [u'Information Technology'],
#  [u'Legal Management'],
#  [],
#  [u'Computer Science'],
#  [u'Computer Technology'],
#  [u'Commerce Major in Entrepreneurship'],
#  [],
#  [u'Human Resources'],
#  [],
#  [u'Applied Sociology'],
#  [u'Human Resources'],
#  [u'Accounting'],
#  [u'Financial Management'],
#  [u'Business Administration'],
#  [u'History'],
#  [u'Education'],
#  [],
#  [],
#  [u'Financial Management'],
#  [u'Computer Science'],
#  [u'Information Systems'],
#  [u'Psychology'],
#  [],
#  [u'Business Information Management'],
#  [u'Accountancy'],
#  [],
#  [],
#  [u'Agribusiness Management', u'Business Management'],
#  [u'Marine Engineering'],
#  [u'Management Engineering'],
#  [u'Agriculture'],
#  [u'Physical Therapy'],
#  ...]
