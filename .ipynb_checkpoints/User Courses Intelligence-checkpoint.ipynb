# %% [markdown]
# c/o Rico

# %%
from abelian import db
from abelian.models import User, Job, ProfilerAnswer, Profiler
from collections import defaultdict

db.configure("postgresql://kalibrr:password@localhost/kalibrr", False)
session = db.get_session()

# %%
# gather data
db_course_data = \
    session.query(ProfilerAnswer.data).filter(
        ProfilerAnswer.profiler_code==Profiler.code,
        Profiler.type=='EducationProfiler',
        ProfilerAnswer.user_id==User.id,
        ~User.is_test
    ).all()

# %%
db_course_data[0][0]
# Out:
# {u'education': {u'date_last_in_school': u'2005-02-28T16:00:00.000Z',
#   u'fields_of_study': [u'Alternative Education'],
#   u'level': u'Graduated from college',
#   u'status': 300}}

# %%
from algoutils import *

# gather courses
raw_courses = flatten([
    ' / '.join(item[0]['education']['fields_of_study'])
    for item in db_course_data
    if len(item) > 0
    and 'education' in item[0]
    and 'fields_of_study' in item[0]['education']
    and len(item[0]['education']['fields_of_study'])
])

# %%
from cleaning import clean
clean_courses = clean(raw_courses, style='course')

# %%
len(clean_courses)
# Out:
# 38160

# %%
courses = flatten(split(clean_courses, '/'))

# %%
courses
# Out:
# ['ALTERNATIVE EDUCATION',
#  'BUSINESS ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'INDUSTRIAL ENGINEERING IE',
#  'APPLIED PHYSIC',
#  'INSTRUMENTATION',
#  'MARKETING MANAGEMENT',
#  'NURSING',
#  'PSYCHOLOGY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'BUSINESS ADMINISTRATION',
#  'ACCOUNTING',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'NURSING',
#  'BILINGUAL EDUCATION',
#  'BUSINESS ADMINISTRATION',
#  'BIOLOGY',
#  'ELEMENTARY EDUCATION',
#  'MATHEMATICS',
#  'INFORMATION TECHNOLOGY',
#  'PHARMACY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'BANKING FINANCE',
#  'COMPUTER SCIENCEWITH',
#  'SOFTWARE TECHNOLOGY',
#  'CIVIL ENGINEERING',
#  'TOURISM',
#  'HOSPITALITY MANAGEMENT',
#  'TOURISM',
#  'ACCOUNTING',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'BUSINESS ADMINISTRATION',
#  'INTERDISCIPLINARY BUSINESS STUDY',
#  'ELEMENTARY EDUCATION',
#  'SPECIAL EDUCATION SPED',
#  'MARKETING MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'FINE ART',
#  'FOOD TECHNOLOGY',
#  'COMMERCE',
#  'AGRICULTURE',
#  'ARCHITECTURE',
#  'INFORMATION TECHNOLOGY',
#  'EDUCATION',
#  'ADVERTISING',
#  'BUSINESS ADMINISTRATION ACCOUNTANCY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'DIPLOMACY INTERNATIONAL RELATION',
#  'EAST SOUTHEAST ASIAN STUDY',
#  'INTERNATIONAL RELATION',
#  'POLITICAL SCIENCE GLOBAL POLITICS',
#  'ART EDUCATION',
#  'SPEECH COMMUNICATION',
#  'COMPUTER SCIENCE',
#  'INFORMATION TECHNOLOGY',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'HOSPITALITY MANAGEMENT',
#  'NURSING',
#  'COMPUTER SCIENCE',
#  'INFORMATION TECHNOLOGY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'MARKETING',
#  'ELEMENTARY EDUCATION',
#  'EDUCATION',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'COMPUTER SCIENCE',
#  'FINANCIAL MANAGEMENT',
#  'BUSINESS ADMINISTRATION',
#  'BANKING FINANCE',
#  'PSYCHOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'COMPUTER SECRETARIAL',
#  'EDUCATION',
#  'PHILOSOPHY',
#  'INDUSTRIAL ENGINEERING IE',
#  'ACCOUNTANCY',
#  'APPLIED MATHEMATICS',
#  'EDUCATION',
#  'INFORMATION TECHNOLOGY',
#  'HOSPITALITY MANAGEMENT',
#  'BUSINESS ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'SPEECH COMMUNICATION',
#  'ENTREPRENEURSHIP',
#  'COMPUTER SCIENCE',
#  'INFORMATION TECHNOLOGY',
#  'FINANCIAL MANAGEMENT',
#  'BUSINESS MANAGEMENT',
#  'ACCOUNTANCY',
#  'MARKETING',
#  'LINGUISTICS',
#  'COMPUTER ENGINEERING',
#  'INFORMATION TECHNOLOGY',
#  'ACCOUNTANCY',
#  'ACCOUNTING',
#  'BUSINESS MANAGEMENT',
#  'CHEMISTRY',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'MANAGEMENT ACCOUNTING',
#  'CIVIL ENGINEERING',
#  'COMPUTER TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'ACCOUNTANCY',
#  'INFORMATION TECHNOLOGY',
#  'TOURISM',
#  'CIVIL ENGINEERING',
#  'HOSPITALITY MANAGEMENT',
#  'TOURISM',
#  'LEGAL MANAGEMENT',
#  'CRIMINOLOGY',
#  'CRIMINAL JUSTICE',
#  'EDUCATION',
#  'POLITICAL SCIENCE',
#  'ELECTRICAL ENGINEERING',
#  'TOURISM',
#  'COMPUTER TECHNICIAN',
#  'INFORMATION TECHNOLOGY',
#  'CULINARY ART',
#  'FINANCIAL MANAGEMENT',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'COMPUTER SCIENCE',
#  'INFORMATION TECHNOLOGY',
#  'FINANCIAL MANAGEMENT',
#  'ELECTRICAL ENGINEERING',
#  'COMMERCE',
#  'NURSING',
#  'NURSING',
#  'HOTEL RESTAURANT SERVICE',
#  'INFORMATION TECHNOLOGY',
#  'VISUAL COMMUNICATION',
#  'AUTOMOTIVE ENGINEERING',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'ART MANAGEMENT',
#  'ENTREPRENEURSHIP',
#  'BUSINESS MANAGEMENT',
#  'CHEMISTRY',
#  'MATERIAL SCIENCE ENGINEERING',
#  'INFORMATION TECHNOLOGY',
#  'MARKETING',
#  'ELEMENTARY EDUCATION',
#  'HOSPITALITY MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'MARKETING MANAGEMENT',
#  'BUSINESS ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'MARKETING MANAGEMENT',
#  'BUSINESS INFORMATION MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'COMPUTER SECRETARIAL',
#  'COMPUTER TECHNOLOGY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'ACCOUNTING',
#  'INFORMATION TECHNOLOGY',
#  'INTERNATIONAL STUDY',
#  'COMPUTER SCIENCE',
#  'MARKETING MANAGEMENT',
#  'NURSING',
#  'ACCOUNTANCY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'BUSINESS ADMINISTRATION',
#  'BUSINESS ADMINISTRATION',
#  'COMPUTER TECHNOLOGY',
#  'EDUCATION',
#  'CIVIL ENGINEERING',
#  'ACCOUNTANCY',
#  'LITERATURE ENGLISH',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'IE',
#  'INFORMATION TECHNOLOGY ENTREPRENEURSHIP',
#  'ACCOUNTANCY',
#  'AGRICULTURE',
#  'OFFICE ADMINISTRATION',
#  'ADVERTISING',
#  'INFORMATION TECHNOLOGY',
#  'ACCOUNTANCY',
#  'PUBLIC ADMINISTRATION',
#  'SOCIAL SCIENCE',
#  'COMPUTER SCIENCE',
#  'APPLIED CORPORATE MANAGEMENT',
#  'COMPUTER PROGRAMMING',
#  'BUSINESS ADMINISTRATION',
#  'EDUCATION',
#  'BIOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'INDUSTRIAL ENGINEERING IE',
#  'ACCOUNTANCY',
#  'ACCOUNTING',
#  'OFFICE ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'ELEMENTARY EDUCATION',
#  'FILM',
#  'PHOTOGRAPHY',
#  'CHEMICAL ENGINEERING',
#  'MATHEMATICS',
#  'ENTREPRENEURSHIP',
#  'ACCOUNTANCY',
#  'MANAGEMENT ENGINEERING',
#  'MANAGEMENT ACCOUNTING',
#  'COMPUTER ENGINEERING',
#  'NURSING',
#  'ACCOUNTANCY',
#  'ENGLISH',
#  'BUSINESS ADMINISTRATION',
#  'PHILOSOPHY',
#  'HOSPITALITY MANAGEMENT',
#  'ELECTRICAL ENGINEERING',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'NURSING',
#  'COMPUTER SECRETARIAL',
#  'COMMUNICATION RESEARCH',
#  'COMPUTER ENGINEERING',
#  'MATHEMATICS',
#  'PSYCHOLOGY',
#  'EDUCATION',
#  'POLITICAL SCIENCE',
#  'EDUCATION',
#  'ACCOUNTANCY',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'INTERIOR DESIGN',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'BUSINESS ADMINISTRATION',
#  'CHEMISTRY',
#  'BUSINESS MANAGEMENT',
#  'JOURNALISM',
#  'HISTORY',
#  'ANTHROPOLOGY',
#  'ACCOUNTANCY',
#  'AGRIBUSINESS MANAGEMENT',
#  'NURSING',
#  'INFORMATION SYSTEM',
#  'CIVIL ENGINEERING',
#  'INFORMATION TECHNOLOGY',
#  'COMPUTER SCIENCE',
#  'BANKING FINANCE',
#  'MARKETING MANAGEMENT',
#  'BUSINESS ADMINISTRATION',
#  'MARKETING',
#  'OFFICE ADMINISTRATION',
#  'COMPUTER SCIENCE',
#  'ADVERTISING',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'INFORMATION TECHNOLOGY',
#  'COMMUNICATION STUDY',
#  'COMPUTER SCIENCE',
#  'ANIMATION',
#  'FINANCIAL MANAGEMENT',
#  'SECONDARY EDUCATION',
#  'BUSINESS ADMINISTRATION',
#  'BUSINESS MANAGEMENT',
#  'HUMAN RESOURCE',
#  'BANKING FINANCE',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'ACCOUNTANCY',
#  'INFORMATION TECHNOLOGY',
#  'MECHANICAL ENGINEERING',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'COMPUTER ENGINEERING',
#  'ECONOMICS',
#  'INFORMATION TECHNOLOGY',
#  'FINANCIAL MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'NURSING',
#  'COMPUTER ENGINEERING',
#  'ACCOUNTING',
#  'ACCOUNTING',
#  'FILM',
#  'NURSING',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'ACCOUNTING',
#  'INFORMATION TECHNOLOGY',
#  'PSYCHOLOGY',
#  'ACCOUNTANCY',
#  'CRIMINOLOGY',
#  'CRIMINAL JUSTICE',
#  'ELEMENTARY EDUCATION',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'BUSINESS MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'ELEMENTARY EDUCATION',
#  'INFORMATION TECHNOLOGY',
#  'COMPUTER SCIENCE',
#  'ELEMENTARY EDUCATION',
#  'COMPUTER SCIENCEWITH',
#  'SOFTWARE TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'COMPUTER PROGRAMMING',
#  'INFORMATION TECHNOLOGY',
#  'BUSINESS MANAGEMENT',
#  'TOURISM',
#  'ACCOUNTANCY',
#  'APPLIED PHYSIC',
#  'APPLIED COMPUTER SYSTEM',
#  'TOURISM',
#  'INFORMATION TECHNOLOGY',
#  'MARINE TRANSPORTATION',
#  'CRIMINOLOGY',
#  'CRIMINAL JUSTICE',
#  'FOOD TECHNOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'CHEMISTRY',
#  'MARKETING MANAGEMENT',
#  'NURSING',
#  'SECONDARY EDUCATION',
#  'INFORMATION TECHNOLOGY',
#  'COMPUTER ENGINEERING',
#  'BUSINESS ADMINISTRATION',
#  'COMPUTER TECHNOLOGY',
#  'ORGANIZATIONAL COMMUNICATION',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'PSYCHOLOGY',
#  'ELECTRONIC ENGINEERING',
#  'CRIMINOLOGY',
#  'CRIMINAL JUSTICE',
#  'CHEMISTRY',
#  'ACCOUNTING',
#  'BIOLOGY',
#  'BUSINESS MANAGEMENT',
#  'COMPUTER SCIENCEWITH',
#  'SOFTWARE TECHNOLOGY',
#  'CHEMICAL ENGINEERING',
#  'COMPUTER TECHNICIAN',
#  'LINGUISTICS',
#  'MATHEMATICS',
#  'MEDICAL TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'COMPUTER SCIENCEWITH',
#  'SOFTWARE TECHNOLOGY',
#  'COMPUTER ENGINEERING',
#  'BUSINESS ADMINISTRATION',
#  'MARKETING MANAGEMENT',
#  'ACCOUNTANCY',
#  'CIVIL ENGINEERING',
#  'BUSINESS ADMINISTRATION',
#  'CHEMISTRY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'CHEMISTRY',
#  'MARINE TRANSPORTATION',
#  'CHEMISTRY',
#  'BUSINESS ADMINISTRATION',
#  'INTERNATIONAL STUDY',
#  'INFORMATION TECHNOLOGY',
#  'ELECTRONIC ENGINEERING',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'MATHEMATICS',
#  'INFORMATION TECHNOLOGY',
#  'EDUCATION',
#  'INFORMATION TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'MATHEMATICS',
#  'MARKETING',
#  'INFORMATION TECHNOLOGY',
#  'ACCOUNTANCY',
#  'NURSING',
#  'OFFICE ADMINISTRATION',
#  'BUSINESS INFORMATION MANAGEMENT',
#  'MINING ENGINEERING',
#  'CIVIL ENGINEERING',
#  'COMPUTER SCIENCE',
#  'COMPUTER PROGRAMMING',
#  'COMPUTER SCIENCEWITH',
#  'SOFTWARE TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'MATHEMATICS',
#  'INFORMATION DESIGN',
#  'BUSINESS ADMINISTRATION',
#  'PSYCHOLOGY',
#  'TOURISM',
#  'MATHEMATICS',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'HOTEL RESTAURANT SERVICE',
#  'BUSINESS ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'COMMUNITY DEVELOPMENT',
#  'COMPUTER SCIENCE',
#  'COMPUTER TECHNOLOGY',
#  'ACCOUNTING',
#  'PSYCHOLOGY',
#  'INDUSTRIAL MANAGEMENT ENGINEERING',
#  'INFORMATION TEHCNOLOGY',
#  'COMPUTER PROGRAMMING',
#  'ELEMENTARY EDUCATION',
#  'PSYCHOLOGY',
#  'ACCOUNTANCY',
#  'SECONDARY EDUCATION',
#  'EDUCATION',
#  'CIVIL ENGINEERING',
#  'ARCHITECTURE',
#  'SECONDARY EDUCATION',
#  'SECONDARY EDUCATION',
#  'COMPUTER SCIENCE',
#  'NURSING',
#  'INFORMATION TECHNOLOGY',
#  'BUSINESS MANAGEMENT',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'SOCIAL SCIENCE',
#  'SOCIAL SCIENCE',
#  'HOTEL RESTAURANT SERVICE',
#  'BUSINESS MANAGEMENT',
#  'BUSINESS ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'NURSING',
#  'MARKETING',
#  'BUSINESS MANAGEMENT',
#  'JOURNALISM',
#  'PSYCHOLOGY',
#  'COMPUTER SCIENCE',
#  'EDUCATIONAL PSYCHOLOGY',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'MANAGEMENT',
#  'BUSINESS',
#  'INFORMATION TECHNOLOGY',
#  'COMPUTER SCIENCE',
#  'COMPUTER SCIENCE',
#  'NURSING',
#  'MATHEMATICS SCIENCE TEACHING',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'COMPUTER SCIENCE',
#  'ACCOUNTING',
#  'ASIAN STUDY',
#  'BANKING FINANCE',
#  'MANAGEMENT',
#  'MANAGEMENT HONOR',
#  'CREATIVE WRITING',
#  'COMPUTER SCIENCE',
#  'INFORMATION TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'INDUSTRIAL PSYCHOLOGY',
#  'PSYCHOLOGY',
#  'INDUSTRIAL ENGINEERING',
#  'HUMAN RESOURCE',
#  'OFFICE ADMINISTRATION',
#  'PSYCHOLOGY',
#  'BUSINESS ECONOMICS',
#  'DENTISTRY',
#  'CIVIL ENGINEERING',
#  'SOCIAL SCIENCE',
#  'BUSINESS MANAGEMENT',
#  'MARKETING MANAGEMENT',
#  'CRIMINOLOGY',
#  'CRIMINAL JUSTICE',
#  'FINANCIAL MANAGEMENT',
#  'FOOD TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'INDUSTRIAL PSYCHOLOGY',
#  'INDUSTRIAL PSYCHOLOGY',
#  'CRIMINOLOGY',
#  'CRIMINAL JUSTICE',
#  'COMPUTER SCIENCE',
#  'BANKING FINANCE',
#  'BROADCAST COMMUNICATION',
#  'ELEMENTARY EDUCATION',
#  'PRE SCHOOL EDUCATION',
#  'BUSINESS MANAGEMENT',
#  'ECONOMICS',
#  'POLITICAL SCIENCE',
#  'HUMAN RESOURCE',
#  'COMPUTER SCIENCE',
#  'BEHAVIORAL SCIENCE',
#  'COMMERCE',
#  'ELEMENTARY EDUCATION',
#  'INFORMATION TECHNOLOGY',
#  'MARKETING MANAGEMENT',
#  'INDUSTRIAL ENGINEERING',
#  'INFORMATION TECHNOLOGY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'HUMAN RESOURCE',
#  'BROADCAST COMMUNICATION',
#  'SECONDARY EDUCATION',
#  'INFORMATION TECHNOLOGY',
#  'HOTEL RESTAURANT SERVICE',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'ELECTRO MECHANICAL TECHNOLOGY',
#  'BANKING FINANCE',
#  'BIOLOGY',
#  'INFORMATION DESIGN',
#  'INDUSTRIAL ENGINEERING',
#  'INFORMATION TECHNOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'TOURISM',
#  'SECONDARY EDUCATION',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'NURSING',
#  'ELEMENTARY EDUCATION',
#  'SPECIAL EDUCATION SPED',
#  'BUSINESS ADMINISTRATION',
#  'MIDWIFERY',
#  'INFORMATION TECHNOLOGY',
#  'MASS COMMUNICATION',
#  'PHILIPPINE STUDY',
#  'FILIPINO',
#  'MASS MEDIUM',
#  'BUSINESS ADMINISTRATION',
#  'BUSINESS ADMINISTRATION',
#  'MOLECULAR BIOLOGY BIOTECHNOLOGY',
#  'BUSINESS MANAGEMENT',
#  'ENTREPRENEURSHIP',
#  'MARKETING',
#  'ELECTRICAL ENGINEERING',
#  'COMMERCE',
#  'BUSINESS ADMINISTRATION',
#  'COMPUTER TECHNOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'ACCOUNTING',
#  'INTERDISCIPLINARY STUDY',
#  'INTERNATIONAL RELATION',
#  'APPLIED CORPORATE MANAGEMENT',
#  'COMPUTER SCIENCE',
#  'ART EDUCATION',
#  'PSYCHOLOGY',
#  'COMMUNICATION TECHNOLOGY MANAGEMENT',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'HUMAN RESOURCE',
#  'INFORMATION TECHNOLOGY',
#  'INFORMATION DESIGN',
#  'CIVIL ENGINEERING',
#  'BUSINESS ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'PSYCHOLOGY',
#  'AGRICULTURE',
#  'LEGAL MANAGEMENT',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'MARKETING',
#  'MANAGEMENT',
#  'APPLIED CHEMISTRY',
#  'MANAGEMENT ENGINEERING',
#  'COMMUNICATION TECHNOLOGY MANAGEMENT',
#  'MECHANICAL ENGINEERING',
#  'INFORMATION TECHNOLOGY',
#  'COMPUTER SCIENCE',
#  'HUMAN RESOURCE',
#  'INFORMATION TECHNOLOGY',
#  'NURSING',
#  'COMPUTER SCIENCE',
#  'MATHEMATICS',
#  'PSYCHOLOGY',
#  'AGRIBUSINESS MANAGEMENT',
#  'ANIMATION',
#  'NURSING',
#  'COMPUTER SCIENCEWITH',
#  'SOFTWARE TECHNOLOGY',
#  'INTERNATIONAL RELATION',
#  'NURSING',
#  'BUSINESS ADMINISTRATION',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'PSYCHOLOGY',
#  'NURSING',
#  'FOOD TECHNOLOGY',
#  'BANKING FINANCE',
#  'FINANCIAL MANAGEMENT',
#  'COMPUTER SCIENCE',
#  'FOODSERVICE MANAGEMENT',
#  'COMPUTER TECHNOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'COMPUTER ENGINEERING',
#  'COMPUTER GRAPHIC',
#  'COMPUTER PROGRAMMING',
#  'COMPUTER SCIENCEMAJOR',
#  'COMPUTER SYSTEM ENGINEERING',
#  'COMPUTER SCIENCE',
#  'INFORMATION TECHNOLOGY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'HUMAN RESOURCE',
#  'INFORMATION TECHNOLOGY',
#  'HUMAN RESOURCE',
#  'COMPUTER SCIENCE',
#  'COMPUTER SCIENCE',
#  'INFORMATION SYSTEM',
#  'HOSPITALITY MANAGEMENT',
#  'BANKING FINANCE',
#  'ELECTRICAL ENGINEERING',
#  'MARKETING MANAGEMENT',
#  'PSYCHOLOGY',
#  'ECONOMICS',
#  'COMPUTER ENGINEERING',
#  'BUSINESS ADMINISTRATION',
#  'COMPUTER SCIENCE',
#  'ELEMENTARY EDUCATION',
#  'BUSINESS ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'MARINE TRANSPORTATION',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'TOURISM',
#  'MARKETING MANAGEMENT',
#  'BUSINESS ADMINISTRATION',
#  'MARKETING MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'HOTEL RESTAURANT SERVICE',
#  'INFORMATION TECHNOLOGY',
#  'TOURISM',
#  'BUSINESS ADMINISTRATION ACCOUNTANCY',
#  'ACCOUNTANCY',
#  'NURSING',
#  'COMPUTER SCIENCE',
#  'ACCOUNTANCY',
#  'MARKETING MANAGEMENT',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'NURSING',
#  'INFORMATION DESIGN',
#  'CULINARY ART',
#  'PSYCHOLOGY',
#  'ACCOUNTANCY',
#  'HUMAN RESOURCE',
#  'BUSINESS ADMINISTRATION',
#  'BUSINESS MANAGEMENT',
#  'FINANCIAL MANAGEMENT',
#  'CREATIVE WRITING',
#  'TOURISM',
#  'INDUSTRIAL MANAGEMENT ENGINEERING',
#  'INFORMATION TEHCNOLOGY',
#  'ACCOUNTANCY',
#  'INFORMATION TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'ACCOUNTING',
#  'ACCOUNTING',
#  'BUSINESS ADMINISTRATION',
#  'POLITICAL SCIENCE GLOBAL POLITICS',
#  'BUSINESS MANAGEMENT',
#  'ELECTRONIC ENGINEERING',
#  'MARKETING MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'ACCOUNTANCY',
#  'CIVIL ENGINEERING',
#  'HUMAN RESOURCE',
#  'COMMERCE',
#  'COMMUNICATION RESEARCH',
#  'HUMAN RESOURCE',
#  'BUSINESS ADMINISTRATION',
#  'BUSINESS MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'PSYCHOLOGY',
#  'COMPUTER ENGINEERING',
#  'INFORMATION TECHNOLOGY',
#  'CIVIL ENGINEERING',
#  'CIVIL ENGINEERING',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'BUSINESS ADMINISTRATION',
#  'BUSINESS ADMINISTRATION',
#  'NURSING',
#  'MULTIMEDIA ART',
#  'BUSINESS ADMINISTRATION',
#  'FINANCE',
#  'CRIMINOLOGY',
#  'CRIMINAL JUSTICE',
#  'INFORMATION TECHNOLOGY',
#  'NURSING',
#  'BIOLOGY',
#  'HEALTHCARE SCIENCE',
#  'SECONDARY EDUCATION',
#  'NURSING',
#  'INFORMATION TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'PSYCHOLOGY',
#  'EDUCATION',
#  'ELEMENTARY EDUCATION',
#  'ELEMENTARY EDUCATION',
#  'PRE SCHOOL EDUCATION',
#  'ENGLISH',
#  'AGRIBUSINESS MANAGEMENT',
#  'GEOLOGY',
#  'POLITICAL SCIENCE',
#  'SECONDARY EDUCATION',
#  'BIOLOGY',
#  'COMPUTER SCIENCE',
#  'POLITICAL SCIENCE',
#  'COMPUTER SECRETARIAL',
#  'BIOLOGY',
#  'ACCOUNTANCY',
#  'BUSINESS MANAGEMENT',
#  'HUMAN RESOURCE HR',
#  'APPLIED PHYSIC',
#  'BUSINESS ADMINISTRATION',
#  'BUSINESS MANAGEMENT',
#  'COMPUTER ENGINEERING',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'MARKETING MANAGEMENT',
#  'CRIMINOLOGY',
#  'CRIMINAL JUSTICE',
#  'COMPUTER PROGRAMMING',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'COMPUTER PROGRAMMING',
#  'BANKING FINANCE',
#  'BANKING FINANCE',
#  'COMPUTER ENGINEERING',
#  'HUMAN RESOURCE',
#  'INFORMATION TECHNOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'HUMAN RESOURCE',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'COMPUTER TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'ELEMENTARY EDUCATION',
#  'ECONOMICS',
#  'BUSINESS ADMINISTRATION',
#  'POLITICAL SCIENCE',
#  'CIVIL ENGINEERING',
#  'INFORMATION TECHNOLOGY',
#  'ECONOMICS',
#  'CIVIL ENGINEERING',
#  'FINANCIAL MANAGEMENT',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'PHARMACY',
#  'INFORMATION TECHNOLOGY',
#  'FOOD TECHNOLOGY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'FOODSERVICE MANAGEMENT',
#  'PUBLIC ADMINISTRATION',
#  'OFFICE ADMINISTRATION',
#  'PSYCHOLOGY',
#  'CLINICAL PSYCHOLOGY',
#  'HUMAN RESOURCE',
#  'APPLIED MATHEMATICS',
#  'MATHEMATICAL FINANCE',
#  'ADVERTISING MANAGEMENT',
#  'BUSINESS ADMINISTRATION',
#  'BUSINESS MANAGEMENT',
#  'COMMUNICATION STUDY',
#  'ELEMENTARY EDUCATION',
#  'BUSINESS ADMINISTRATION',
#  'APPLIED PHYSIC',
#  'COMMERCE',
#  'ENTREPRENEURSHIP',
#  'BUSINESS MANAGEMENT',
#  'PSYCHOLOGY',
#  'FINANCIAL MANAGEMENT',
#  'PSYCHOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'MARKETING MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'CUSTOM ADMINISTRATION',
#  'INFORMATION TECHNOLOGY',
#  'ACCOUNTING',
#  'POLITICAL SCIENCE',
#  'MANAGEMENT',
#  'FINANCIAL MANAGEMENT',
#  'PSYCHOLOGY',
#  'COMPUTER SCIENCE',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'FOODSERVICE MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'INFORMATION TECHNOLOGY ENTREPRENEURSHIP',
#  'INDUSTRIAL ENGINEERING',
#  'MARKETING MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'MASS COMMUNICATION',
#  'ELEMENTARY EDUCATION',
#  'SPECIAL EDUCATION SPED',
#  'HUMAN RESOURCE',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'COMPUTER ENGINEERING',
#  'AGRIBUSINESS MANAGEMENT',
#  'AGRIBUSINESS ECONOMICS',
#  'HOTEL RESTAURANT SERVICE',
#  'INFORMATION TECHNOLOGY',
#  'COMPUTER ENGINEERING',
#  'INDUSTRIAL MANAGEMENT ENGINEERING',
#  'INFORMATION TEHCNOLOGY',
#  'ECONOMICS',
#  'TOURISM',
#  'BUSINESS ADMINISTRATION',
#  'BROADCAST COMMUNICATION',
#  'HOTEL RESTAURANT SERVICE',
#  'LEGAL MANAGEMENT',
#  'EDUCATION',
#  'COMPUTER SCIENCE',
#  'COMMERCE',
#  'MANAGEMENT',
#  'MARKETING',
#  'COMPUTER TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'PHARMACY',
#  'SECONDARY EDUCATION',
#  'COMPUTER TECHNOLOGY',
#  'INFORMATION TECHNOLOGY',
#  'HOTEL RESTAURANT INSTITUTION MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'BUSINESS MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'BANKING FINANCE',
#  'INFORMATION TECHNOLOGY',
#  'SECONDARY EDUCATION',
#  'COMPUTER PROGRAMMING',
#  'MATHEMATICS',
#  'HUMAN RESOURCE',
#  'COMPUTER ENGINEERING',
#  'BUSINESS ADMINISTRATION ACCOUNTANCY',
#  'HUMAN RESOURCE HR',
#  'INFORMATION TECHNOLOGY',
#  'ACCOUNTANCY',
#  'PHARMACY',
#  'BANKING FINANCE',
#  'BUSINESS MANAGEMENT',
#  'ACCOUNTING',
#  'BUSINESS ADMINISTRATION ACCOUNTANCY',
#  'ACCOUNTANCY',
#  'INFORMATION TECHNOLOGY',
#  'TOURISM',
#  'SECONDARY EDUCATION',
#  'BUSINESS ADMINISTRATION ACCOUNTANCY',
#  'BUSINESS ADMINISTRATION',
#  'BUSINESS ECONOMICS',
#  'HOTEL RESTAURANT SERVICE',
#  'ART MANAGEMENT',
#  'FINANCIAL MANAGEMENT',
#  'BANKING FINANCE',
#  'MECHANICAL ENGINEERING',
#  'ACCOUNTING',
#  'COMMUNITY DEVELOPMENT',
#  'ACCOUNTANCY',
#  'INFORMATION TECHNOLOGY',
#  'COMMERCE',
#  'ENTREPRENEURSHIP',
#  'CHEMICAL ENGINEERING',
#  'MIDWIFERY OBSTETRICS',
#  'BUSINESS ADMINISTRATION',
#  'MANAGEMENT',
#  'ADVERTISING',
#  'COMMUNICATION ART',
#  'MASS COMMUNICATION',
#  'COMPUTER TECHNOLOGY',
#  'NURSING',
#  'APPLIED PHYSIC',
#  'APPLIED COMPUTER SYSTEM',
#  'MATHEMATICS',
#  'MARKETING MANAGEMENT',
#  'BANKING FINANCE',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'CRIMINOLOGY',
#  'CRIMINAL JUSTICE',
#  'APPLIED PSYCHOLOGY',
#  'BUSINESS ADMINISTRATION ACCOUNTANCY',
#  'BANKING FINANCE',
#  'BUSINESS ADMINISTRATION',
#  'BUSINESS ADMINISTRATION',
#  'FINANCIAL MANAGEMENT',
#  'ART STUDY',
#  'ENGLISH',
#  'PUBLIC ADMINISTRATION',
#  'COMPUTER ENGINEERING',
#  'BUSINESS ADMINISTRATION',
#  'PUBLIC ADMINISTRATION',
#  'ECONOMICS',
#  'FINANCIAL MANAGEMENT',
#  'INFORMATION TECHNOLOGY',
#  'BUSINESS ADMINISTRATION',
#  'COMPUTER PROGRAMMING',
#  'NURSING',
#  'INFORMATION TECHNOLOGY',
#  'LEGAL MANAGEMENT',
#  'COMPUTER SCIENCE',
#  'COMPUTER TECHNOLOGY',
#  'COMMERCE',
#  'ENTREPRENEURSHIP',
#  'HUMAN RESOURCE',
#  'APPLIED SOCIOLOGY',
#  'HUMAN RESOURCE',
#  'ACCOUNTING',
#  'FINANCIAL MANAGEMENT',
#  'BUSINESS ADMINISTRATION',
#  'HISTORY',
#  'EDUCATION',
#  'FINANCIAL MANAGEMENT',
#  'COMPUTER SCIENCE',
#  'INFORMATION SYSTEM',
#  'PSYCHOLOGY',
#  'BUSINESS INFORMATION MANAGEMENT',
#  'ACCOUNTANCY',
#  'AGRIBUSINESS MANAGEMENT',
#  'BUSINESS MANAGEMENT',
#  'MARINE ENGINEERING',
#  'MANAGEMENT ENGINEERING',
#  'AGRICULTURE',
#  'PHYSICAL THERAPY',
#  'COMPUTER SECRETARIAL',
#  'COMPUTER SCIENCE',
#  'COMPUTER ENGINEERING',
#  'BUSINESS MANAGEMENT',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'BUSINESS MANAGEMENT',
#  'CHEMICAL ENGINEERING',
#  'ACCOUNTANCY',
#  'PSYCHOLOGY',
#  'ENTREPRENEURSHIP',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'MULTIMEDIA ART',
#  'INFORMATION TECHNOLOGY',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'INTERDISCIPLINARY STUDY',
#  'INFORMATION TECHNOLOGY',
#  'GEOGRAPHY',
#  'BANKING FINANCE',
#  'APPLIED PSYCHOLOGY',
#  'BUSINESS ECONOMICS',
#  'COMPUTER ENGINEERING',
#  'ART STUDY',
#  'CIVIL ENGINEERING',
#  'COMPUTER SCIENCE',
#  'MUSIC',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'BANKING FINANCE',
#  'ELECTRICAL ENGINEERING',
#  'POLITICAL SCIENCE',
#  'INDUSTRIAL ENGINEERING IE',
#  'MARKETING',
#  'INFORMATION TECHNOLOGY',
#  'COMPUTER SCIENCE',
#  'MARKETING MANAGEMENT',
#  'BANKING FINANCE',
#  'AGRIBUSINESS MANAGEMENT',
#  'BANKING FINANCE',
#  'FOODSERVICE MANAGEMENT',
#  'HOTEL RESTAURANT MANAGEMENT',
#  'TOURISM',
#  'BANKING FINANCE',
#  'FINANCE',
#  'CRIMINOLOGY',
#  'CRIMINAL JUSTICE',
#  'ELECTRONICS COMMUNICATION ENGINEERING',
#  'ENGLISH',
#  'COMMUNICATION TECHNOLOGY MANAGEMENT',
#  'BUSINESS ADMINISTRATION',
#  'MARKETING',
#  'SECONDARY EDUCATION',
#  'POLITICAL SCIENCE',
#  'EDUCATION',
#  'INFORMATION TECHNOLOGY',
#  'COMPUTER ENGINEERING',
#  'SOCIAL WORK',
#  'NURSING',
#  'HOTEL RESTAURANT INSTITUTION MANAGEMENT',
#  'ACCOUNTING',
#  'MARKETING MANAGEMENT',
#  'INDUSTRIAL ENGINEERING',
#  'ARCHITECTURE',
#  'BUSINESS MANAGEMENT',
#  'MATHEMATICS',
#  'COMPUTER SECRETARIAL',
#  'BANKING FINANCE',
#  'COMPUTER ENGINEERING',
#  'HOTEL RESTAURANT INSTITUTION MANAGEMENT',
#  'INDUSTRIAL MANAGEMENT ENGINEERING',
#  'SERVICE MANAGEMENT',
#  'NURSING',
#  'ACCOUNTING',
#  'INFORMATION TECHNOLOGY',
#  'ACCOUNTING',
#  'BUSINESS ADMINISTRATION ACCOUNTANCY',
#  ...]

# %%
from collections import defaultdict
mapper = defaultdict(int)
for course in courses:
    if (len(course) > 0):
        mapper[course] += 1

# %%
sorted(mapper.items(), key=lambda pair: pair[1], reverse=True)
# Out:
# [('INFORMATION TECHNOLOGY', 4151),
#  ('BUSINESS ADMINISTRATION', 3021),
#  ('COMPUTER SCIENCE', 1928),
#  ('HOTEL RESTAURANT MANAGEMENT', 1755),
#  ('NURSING', 1538),
#  ('PSYCHOLOGY', 838),
#  ('ACCOUNTANCY', 824),
#  ('MASS COMMUNICATION', 768),
#  ('SECONDARY EDUCATION', 749),
#  ('MARKETING MANAGEMENT', 691),
#  ('BUSINESS MANAGEMENT', 668),
#  ('COMPUTER ENGINEERING', 666),
#  ('ELEMENTARY EDUCATION', 631),
#  ('EDUCATION', 531),
#  ('MECHANICAL ENGINEERING', 483),
#  ('COMMUNICATION ART', 464),
#  ('TOURISM', 459),
#  ('ELECTRICAL ENGINEERING', 399),
#  ('MARKETING', 393),
#  ('ACCOUNTING', 371),
#  ('ELECTRONICS COMMUNICATION ENGINEERING', 370),
#  ('CIVIL ENGINEERING', 366),
#  ('FINANCIAL MANAGEMENT', 346),
#  ('COMPUTER PROGRAMMING', 335),
#  ('COMPUTER TECHNOLOGY', 319),
#  ('BANKING FINANCE', 316),
#  ('COMMERCE', 315),
#  ('HOSPITALITY MANAGEMENT', 310),
#  ('OFFICE ADMINISTRATION', 308),
#  ('POLITICAL SCIENCE', 307),
#  ('CRIMINOLOGY', 303),
#  ('HUMAN RESOURCE', 295),
#  ('ENTREPRENEURSHIP', 283),
#  ('HOTEL RESTAURANT SERVICE', 279),
#  ('COMPUTER SECRETARIAL', 259),
#  ('CRIMINAL JUSTICE', 256),
#  ('BIOLOGY', 254),
#  ('MANAGEMENT ACCOUNTING', 244),
#  ('ELECTRONIC ENGINEERING', 223),
#  ('MANAGEMENT', 223),
#  ('ENGLISH', 204),
#  ('MARINE TRANSPORTATION', 200),
#  ('INDUSTRIAL ENGINEERING', 189),
#  ('ARCHITECTURE', 186),
#  ('MATHEMATICS', 165),
#  ('CHEMICAL ENGINEERING', 156),
#  ('COMPUTER HARDWARE SERVICING', 151),
#  ('MULTIMEDIA ART', 149),
#  ('COMPUTER TECHNICIAN', 147),
#  ('ECONOMICS', 147),
#  ('BUSINESS ADMINISTRATION ACCOUNTANCY', 140),
#  ('FOOD TECHNOLOGY', 131),
#  ('FOODSERVICE MANAGEMENT', 130),
#  ('INFORMATION SYSTEM', 129),
#  ('PUBLIC ADMINISTRATION', 124),
#  ('MARINE ENGINEERING', 118),
#  ('AGRICULTURE', 112),
#  ('BUSINESS', 110),
#  ('PHILOSOPHY', 104),
#  ('JOURNALISM', 102),
#  ('INDUSTRIAL MANAGEMENT ENGINEERING', 99),
#  ('ACCOUNTING SCHOLARSHIP', 99),
#  ('MEDICAL TECHNOLOGY', 97),
#  ('INFORMATION TEHCNOLOGY', 95),
#  ('TOURISM MANAGEMENT', 94),
#  ('CUSTOM ADMINISTRATION', 93),
#  ('LEGAL MANAGEMENT', 92),
#  ('CHEMISTRY', 92),
#  ('PHYSICAL THERAPY', 92),
#  ('BUSINESS INFORMATION MANAGEMENT', 91),
#  ('BUSINESS ECONOMICS', 91),
#  ('FINE ART', 87),
#  ('NURSING EDUCATION', 84),
#  ('ADVERTISING', 84),
#  ('CULINARY ART', 82),
#  ('MIDWIFERY OBSTETRICS', 82),
#  ('FINANCE', 79),
#  ('INDUSTRIAL TECHNOLOGY', 79),
#  ('AUTOMOTIVE ENGINEERING', 77),
#  ('SOCIAL SCIENCE', 77),
#  ('COMMUNICATION TECHNOLOGY MANAGEMENT', 75),
#  ('AGRIBUSINESS MANAGEMENT', 75),
#  ('INTERNATIONAL STUDY', 75),
#  ('BROADCAST COMMUNICATION', 71),
#  ('PHARMACY', 70),
#  ('INDUSTRIAL ENGINEERING IE', 70),
#  ('APPLIED MATHEMATICS', 68),
#  ('APPLIED PSYCHOLOGY', 68),
#  ('ALTERNATIVE EDUCATION', 68),
#  ('DEVELOPMENT COMMUNICATION', 66),
#  ('COMMUNICATION STUDY', 64),
#  ('COMPUTER SCIENCEWITH', 61),
#  ('GRAPHIC DESIGN', 59),
#  ('CLINICAL PSYCHOLOGY', 58),
#  ('MANAGEMENT ENGINEERING', 57),
#  ('INDUSTRIAL PSYCHOLOGY', 54),
#  ('COMPUTER COMMUNICATION NETWORK', 54),
#  ('STATISTIC', 53),
#  ('INTERNATIONAL RELATION', 52),
#  ('ART EDUCATION', 51),
#  ('APPLIED PHYSIC', 51),
#  ('GENERAL STUDY', 51),
#  ('INFORMATION MANAGEMENT', 51),
#  ('HUMAN RESOURCE HR', 49),
#  ('HISTORY', 49),
#  ('COMMUNICATION', 49),
#  ('MANAGEMENT INFORMATION SYSTEM', 48),
#  ('SOFTWARE TECHNOLOGY', 48),
#  ('PRE SCHOOL EDUCATION', 46),
#  ('HEALTHCARE SCIENCE', 46),
#  ('SOCIOLOGY', 46),
#  ('TOURISM GEOGRAPHY', 46),
#  ('NUTRITION DIETETICS', 45),
#  ('ANIMATION', 45),
#  ('SOCIAL WORK', 45),
#  ('INFORMATION COMMUNICATION TECHNOLOGY', 45),
#  ('ENVIRONMENTAL SCIENCE', 44),
#  ('LITERATURE ENGLISH', 44),
#  ('ENGLISH LITERATURE', 43),
#  ('GENERAL EDUCATION', 42),
#  ('ADVERTISING MANAGEMENT', 42),
#  ('MANAGEMENT ECONOMICS', 39),
#  ('OFFICE MANAGEMENT', 39),
#  ('JOURNALISM MEDIUM STUDY COMMUNICATION', 38),
#  ('FOOD BEV SERVICE', 38),
#  ('SCIENCE', 38),
#  ('LABORATORY MEDICINE', 37),
#  ('CLINICAL LABORATORY SCIENCE', 37),
#  ('CLINICAL PATHOLOGY', 37),
#  ('SPECIAL EDUCATION SPED', 36),
#  ('HUMAN RESOURCE MANAGEMENT', 35),
#  ('HUMAN RESOURCE DEVELOPMENT MANAGEMENT', 35),
#  ('BEHAVIORAL SCIENCE', 35),
#  ('INTERDISCIPLINARY STUDY', 34),
#  ('ELECTRO MECHANICAL TECHNOLOGY', 34),
#  ('HOTEL RESTAURANT INSTITUTION MANAGEMENT', 34),
#  ('DENTISTRY', 33),
#  ('INFORMATION DESIGN', 32),
#  ('APPLIED CORPORATE MANAGEMENT', 32),
#  ('ACCOUNTING TECHNOLOGY', 32),
#  ('CREATIVE WRITING', 30),
#  ('BILINGUAL EDUCATION', 30),
#  ('COMPUTER SYSTEM DESIGN PROGRAMMING', 29),
#  ('PHYSICAL EDUCATION', 29),
#  ('AGRICULTURAL ENGINEERING', 28),
#  ('CAREGIVING', 28),
#  ('ELECTRICAL INSTALLATION MAINTENANCE', 28),
#  ('COMPUTER GRAPHIC', 26),
#  ('PROGRAMMING', 26),
#  ('MUSIC', 25),
#  ('ASIAN STUDY', 25),
#  ('BUSINESS ADMINISTRATION MANAGEMENT', 25),
#  ('INDUSTRIAL DESIGN', 24),
#  ('APPLIED COMPUTER SYSTEM', 24),
#  ('ARCHITECTURE DESIGN', 24),
#  ('LIBRARY INFORMATION SCIENCE', 24),
#  ('CONSUMER ELECTRONICS SERVICING', 24),
#  ('HOSPITALITY RESTAURANT SERVICE', 23),
#  ('INFORMATION SYSTEM BUSINESS INFORMATICS', 23),
#  ('DEVELOPMENT STUDY', 23),
#  ('WELDING SMAW', 22),
#  ('EUROPEAN STUDY', 22),
#  ('POLITICAL SCIENCE GLOBAL POLITICS', 22),
#  ('LAW', 22),
#  ('STANDARD ENGLISH', 21),
#  ('TEACHING', 21),
#  ('INTERIOR DESIGN', 21),
#  ('SPECIAL EDUCATION', 21),
#  ('ELECTRONICS', 21),
#  ('SPEECH COMMUNICATION', 21),
#  ('AGRICULTURAL EDUCATION', 21),
#  ('AUTOMOTIVE SERVICING', 21),
#  ('TECHNOLOGY', 21),
#  ('ORGANIZATIONAL COMMUNICATION', 21),
#  ('AGRICULTURAL ECONOMICS', 21),
#  ('FORESTRY', 20),
#  ('INTERNAL AUDITING', 20),
#  ('ENTREPRENEURIAL MANAGEMENT', 20),
#  ('APPLIED ECONOMICS', 20),
#  ('NONE', 20),
#  ('ABNORMAL PSYCHOLOGY', 20),
#  ('DIPLOMACY INTERNATIONAL RELATION', 19),
#  ('APPLIED SOCIOLOGY', 19),
#  ('COMPUTER', 19),
#  ('PARALEGAL STUDY', 19),
#  ('MATHEMATICS SCIENCE TEACHING', 19),
#  ('EAST SOUTHEAST ASIAN STUDY', 19),
#  ('COMMERCIAL COOKING', 19),
#  ('LINGUISTICS', 18),
#  ('HEALTH CARE SERVICE', 18),
#  ('CULINARY', 18),
#  ('ELECTRONICS ENGINEERING', 18),
#  ('PHOTOGRAPHY', 18),
#  ('COMMUNITY DEVELOPMENT', 18),
#  ('PRACTICAL NURSING', 17),
#  ('HOME ECONOMICS', 17),
#  ('N', 17),
#  ('MULTIMEDIA HYPERMEDIA', 17),
#  ('FILIPINO', 17),
#  ('PHYSIC', 17),
#  ('COMPUTER ELECTRONICS TECHNOLOGY', 17),
#  ('ART STUDY', 16),
#  ('GEOLOGY', 16),
#  ('OPERATION MANAGEMENT', 16),
#  ('FOREIGN SERVICE', 16),
#  ('GENERAL PRACTICE', 16),
#  ('GENERAL', 16),
#  ('INTERNATIONAL HOSPITALITY MANAGEMENT', 16),
#  ('MIDWIFERY', 15),
#  ('BUSINESS SCIENCE', 15),
#  ('ELECTRICAL TECHNOLOGY', 15),
#  ('MECHANICAL TECHNOLOGY', 15),
#  ('RADIOLOGIC TECHNOLOGY', 15),
#  ('GENERAL PSYCHOLOGY', 14),
#  ('COMPUTER APPLICATION', 14),
#  ('FILM', 14),
#  ('SECRETARIAL', 14),
#  ('DEVELOPMENT ECONOMICS', 14),
#  ('BATCHELOR', 14),
#  ('VISUAL COMMUNICATION', 14),
#  ('COMPUTER MANAGEMENT', 14),
#  ('MATHEMATICAL FINANCE', 13),
#  ('INFORMATION TECHNOLOGY ENTREPRENEURSHIP', 13),
#  ('INDUSTRIAL EDUCATION', 13),
#  ('COMPUTER SCIENCEMAJOR', 13),
#  ('PRIMARY EDUCATION', 13),
#  ('AUTOMOTIVE MECHANICAL ASSEMBLY', 13),
#  ('THEOLOGY', 13),
#  ('MATHEMATICS EDUCATION', 13),
#  ('COMPUTING', 13),
#  ('COMPUTER SYSTEM ENGINEERING', 13),
#  ('MATERIAL SCIENCE ENGINEERING', 13),
#  ('GEODETIC ENGINEERING', 13),
#  ('TRAVEL MANAGEMENT', 12),
#  ('HUMANITY', 12),
#  ('SOCIAL SCIENCE ART HUMANITY PROFESSION', 12),
#  ('MATERIAL ENGINEERING', 12),
#  ('HOUSEKEEPING', 12),
#  ('BUSINESS ADMINISTRATION MARKETING', 12),
#  ('LITERATURE', 12),
#  ('COMMUNICATION RESEARCH', 12),
#  ('HOTEL RESTAURANT TOURISM MANAGEMENT', 12),
#  ('COMPUTER STUDY', 12),
#  ('BIOCHEMISTRY', 12),
#  ('A', 11),
#  ('BUSINESS ADMINISTRATION FINANCIAL MANAGEMENT', 11),
#  ('VETERINARY MEDICINE', 11),
#  ('ACCOUNTING MANAGEMENT', 11),
#  ('COSMETOLOGY', 11),
#  ('NUTRITIONAND DIETETICS', 11),
#  ('FINANCIAL MANAGEMENT ACCOUNTING', 11),
#  ('LIBERAL ART', 11),
#  ('CAREGIVER', 10),
#  ('BUSINESS ADMINISTRATION MARKETING MANAGEMENT', 10),
#  ('PUBLIC RELATION', 10),
#  ('SOFTWARE DEVELOPMENT', 10),
#  ('MOLECULAR BIOLOGY BIOTECHNOLOGY', 10),
#  ('THEATRE', 10),
#  ('AIRCRAFT MAINTENANCE TECHNOLOGY', 10),
#  ('AGRIBUSINESS', 10),
#  ('ART MANAGEMENT', 10),
#  ('DATA MANAGEMENT', 10),
#  ('BIOLOGICAL SCIENCE', 10),
#  ('BROADCAST JOURNALISM', 10),
#  ('GENERAL SCIENCE', 10),
#  ('EDUCATIONAL PSYCHOLOGY', 10),
#  ('BROADCASTING', 9),
#  ('THEATER ART', 9),
#  ('SOFTWARE ENGINEERING', 9),
#  ('POLITICAL ECONOMY', 9),
#  ('ENGLISH LANGUAGE', 9),
#  ('EARLY CHILDHOOD EDUCATION', 9),
#  ('FOOD SCIENCE', 9),
#  ('PHILIPPINE STUDY', 9),
#  ('APPLIED CHEMISTRY', 9),
#  ('INTERNATIONAL TRAVEL TOURISM MANAGEMENT', 9),
#  ('AGRICULTURAL BIOTECHNOLOGY', 9),
#  ('AUTOMOTIVE', 9),
#  ('COMPUTER EDUCATION', 9),
#  ('AUTOMOTIVE TECHNOLOGY', 9),
#  ('INDUSTRIAL DESIGN PRODUCT', 9),
#  ('EDUCATION ENGLISH', 9),
#  ('CONSUMER ECONOMICS', 9),
#  ('SOCIAL STUDY', 9),
#  ('HOTEL RESTAURANT', 9),
#  ('HEALTH SCIENCE', 9),
#  ('COMMERCIAL SCIENCE', 9),
#  ('FOOD SERVICE MANAGEMENT', 9),
#  ('BEED', 9),
#  ('PUBLIC HEALTH', 9),
#  ('FOOD BEVERAGE', 9),
#  ('ENGLISH PROFICIENCY', 9),
#  ('DENTAL MEDICINE', 8),
#  ('TECHNICAL DRAFTING', 8),
#  ('HOTEL SERVICE', 8),
#  ('COMMUNITY PSYCHOLOGY', 8),
#  ('ARCHITECTURAL DRAFTING', 8),
#  ('NUTRITION', 8),
#  ('BUSINESS LAW', 8),
#  ('INFORMATION', 8),
#  ('MT', 8),
#  ('ELECTRONIC COMMUNICATION ENGINEERING', 8),
#  ('ANTHROPOLOGY', 8),
#  ('POLITICAL SCIENCE PUBLIC MANAGEMENT', 8),
#  ('TEACHER', 8),
#  ('AVIATION', 8),
#  ('FINISHING', 8),
#  ('SPORT COACHING', 8),
#  ('ENVIRONMENTAL STUDY FORESTRY', 8),
#  ('GEOGRAPHY', 8),
#  ('ECONOMICS HONOR', 8),
#  ('CONSULAR DIPLOMATIC AFFAIR', 8),
#  ('COMPUTER SYSTEM NETWORK TECHNOLOGY', 8),
#  ('BUSINESS ADMINISTRATION HUMAN RESOURCE DEVELOPMENT MANAGEMENT', 8),
#  ('AESTHETIC', 8),
#  ('HOTEL RESTAURANT ADMINISTRATION', 8),
#  ('MINING ENGINEERING', 8),
#  ('OCCUPATIONAL THERAPY', 8),
#  ('APPLIED LINGUISTICS', 8),
#  ('COMPUTER ENGINEERING TECHNOLOGY', 8),
#  ('NETWORK ENGINEERING', 8),
#  ('ELECTRICAL', 8),
#  ('ELECTRICAL COMPUTER ENGINEERING', 8),
#  ('MUSIC EDUCATION', 8),
#  ('EUROPEAN LANGUAGE', 8),
#  ('FINANCIAL INSTITUTION', 8),
#  ('COMPUTER SCIENCE INFORMATION TECHNOLOGY', 7),
#  ('ENGINEERING', 7),
#  ('AGRIBUSINESS ECONOMICS', 7),
#  ('CRUISE LINE OPERATION', 7),
#  ('MECHANICAL ENGINEER', 7),
#  ('AGRICULTURAL BIOSYSTEMS ENGINEERING', 7),
#  ('VISUAL GRAPHIC DESIGN', 7),
#  ('AEROSPACE ENGINEERING', 7),
#  ('PHYSIOTHERAPY', 7),
#  ('LOGIC', 7),
#  ('E', 7),
#  ('EXPORT MANAGEMENT', 7),
#  ('COMPUTER HARDWARE', 7),
#  ('DIGITAL ART', 7),
#  ('SECONDARY EDUCATION ENGLISH', 7),
#  ('BARTENDING', 7),
#  ('CALLCENTER MANAGEMENT', 7),
#  ('HOSPITALITY INDUSTRY', 7),
#  ('INSTRUMENTATION', 7),
#  ('COMPUTER BASED ACCOUNTANCY', 6),
#  ('LANGUAGE LITERATURE', 6),
#  ('FINANCIAL ACCOUNTING', 6),
#  ('BUSINESS INFORMATION TECHNOLOGY', 6),
#  ('EXERCISE SCIENCE', 6),
#  ('ACTUARIAL SCIENCE', 6),
#  ('HRS', 6),
#  ('ELECTRONICS TECHNOLOGY', 6),
#  ('DRAFTING TECHNOLOGY', 6),
#  ('ELECTRONICS COMPUTER TECHNOLOGY', 6),
#  ('ADVERTISING PUBLIC RELATION', 6),
#  ('HOSPITALITY INDUSTRY MANAGEMENT', 6),
#  ('HOTEL RESTAURANT TECHNOLOGY', 6),
#  ('HOSPITALITY', 6),
#  ('FASHION DESIGN', 6),
#  ('CHEMISTRY EDUCATION', 6),
#  ('ADMINISTRATION', 6),
#  ('MECHANICAL ENGINEERING TECHNOLOGY', 6),
#  ('ELECTRICAL ENGINEERING TECHNOLOGY', 6),
#  ('INTERNATIONAL BUSINESS', 6),
#  ('OBJECT ORIENTED PROGRAMMING', 6),
#  ('MICROBIOLOGY', 6),
#  ('MASS MEDIUM', 6),
#  ('HUMAN ECOLOGY', 6),
#  ('NURSING AIDE', 6),
#  ('COMMERCE ACCOUNTING', 6),
#  ('INFORMATION TECHNOLOGY ENTREPRENEURSHIP ITE', 6),
#  ('SPORT SCIENCE', 6),
#  ('ADVERTISING ART', 6),
#  ('ANIMAL HUSBANDRY SCIENCE', 6),
#  ('HOSPITALITY TOURISM MANAGEMENT', 6),
#  ('COMPUTER SECRETARY', 6),
#  ('NURSING ASSISTANT', 5),
#  ('LANGUAGE EDUCATION', 5),
#  ('FISHERY', 5),
#  ('BIOLOGICAL PSYCHOLOGY', 5),
#  ('INSTRUCTIONAL SYSTEM TECHNOLOGY', 5),
#  ('CRUISE SHIP MANAGEMENT', 5),
#  ('BUSINESS ADMINISTRATION BANKING FINANCE', 5),
#  ('BASIC COMPUTER OPERATION', 5),
#  ('HM', 5),
#  ('OPTOMETRY', 5),
#  ('COMPUTER LITERATE', 5),
#  ('TECHNICAL TEACHER EDUCATION', 5),
#  ('KINESIOLOGY', 5),
#  ('COMMUNICATIONS TECHNOLOGY', 5),
#  ('INFOMATION TECHNOLOGY', 5),
#  ('MULTIMEDIA ART SCIENCE', 5),
#  ('ELECTRONICS ENGINEERING TECHNOLOGY', 5),
#  ('AGRICULTURAL TECHNOLOGY', 5),
#  ('PROFESSIONAL EDUCATION', 5),
#  ('MASSAGE THERAPY', 5),
#  ('PETROLEUM ENGINEERING', 5),
#  ('COMMUNICATION TECHNOLOGY', 5),
#  ('BUSINESS ENGLISH', 5),
#  ('HOTEL MANAGEMENT', 5),
#  ('BUSINESS EDUCATION', 5),
#  ('ENGLISH LANGUAGE LITERATURE', 5),
#  ('HUMAN PERFORMANCE', 5),
#  ('EDUCATIONAL MANAGEMENT', 5),
#  ('MANAGEMENT ACCOUNTANCY', 5),
#  ('HOTEL RESORT RESTAURANT MANAGEMENT', 5),
#  ('LIFE SCIENCE', 5),
#  ('SEAFARER RATING', 5),
#  ('MARINE BIOLOGY', 5),
#  ('COGNITIVE PSYCHOLOGY', 5),
#  ('ENGINEERING MANAGEMENT', 5),
#  ('SCIENCE EDUCATION', 5),
#  ('NETWORKING TELECOMMUNICATION TECHNOLOGY', 5),
#  ('BUSINESS TEACHER EDUCATION', 5),
#  ('COMPUTER PROGRAMMER', 5),
#  ('MEDICAL EDUCATION', 5),
#  ('INDUSTRIAL FACILITY TECHNOLOGY', 4),
#  ('SEAMAN', 4),
#  ('CONTACT CENTER SERVICE', 4),
#  ('COMPARATIVE SOCIOLOGY', 4),
#  ('COMPARATIVE LITERATURE', 4),
#  ('CONSTITUTIONAL LAW', 4),
#  ('HOTEL TOURISM MANAGEMENT', 4),
#  ('VISUAL ART', 4),
#  ('INFORMATION TECHNOLOGY BSIT', 4),
#  ('INTEGRATED MARKETING COMMUNICATION', 4),
#  ('ENGLISH LANGUAGE PROFICIENCY', 4),
#  ('COMMUNICATION SERVICE MANAGEMENT', 4),
#  ('RESPIRATORY THERAPY', 4),
#  ('TOURISM HOSPITALITY MANAGEMENT', 4),
#  ('MACHINING', 4),
#  ('INFORMATION TECHNOLOGY PROGRAM', 4),
#  ('FAMILY CONSUMER SCIENCE', 4),
#  ('AERONAUTICAL ENGINEERING', 4),
#  ('MEDICAL', 4),
#  ('HOSPITALITY RESTAURANT MANAGEMENT', 4),
#  ('FILMMAKING', 4),
#  ('COMPUTER ARCHITECTURE', 4),
#  ('AGRICULTURAL CHEMISTRY', 4),
#  ('FAMILY LIFE CHILD DEVELOPMENT', 4),
#  ('SCINCE', 4),
#  ('DEVELOPMENT MANAGEMENT', 4),
#  ('HOTEL RESTAURANT MANANGEMENT', 4),
#  ('YES', 4),
#  ('TELECOMMUNICATION ENGINEERING', 4),
#  ('NAUTICAL', 4),
#  ('INDUSTRIAL ORGANIZATIONAL PSYCHOLOGY', 4),
#  ('ARCHITECTURAL ENGINEERING', 4),
#  ('COUNSELOR EDUCATION', 4),
#  ('LITERATURE FILIPINO PANITIKAN', 4),
#  ('ELECTRONICS COMMUNICATION TECHNOLOGY', 4),
#  ('INFORMATION COMMUNICATION MANAGEMENT TECHNOLOGY', 4),
#  ('BUSINESS ADMINISTRATION HUMAN RESOURCE MANAGEMENT', 4),
#  ('LEGAL EDUCATION', 4),
#  ('DRAFTING', 4),
#  ('NUTRITION FOOD TECHNOLOGY', 4),
#  ('CIVIL LAW', 4),
#  ('ENVIRONMENTAL MANAGEMENT', 4),
#  ('BOOKKEEPING', 4),
#  ('ELECTRONICS COMMUNICATION', 4),
#  ('TRAVEL TOURISM', 4),
#  ('AIRLINE OPERATION', 4),
#  ('BIOLOGY CHEMISTRY', 4),
#  ('COMPUTER LITERACY', 4),
#  ('INTERNET WORLD WIDE WEB', 4),
#  ('BIOMECHANICAL ENGINEERING', 4),
#  ('HOTEL RESTURANT MANAGEMENT', 4),
#  ('OPERATION', 4),
#  ('COMPUTER PROGRAMING', 4),
#  ('CHRISTIAN EDUCATION', 4),
#  ('MAPEH', 4),
#  ('PHYSICAL SCIENCE', 4),
#  ('SECONDARY', 4),
#  ('METALLURGICAL ENGINEERING', 4),
#  ('CUSTOMER SERVICE', 4),
#  ('FRONT OFFICE', 4),
#  ('BEHAVIORAL MEDICINE', 4),
#  ('STEWARDING', 4),
#  ('SOCIAL ANTHROPOLOGY', 4),
#  ('COMPUTER ENGINEERING MANAGEMENT TECHNOLOGY', 4),
#  ('ADVANCE', 4),
#  ('MARITIME TRANSPORTATION', 4),
#  ('FILIPINO AT PANITIKAN NG PILIPINAS', 4),
#  ('ELECTRONICS COMMUNICATION ENGINEERING TECHNOLOGY', 3),
#  ('ASSOSIATE', 3),
#  ('INFORMATIC', 3),
#  ('HEALTH SCIENCE EDUCATION', 3),
#  ('OFFICE INFORMATION SYSTEM', 3),
#  ('BAKING PASTRY', 3),
#  ('EXERCISE PHYSIOLOGY', 3),
#  ('INTERDISCIPLINARY BUSINESS STUDY', 3),
#  ('CRUISELINE OPERATION', 3),
#  ('ENGLISH EDUCATION', 3),
#  ('BUSINESS STUDY', 3),
#  ('ELECTRICAL ENGINEER', 3),
#  ('INFORMATION TECNOLOGY', 3),
#  ('OR ART', 3),
#  ('CAM OPERATION', 3),
#  ('BUSINESS ACCOUNTANCY', 3),
#  ('NATURAL SCIENCE', 3),
#  ('HOTEL RESTAURANT MANAGMENT', 3),
#  ('MEDICAL LABORATORY SCIENCE', 3),
#  ('FOR CALLCENTER AGENT', 3),
#  ('HOTEL RESTAURANT MANGEMENT', 3),
#  ('MANAGEMENT MARKETING', 3),
#  ('MECHANICAL ENGINEERING BSME', 3),
#  ('EARLY CHILDHOOD', 3),
#  ('ABRAHAMIC RELIGION', 3),
#  ('HOTEL RESTAURANT MANAGEMNET', 3),
#  ('AGRONOMY', 3),
#  ('DIPLOMACY', 3),
#  ('ACCOUNTANT', 3),
#  ('COOPERATIVE LEARNING', 3),
#  ('DATABASE', 3),
#  ('WELDING GMAW', 3),
#  ('BUSINESS MANAGEMENT ACCOUNTING', 3),
#  ('ELECTRONIC ENGINEERING TECHNOLOGY', 3),
#  ('CUSTOMER SERVICE COMMUNICATION', 3),
#  ('MARKETING ADVERTISING MANAGEMENT', 3),
#  ('TOURISM HOTEL RESTAURANT MANAGEMENT', 3),
#  ('FRENCH LITERATURE', 3),
#  ('PRACTICAL ELECTRICITY', 3),
#  ('OJT', 3),
#  ('DISTANCE EDUCATION', 3),
#  ('INTERNATIONAL TRADE', 3),
#  ('COMMUNICATIONS ART', 3),
#  ('BUSINESS OFFICE INFORMATION SERVICE', 3),
#  ('MULTIMEDIA', 3),
#  ('TEACHER EDUCATION', 3),
#  ('BUILDING TECHNOLOGY MANAGEMENT', 3),
#  ('ENVIRONMENTAL SANITARY ENGINEERING', 3),
#  ('AIRCRAFT MAINTENANCE', 3),
#  ('COMMERCE ACCOUNTANCY', 3),
#  ('OFFICE SYSTEM TECHNOLOGY', 3),
#  ('BUSINESS OFFICE ADMINISTRATION SERVICE', 3),
#  ('IE', 3),
#  ('COMPUTER OPERATION', 3),
#  ('AGRICULTURAL BUSINESS', 3),
#  ('ACCOMPANYING', 3),
#  ('CULINARY TEXTILE ART', 3),
#  ('ELECTRICIAN', 3),
#  ('LIBRARY SCIENCE', 3),
#  ('LOGISTICS', 3),
#  ('BACHERLOR', 3),
#  ('WEB APPLICATION DEVELOPMENT', 3),
#  ('INDUSTRIAL ORGANIZATION', 3),
#  ('CAD', 3),
#  ('STUDY', 3),
#  ('PASTORAL THEOLOGY', 3),
#  ('BUSINESS ADMINISTRATION ACCOUNTING', 3),
#  ('INFORMATION SCIENCE', 3),
#  ('EE', 3),
#  ('FISHERY TECHNOLOGY', 3),
#  ('ACTING', 3),
#  ('CRITICAL MANAGEMENT STUDY', 3),
#  ('OR SCIENCE', 3),
#  ('EDUCATIONAL TECHNOLOGY', 3),
#  ('ANIMATION 2D DIGITAL', 3),
#  ('TELEMARKETING', 3),
#  ('INDUSTRIAL ELECTRONICS', 3),
#  ('CHRISTIAN THEOLOGY', 3),
#  ('PERSONAL COMPUTER OPERATION', 3),
#  ('VALUE EDUCATION', 3),
#  ('BUSSINESS ADMINISTRATION', 3),
#  ('ANIMAL SCIENCE', 3),
#  ('FOOD TRADE', 3),
#  ('APPLIED SCIENCE', 3),
#  ('ELECTRONIC TECHNOLOGY', 3),
#  ('INFORMATIONTECHNOLOGY', 3),
#  ('CONTEMPORARY PHILOSOPHY', 3),
#  ('VOCATIONAL', 3),
#  ('INFORMATION TECHNOLOGY PROGRAMMING', 3),
#  ('MECHANICAL PRODUCTION ENGINEERING TECHNOLOGY', 3),
#  ('AERONAUTICS', 3),
#  ('MUSICAL THEATRE', 3),
#  ('FOOD BUSINESS MANAGEMENT', 3),
#  ('BUSINESS ADMINSTRATION', 3),
#  ('PHYSICAL THERAPIST', 3),
#  ('INDUSTRIAL LABOR RELATION', 3),
#  ('ARCHITECTURE RELATED DESIGN', 3),
#  ('COMPUTER HARDWARE SERVICING NC II', 3),
#  ('COMPUTER HARDWARE SERVICING NCII', 3),
#  ('AIRLINE MANAGEMENT', 3),
#  ('COMPUTATIONAL FINANCE', 3),
#  ('MANAGEMENT HONOR', 3),
#  ('COMPUTER NETWORK ADMINISTRATION', 3),
#  ('COMMUNITY NUTRITION', 3),
#  ('JUNIOR SECRETARIAL', 3),
#  ('PRESCHOOL EDUCATION', 3),
#  ('CULINARY ART KITCHEN OPERATION', 3),
#  ('MASSCOMMUNICATION', 3),
#  ('OPERATION RESEARCH', 3),
#  ('BUSINESS ADMINISTRATION ECONOMICS', 3),
#  ('ECONOMICS PUBLIC ADMINISTRATION', 3),
#  ('SERVICE MANAGEMENT', 3),
#  ('ART HISTORY', 3),
#  ('INFORMATION COMPUTER TECHNOLOGY', 3),
#  ('BUSINESS ADMINISTRATION MANAGEMENT ACCOUNTING', 3),
#  ('RADIOLOGY', 3),
#  ('CHINESE STUDY', 3),
#  ('OFFICE MANAGEMENT TECHNOLOGY', 3),
#  ('COMPUTER SOFTWARE', 3),
#  ('HOSPITALITY MANANGEMENT', 2),
#  ('COMPUTER ELECTRONIC TECHNICIAN', 2),
#  ('ELECTRONIC COMMUNICATION ENGINEER', 2),
#  ('TRANSLATION', 2),
#  ('FOOD SERVICE', 2),
#  ('MARKETING ADVERTISING', 2),
#  ('WELDING', 2),
#  ('COMMERCE MANAGEMENT', 2),
#  ('INTERNATIONAL BUSINESS MARKETING', 2),
#  ('BUSINESS AD', 2),
#  ('FOODTECHNOLOGY', 2),
#  ('CLERICAL SKILL', 2),
#  ('FOR CULINARY ART', 2),
#  ('MATERIAL SCIENCE', 2),
#  ('MILITARY SCIENCE', 2),
#  ('COMPUTER SOFTWARE TECHNOLOGY', 2),
#  ('CRIMINAL JUSTICE EDUCATION', 2),
#  ('COMPUTER AIDED ENGINEERING', 2),
#  ('OFFICE ADMNISTRATION', 2),
#  ('AUTOMOTIVE MECHANIC', 2),
#  ('GENERAL RADIO COMMUNICATION OPERATOR', 2),
#  ('TOUR GUIDING SERVICE', 2),
#  ('PHILOSOPHY HEALTH DEVELOPMENT', 2),
#  ('COMPUTER HARDWARE SERVICING NCLL', 2),
#  ('CONSUMER ELECTRONICS SERVICING NC II', 2),
#  ('COMPUTER TECNOLOGY', 2),
#  ('CYBER PROGRAMMING', 2),
#  ('BUSINESS ADMINISTRATION HRDM', 2),
#  ('COMPUTER SYSTEM OFFICE MANAGEMENT', 2),
#  ('AUTO MECHANIC', 2),
#  ('BSCS', 2),
#  ('BEED EDUCATION', 2),
#  ('COMPUTER SYSTEM NETWORKING TECHNOLOGY', 2),
#  ('INFORMATION TECHNOLOGY SPECIALIZED', 2),
#  ('ANIMAL COMMUNICATION', 2),
#  ('SCIRNCE', 2),
#  ('MANAGEMENT COMMUNICATION', 2),
#  ('ANT MANAGEMENT', 2),
#  ('CREATIVE ART', 2),
#  ('INFORMATION TECHNOLOY', 2),
#  ('COOPERATIVE', 2),
#  ('MASTERY LEARNING', 2),
#  ('HEALTHCARE ADMINISTRATION', 2),
#  ('MANAGEMENT PSYCHOLOGY COUNSELING', 2),
#  ('ELECTROMECHANICS TECHNOLOGY', 2),
#  ('ART ADMINISTRATION', 2),
#  ('INFORMATION TECHNOLOGY ANIMATION', 2),
#  ('MANUFACTURING ENGINEERING MANAGEMENT', 2),
#  ('MECHANICAL', 2),
#  ('MEDICAL ASSISTANT', 2),
#  ('MATHEMATICAL STATISTIC', 2),
#  ('PHARMACY SERVICE', 2),
#  ('ELECTRONICS TELECOMMUNICATION TECHNOLOGY', 2),
#  ('GRAPHIC ART PRINTING TECHNOLOGY', 2),
#  ('TRAVEL TOURISM MANAGEMENT', 2),
#  ('DIGITAL FILMMAKING', 2),
#  ('COMSCIE', 2),
#  ('NETWORKING', 2),
#  ('WEB DESIGN', 2),
#  ('COMMERCE MANAGEMENT ACCOUNTING', 2),
#  ('SCEINCE', 2),
#  ('HOUSEKEEPING NC II', 2),
#  ('BARTENDING NC II', 2),
#  ('FOOD ENGINEERING', 2),
#  ('SIENCE', 2),
#  ('AIR TRANSPORTATION', 2),
#  ('PHILOSOPHY HUMAN RESOURCE DEVELOPMENT', 2),
#  ('INTEGRATED STUDY', 2),
#  ('BASIC COMPUTER', 2),
#  ('TOURISM STUDY', 2),
#  ('ENTREPRENEURIAL MARKETING', 2),
#  ('DIGITAL ART DESIGN', 2),
#  ('AUTOCAD', 2),
#  ('FOOD BEVERAGE SERVICE', 2),
#  ('HAIRDRESSING', 2),
#  ('GARMENT FASHION DESIGN', 2),
#  ('VETERINARY TECHNOLOGY', 2),
#  ('FOR CALLCENTER AGENT NCII', 2),
#  ('COMPUTER PROGGRAMING', 2),
#  ('ELECTRO MECHANIC', 2),
#  ('ME', 2),
#  ('IED DRAFTING TECHNOLOGY', 2),
#  ('MANUFACTURING ENGINEERING', 2),
#  ('EXECUTIVE', 2),
#  ('CHEMICAL TECHNOLOGY', 2),
#  ('MEDICINE', 2),
#  ('INFORMATION TECHNOLOGY LADDERIZED', 2),
#  ('AREA STUDY', 2),
#  ('ADVANCED', 2),
#  ('HUMAN RESOURCE DEVELOPEMENT MANAGEMENT', 2),
#  ('E ENGLISH', 2),
#  ('UNDERGRADUATE', 2),
#  ('BUSINES ADMINISTRATION', 2),
#  ('STI', 2),
#  ('BUSINESS OFFICE ADMINISTRATION SYSTEM', 2),
#  ('TOURISM INDUSTRY', 2),
#  ('HILOT WELLNESS MASSAGE', 2),
#  ('BEAUTYCARE', 2),
#  ('INFORMATION COMMUNICATION TECHNOLOGY MANAGEMENT', 2),
#  ('MAR E', 2),
#  ('EMT', 2),
#  ('BARISTA', 2),
#  ('INFORMATION TECHNOLOGY COMPUTER TECHNICIAN', 2),
#  ('HOTEL RESTAURANT SERVICE TECHNOLOGY', 2),
#  ('DRAWING', 2),
#  ('CONCURRENT PROGRAMMING', 2),
#  ('COMPUTER SERCRETARIAL', 2),
#  ('HUMAN RESOURCE DEVELOPMENT', 2),
#  ('H', 2),
#  ('COMPUTER GRAPHIC ANIMATION', 2),
#  ('BIOLOGY FOR TEACHER', 2),
#  ('CIVIL TECHNOLOGY', 2),
#  ('COMPUTER DATA PROCESSING MANAGEMENT', 2),
#  ('FINACIAL MANAGEMENT', 2),
#  ('FOOD', 2),
#  ('FINANCIAL ECONOMICS', 2),
#  ('FISHERY MANAGEMENT', 2),
#  ('AGRICULTURE TECHNOLOGY', 2),
#  ('CULTURAL HISTORY', 2),
#  ('HOUSEKEEPING NC2', 2),
#  ('NETWORKING SCIENCE', 2),
#  ('AGRI BUSINESS', 2),
#  ('SECONDARY EDUCATION MATHEMATICS', 2),
#  ('COMMERCE BUSINESS MANAGEMENT', 2),
#  ('DRESSMAKING', 2),
#  ('SECRETARIAL SCIENCE', 2),
#  ('GENERAL ENGINEERING', 2),
#  ('ANIMATION 3D DIGITAL', 2),
#  ('NETWORK ADMINISTRATION', 2),
#  ('INDUSTRIAL AUTOMATION CONTROL ENGINEERING TECHNOLOGY', 2),
#  ('TOURISM PROMOTION SERVICE', 2),
#  ('COE', 2),
#  ('TESDA', 2),
#  ('FRENCH', 2),
#  ('ENGLISH LITERATURE LINGUISTICS', 2),
#  ('BACHELO', 2),
#  ('GENETICS', 2),
#  ('ELECTONIC TECHNICIAN', 2),
#  ('COMPUTER HARDWARE SERVICING PROGRAMMING', 2),
#  ('EVENT MANAGEMENT', 2),
#  ('INDUSTRIAL ENGINEER', 2),
#  ('NO', 2),
#  ('APPLIED STATISTIC', 2),
#  ('MEDICAL AESTHETIC', 2),
#  ('HOTEL RESTAURANT SEVICES', 2),
#  ('APPLIED PHILOSOPHY', 2),
#  ('COMPUTER INFORMATION TECHNOLOGY', 2),
#  ('ENVIRONMENTAL ENGINEERING', 2),
#  ('PROGRAMMING LANGUAGE', 2),
#  ('TECHNICAL THEATER', 2),
#  ('FIELD', 2),
#  ('ENTREPRENUERSHIP', 2),
#  ('AMERICAN HISTORY', 2),
#  ('MEDICAL DENTAL NURSING ASSISTANT', 2),
#  ('MARITIME STUDY', 2),
#  ('OFFICE SYSTEM MANAGEMENT', 2),
#  ('TECHNOLOGY AUTOMOTIVE', 2),
#  ('MEDIUM STUDY MASS', 2),
#  ('COMPUTER SCIENCE TECHNOLOGY', 2),
#  ('TECHNOLOGY EDUCATION', 2),
#  ('WATER OPERATION MANAGEMENT', 2),
#  ('MULTIMEDIA DESIGN ANIMATION', 2),
#  ('MASSCOMM', 2),
#  ('INFORMATION TECHNOLOGY AUTOMOTIVE', 2),
#  ('EMERGENCY MANAGEMENT', 2),
#  ('DIGITAL MARKETING', 2),
#  ('RADIOLOGIC TECHNICIAN', 2),
#  ('CATERING', 2),
#  ('BACHELOS', 2),
#  ('COMPUTER SOFTWARE APPLICATION', 2),
#  ('HOSPITALITY MANAGEMENT HOTEL RESTAURANT', 2),
#  ('LOGIC FOUNDATION', 2),
#  ('SPANISH', 2),
#  ('ACOUNTANCY', 2),
#  ('COMMERCE BANKING FINANCE', 2),
#  ('COMPUTATIONAL MATHEMATICS', 2),
#  ('BAACHELOR', 2),
#  ('PYSCHOLOGY', 2),
#  ('OFFICE ADMINSTRATION', 2),
#  ('BUSINES MANAGEMENT', 2),
#  ('NC II', 2),
#  ('CIVIL ENGINEERING TECHNOLOGY', 2),
#  ('COMPUTER SYSTEM TECHNOLOGY', 2),
#  ('TECHNOLOGY COMMUNICATION MANAGEMENT', 2),
#  ('PROFESSIONAL TEACHER', 2),
#  ('AIRLINE OPERATION PROCEDURE', 2),
#  ('CRIMINAL LAW', 2),
#  ('E MATHEMATICS', 2),
#  ('CONSUMER ELECTRONICS', 2),
#  ('COMPUTER SYSTEM', 2),
#  ('HOTEL RESTAURANT TOUR MANAGEMENT', 2),
#  ('BUSINESS MARKETING', 2),
#  ('CABANATUAN CITY', 2),
#  ('CALLCENTER TRAINING', 2),
#  ('TECHNOLOGY MANAGEMENT', 2),
#  ('HOTEL AN RESTAURANT MANAGEMENT', 2),
#  ('BIOECONOMICS', 2),
#  ('COMPUTER BASED ACCOUNTING', 2),
#  ('GOOD', 2),
#  ('JURIS', 2),
#  ('ECONOMICS SOCIOLOGY', 2),
#  ('COMPUTER SYSTEM TECHNICIAN', 2),
#  ('OA', 2),
#  ('SECRETARIAL ADMINISTRATION', 2),
#  ('GOVERNMENTAL AFFAIR', 2),
#  ('SALESMANSHIP', 2),
#  ('COMPUTER SECRETARIAL SCIENCE', 2),
#  ('ACT', 2),
#  ('CLOTHING TECHNOLOGY', 2),
#  ('BIBLE', 2),
#  ('PROFESSION APPLIED SCIENCE', 2),
#  ('COMPUTER TECHNICIAN SYSTEM MANAGEMENT', 2),
#  ('PERFORMING ART', 2),
#  ('HUMAN DEVELOPMENT FAMILY STUDY', 2),
#  ('SOFTWARE DEVELOPER', 2),
#  ('COMPUTER SECRETARIAT', 2),
#  ('INFO TECHNOLOGY', 2),
#  ('LANDSCAPE ARCHITECTURE PLANNING', 2),
#  ('ASTROPHYSICS', 2),
#  ('ELEMENTARY', 2),
#  ('FINANCIAL ECONOMETRICS', 2),
#  ('INFORAMTION TECHNOLOGY', 2),
#  ('SUSTAINABLE AGRICULTURE', 2),
#  ('MULTIMEDIA TECHNOLOGY', 2),
#  ('COMPUTER OFFICE MANAGEMENT', 2),
#  ('TRAVEL TOUR', 2),
#  ('AGRICULTURAL BUSINESS MANAGEMENT', 2),
#  ('T L E', 2),
#  ('INFORMATION TECHNLOGY', 2),
#  ('BUSINESS ADMINSITRATION', 2),
#  ('BIOMEDICAL ENGINEERING', 2),
#  ('HOTEL RESTUARANT SERVICE', 2),
#  ('INDUSTRIAL MANAGEMENT', 2),
#  ('INTERNET TECNOLOGY', 2),
#  ('MEDICAL TRANSCRIPTION', 2),
#  ('EUROPEAN STUDY INTERNATIONAL RELATION', 2),
#  ('ENTREPRENEURSHIP MANAGEMENT', 2),
#  ('AUTOMOTIVE ELECTRICAL ASSEMBLY', 2),
#  ('FOOD BEVERAGE NCII', 2),
#  ('NURSING MIDWIFERY', 2),
#  ('AUTO DIESEL TECHNOLOGY', 2),
#  ('BUSINESS ADMINISTRATOR', 2),
#  ('PRODUCTION DESIGN', 2),
#  ('ARCHITECTURAL TECHNOLOGY', 2),
#  ('MARINE SCIENCE', 2),
#  ('SMALL ENGINE', 2),
#  ('WORKING STUDENT', 2),
#  ('MASS COMMUNICATIONS', 2),
#  ('ART SCIENCE', 2),
#  ('BUTUAN CITY', 2),
#  ('DIPLOMATIC HISTORY', 2),
#  ('HOTEL HOSPITALITY MANAGEMENT', 2),
#  ('PAINTING', 2),
#  ('GENERAL MANAGEMENT', 2),
#  ('PT', 2),
#  ('BOOKKEEPING ACCOUNTING', 2),
#  ('TOURISIM', 2),
#  ('HOTEL RESTUARANT MANAGEMENT', 2),
#  ('INDUSTRIAL ELECTRICIAN', 2),
#  ('BUSINESS ADMINISTRATION HOTEL RESTAURANT MANAGEMENT', 2),
#  ('ELECTRONICS COMMUNICATION ENGINEER', 2),
#  ('MIDDLE EAST STUDY', 2),
#  ('PHILIPPINE ART', 2),
#  ('INSTRUMENTATION CONTROL ENGINEERING', 2),
#  ('TECHNOLOGY LIVELIHOOD EDUCATION', 2),
#  ('ANIMAL HEALTH CARE MANAGEMENT', 2),
#  ('AUTOMOTIVE DIESEL MECHANIC', 2),
#  ('5', 2),
#  ('BUSINESS ACCOUNTING', 2),
#  ('BCS COMPUTER SCIENCE', 2),
#  ('CONSERVATORY', 2),
#  ('DOUBLE', 2),
#  ('TECHNICIAN', 2),
#  ('WORLD HISTORY', 2),
#  ('INFORMATION COMPUTER SCIENCE', 2),
#  ('STEWARDSHIP', 2),
#  ('ANALYTIC PHILOSOPHY', 2),
#  ('HEALTH EDUCATION', 2),
#  ('MANAGERIAL ACCOUNTING', 2),
#  ('PRESCHOOL', 2),
#  ('BUSINESS ADMINISTRATIVE', 2),
#  ('DIGITAL MEDIUM ART', 2),
#  ('NURSING AID', 2),
#  ('AUDIO PRODUCTION', 2),
#  ('LANDSCAPE ARCHITECTURE', 2),
#  ('MATION TECHNOLOGY', 2),
#  ('CE', 2),
#  ('DENTAL ASSISTING', 2),
#  ('RESTAURANT COFFEE SHOP LEAD TO FOOD BEVERAGE SERVICE', 1),
#  ('PAMANTASAN LUNGSOD NG MAKATI', 1),
#  ('CULINARY ART NC1 NC2', 1),
#  ('PSYCHOLOGY CRIMINAL JUSTICE', 1),
#  ('ELEM EDUCATION', 1),
#  ('INTERDISCIPLINARY STUDY PYSCHOLOGY COMMUNICATION', 1),
#  ('INTOURISM', 1),
#  ('DANCE', 1),
#  ('SOCIAL SCIENCE HISTORY', 1),
#  ('FOOD PREPARATION SERVICE TECHNOLOGY', 1),
#  ('MULTI MEDIUM INTERNET TECHNOLOGY', 1),
#  ('ADMINISTRATIVE ASSISTANT', 1),
#  ('MEDICAL SCIENCE', 1),
#  ('COMPUTER SECRETARIAL ACCOUNTING SERVICE', 1),
#  ('NURSING AIDE ING', 1),
#  ('BUSINESS INFORMATION SYSTEM', 1),
#  ('NIRSING', 1),
#  ('CUSTOMER SERVICE CENTER', 1),
#  ('INTER DISCIPLINARY STUDY', 1),
#  ('COMMUNICATION ADVERTISING PUBLIC RELATION', 1),
#  ('LAW POLICY STUDY', 1),
#  ('DYNAMIC PROGRAMMING', 1),
#  ('COMPUER SECRETATIAL OFFICE MANAGEMENT', 1),
#  ('WELDING SMAW GMAW', 1),
#  ('HOTEL RESATAURANT SERVICE', 1),
#  ('COMPUTER HARDWARE SERVICING NC 11', 1),
#  ('MEDICAL SUPPORT ASSISTANT', 1),
#  ('ENTREPRENEURSHIP MARKETING', 1),
#  ('ECONOMICS PUBLIC POLICY', 1),
#  ('SOCIOLOGY ECONOMICS', 1),
#  ('HEALTHCARE', 1),
#  ('POWERPOINT', 1),
#  ('HOTEL RETAURANT MANAGEMENT', 1),
#  ('SYSTEM ANALYSIS DESIGN CONTROL AUDIT STUDENT ALSO GAIN THE SKILL TO DEVELOP MANAGE COMPUTER APPLICATION INVOLVING ACCOUNTING DATA',
#   1),
#  ('CHINA BEIJING', 1),
#  ('AEROSPACE TECHNOLOGY', 1),
#  ('EXECUTIVE ASSISTANSHIP', 1),
#  ('MARINE ENGINE', 1),
#  ('CUM LAUDE', 1),
#  ('INTERNATIONAL ECONOMIC BUSINESS LAW', 1),
#  ('MANAGEMENT BUSINESS', 1),
#  ('HRA HOTEL RESTAURANT ADMINISTRATION', 1),
#  ('AVIATION ELECTRONICS TECHNOLOGY', 1),
#  ('EDUCATION IOLOGY TEACHER', 1),
#  ('TTM', 1),
#  ('MICROSOFT OFFICE WORD', 1),
#  ('SCRIPT IMG SRC SEARCH', 1),
#  ('BANLIC CABUYAO LAGUNA', 1),
#  ('TTE', 1),
#  ('MAHTHEMATICS', 1),
#  ('LHRM', 1),
#  ('PEDIATRICS', 1),
#  ('DIESEL ENGINE MECHANIC', 1),
#  ('ELEMENTARY PARTICLE PHYSIC', 1),
#  ('COMPUTER APPLICATION INFORMATION SYSTEM', 1),
#  ('BOOKKEPPING', 1),
#  ('MICRO COMPUTER TECHNOLOGY', 1),
#  ('INFROMATION TECHNOLOGY', 1),
#  ('MAJOT ECONOMICS', 1),
#  ('BSED TLE', 1),
#  ('ADVERTISING PUBLIC RELATION ACCOUNT MANAGEMENT', 1),
#  ('GEOLOGICAL SCIENCE ENGINEERING', 1),
#  ('ELEMENTARY AGRICULTURAL EDUCATION', 1),
#  ('COMPUTRE SECRETARY', 1),
#  ('COMMUNICATION STUDY PUBLIC RELATION', 1),
#  ('HUMAN DEVELOPMENT FINE ART', 1),
#  ('SCIENCE INFORMATION TECHNOLOGY', 1),
#  ('MATHEMATICS PHYSIC', 1),
#  ('WILDLIFE MANAGEMENT', 1),
#  ('ST FRANCIS DIVINE', 1),
#  ('ANALYTICAL CHEMISTRY', 1),
#  ('ELECTOR MECHANICAL', 1),
#  ('PHYSICOLOGY', 1),
#  ('ECONOMICS MANAGEMENT', 1),
#  ('THEOLOGY PROPER', 1),
#  ('KITCHEN', 1),
#  ('FINANCIAL MANAGERIAL ACCOUNTING', 1),
#  ('COMPUTER SECRETARIAL OFFICE MANAGEMENT', 1),
#  ('INFORMATION TEHNOLOGY', 1),
#  ('PROGRAMMING NC IV', 1),
#  ('INTERNATIONAL MANAGEMENT', 1),
#  ('ELECTRICAL LINEMAN', 1),
#  ('MANAGERIAL ECONOMICS', 1),
#  ('HOTEL REASTAURANT MANAGEMENT', 1),
#  ('3D MODELLING ANIMATION', 1),
#  ('COMPUTER APPLICATION PACKAGE', 1),
#  ('CRUISE LINE', 1),
#  ('GENERAL AGRICULTURE', 1),
#  ('ACCOUNTING SCIENCE', 1),
#  ('HISTORY SOUTHEAST ASIAN STUDY', 1),
#  ('MULTIMEDIA DESIGNER', 1),
#  ('BEED SPED', 1),
#  ('BIOMEDICAL TECHNICIAN', 1),
#  ('BUSINESS ANALYSIS', 1),
#  ('FINANCIAL MANAGEMENT HOTEL RESTAURANT', 1),
#  ('A ACCOUNTING', 1),
#  ('COMMUNICATION DISORDER DEAF EDUCATION', 1),
#  ('PHILOSOHY', 1),
#  ('MECHANICAL ENGEENERING', 1),
#  ('21 BSOA', 1),
#  ('PULMONARY THERAPY', 1),
#  ('EMERGENCY MEDICAL SERVICE', 1),
#  ('B CULINARY ARTS', 1),
#  ('BUSINESS HOTEL RESTAURANT MANAGEMENT', 1),
#  ('ARCHITECTURE URBAN PLANNING', 1),
#  ('HOTEL RESTAURANT MANAGER', 1),
#  ('AUTOCAD OPERATOR', 1),
#  ('GENERAL STUDY PROGRAM', 1),
#  ('GEN SCIENCE', 1),
#  ...]
