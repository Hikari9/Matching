# %%
from abelian import db
from abelian.models import ProfilerAnswer, Profiler, User, Job

db.configure('postgresql://kalibrr:password@localhost/kalibrr', False)
session = db.get_session()
session.rollback()

# %%
def extract_fields_of_study(education_profiler_data):
    fields_of_study = []
    
    for epd in education_profiler_data:
        if len(epd) > 1:
            print(epd)
        data = epd['education']
        education_dict = {key:data.get(key, '') for key in ['school', 'fields_of_study', 'level']}

        field_of_study = education_dict['fields_of_study']

        if field_of_study:
            fields_of_study += field_of_study

    return fields_of_study

uid_industry_data = {x[0]: x[1] for x in filter(lambda x: not x[1]['no_work_experience'], session.query(User.id, ProfilerAnswer.data).filter(ProfilerAnswer.user_id==User.id, User.is_test==False, ProfilerAnswer.profiler_code==Profiler.code, Profiler.type=='WorkHistoryProfiler').all())}
uid_course_data = {x[0]: x[1] for x in filter(lambda x: x[1]['education'].get('fields_of_study', None), session.query(User.id, ProfilerAnswer.data).filter(ProfilerAnswer.user_id==User.id, User.is_test==False, ProfilerAnswer.profiler_code==Profiler.code, Profiler.type=='EducationProfiler').all())}

# %%
uid_industry_data
# Out:
# {2825: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Jollibee Food Corporation',
#     u'end_date': u'2013-03-04T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Fryman',
#     u'job_title': u'Service Crew',
#     u'start_date': u'2010-03-09T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2837: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Pingu Tech Inc.',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'I motivate my coworkers by dressing up in an oversized penguin suit.',
#     u'job_title': u'Mascot',
#     u'start_date': u'2013-12-31T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2854: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Kalibrr',
#     u'end_date': u'2015-02-28T16:00:00.000Z',
#     u'industry': u'Operations & Management',
#     u'job_desc': u'Work with the design, engineering, business development, customer success, and marketing team to identify product opportunities and execute activities that create value for our users, clients, and investors. Manage operations and delivery of our product to clients and users.',
#     u'job_title': u'Product Manager',
#     u'start_date': u'2014-05-31T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2861: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'ta ke union co.ltd',
#     u'end_date': u'2014-11-30T16:00:00.000Z',
#     u'industry': u'Finance & Accounting',
#     u'job_desc': None,
#     u'job_title': u'secretary',
#     u'start_date': u'2012-04-30T16:00:00.000Z',
#     u'still_work_here': False,
#     u'type': 100}]},
#  2863: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Kinston Garment{bonjour de corp & Pbx',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'sewin line',
#     u'job_title': u'sewer',
#     u'start_date': u'2011-01-04T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2866: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Italk24 philippines',
#     u'end_date': u'2013-03-23T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Make a sale and meet there quota everyday',
#     u'job_title': u'Sales Agent',
#     u'start_date': u'2012-12-17T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Altus powered by Standard Charter Bank',
#     u'end_date': u'2013-06-14T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Make a sale only.',
#     u'job_title': u'Sales Agent',
#     u'start_date': u'2013-04-01T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Jaka Tent Rental(Abs Cbn outsource)',
#     u'end_date': u'2013-10-06T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u"Assist and provide the needs of the artist in the program or movie that we're taping.",
#     u'job_title': u'Rental Crew',
#     u'start_date': u'2013-06-27T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Pc support philippines',
#     u'end_date': u'2014-04-14T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Make a sale and meet there quota everyday.',
#     u'job_title': u'Technical support',
#     u'start_date': u'2013-11-11T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2868: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'myerix Internet Shop',
#     u'end_date': u'2014-06-09T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Assisting the customer in their computer needs.\nDoing typing jobs and operating photocopying machine.',
#     u'job_title': u'Assistant in Computer Shop',
#     u'start_date': u'2013-12-02T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'JBC Food Corporation',
#     u'end_date': u'2009-12-28T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Repacking of JBC Products.',
#     u'job_title': u'Factory Worker',
#     u'start_date': u'2009-07-12T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Tinbox Manufacturing Corporated',
#     u'end_date': u'2009-03-31T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Sorting of can lids.',
#     u'job_title': u'Factory Worker',
#     u'start_date': u'2008-09-30T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2873: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'West Contact Services, Inc.',
#     u'end_date': u'2014-04-04T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'responsible for answering incoming calls from customers and resolving technical issues,\nwhile ensuring a high level of customer service and maximizing productivity',
#     u'job_title': u'Tech Support Representative',
#     u'start_date': u'2013-10-06T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2877: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Mija Hachi',
#     u'end_date': u'2014-02-02T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'generate leads, meet, negotiate, and close deals',
#     u'job_title': u'Business Development Manager',
#     u'start_date': u'2012-09-26T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2878: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Convergys Phils.',
#     u'industry': u'Customer Service',
#     u'job_title': u'Technical Support',
#     u'start_date': u'2013-03-31T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2884: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Barangay Paratong Paoay, IN',
#     u'end_date': u'2016-12-30T08:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'To  planning and implementing unit of government policies, plans, programs, projects, and activities in the community, and as a forum wherein the collective views of the people may be expressed, crystallized and considered, and where disputes may be amicably settled',
#     u'job_title': u'BARANGAY KAGAWAD',
#     u'start_date': u'2013-12-13T08:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2891: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Al Habtoor Engineering',
#     u'end_date': u'2010-05-28T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'answering incoming calls.\nfilling of documents.',
#     u'job_title': u'telephone operator / document controller',
#     u'start_date': u'2006-08-11T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2898: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'chooks to go.bounty fresh',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'to get sales.our all available products.',
#     u'job_title': u'service crew',
#     u'start_date': u'2010-09-01T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2904: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'community based monitoring sytsem (city government of pasay)',
#     u'end_date': u'2009-06-15T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'conducting survey about the family background to know how big the the individual family population we have here in pasay and the benefits they can get in this survey.',
#     u'job_title': u'enumerator (job order)',
#     u'start_date': u'2008-09-15T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2905: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'far east bank(under agency)',
#     u'end_date': u'1999-03-18T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'encoding sales draft (credit card dept.)',
#     u'job_title': u'encoder',
#     u'start_date': u'1997-06-24T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2910: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'asdfasdfasdf',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'asdfasdfsadf',
#     u'job_title': u'efasdfasf',
#     u'start_date': u'2014-07-02T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2915: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Makhsoom Luxury',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'Write product descriptions, product research and branding, website administrator, sales assistant, product blogger',
#     u'job_title': u'Copywriter, Blogger, Product Researcher, Project Manager',
#     u'start_date': u'2013-03-31T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2919: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'high speed fotolusio',
#     u'end_date': u'2014-01-02T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'encode data in the computer',
#     u'job_title': u'data encoder',
#     u'start_date': u'2011-05-03T16:00:00.000Z',
#     u'still_work_here': False,
#     u'type': 100}]},
#  2920: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'fujitsu die tech phils.',
#     u'end_date': u'2009-12-06T08:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'i inspect the product if its good or reject before we ship into the costumers',
#     u'job_title': u'PRODUCTION INSPECTOR',
#     u'start_date': u'2009-07-06T07:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2921: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'at Kuwait',
#     u'end_date': u'2014-06-06T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Taking care of a sick and disable child.',
#     u'job_title': u'Caregiver',
#     u'start_date': u'2012-06-01T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2922: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'at Kuwait',
#     u'end_date': u'2013-06-13T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Taking care a sick and disable child.',
#     u'job_title': u'Caregiver',
#     u'start_date': u'2012-06-01T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2931: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'MONDE',
#     u'end_date': u'2000-09-30T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Inspect the finish product before giving to Quality Control(QC)',
#     u'job_title': u'Inspector',
#     u'start_date': u'1998-11-30T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2940: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'sterling global call center',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'to help or to resolve the problem of the customer',
#     u'job_title': u'Customer Service',
#     u'start_date': u'2013-11-10T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2942: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'technological institute of the phillipines',
#     u'end_date': u'2013-01-31T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'To make sure my area is clean and clear of trash.',
#     u'job_title': u'maintenance',
#     u'start_date': u'2010-08-31T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2950: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Tonichi Group International Inc.',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'to assist clients in choosing their ideal properties to buy and assist in completion of the documents needed after the sale',
#     u'job_title': u'Real Estate Agent',
#     u'start_date': u'2012-05-31T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2951: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Resort Hotels Corporation',
#     u'end_date': u'1980-01-14T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'recording minutes of the meeting, typing, filling correspondence, coordinating with various department, assisting my supervisor and co-employee,etc.',
#     u'job_title': u'Secretary',
#     u'start_date': u'1975-08-31T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2954: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'ECI Quest Co., Inc.',
#     u'end_date': u'2014-06-14T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'I convert voicemail messages into text messages using a specific program.',
#     u'job_title': u'Quality Control Agent',
#     u'start_date': u'2014-05-11T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'ECI Quest Co., Inc.',
#     u'end_date': u'2014-04-24T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'I type a transcript of the recorded depositions, trial, or hearing.',
#     u'job_title': u'Legal Transcriptionist I',
#     u'start_date': u'2012-04-15T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'ECI Quest Co., Inc.',
#     u'end_date': u'2012-02-05T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'I convert voicemail messages into text using a specific program.',
#     u'job_title': u'Quality Control Agent',
#     u'start_date': u'2012-01-01T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Prudentialife Plans, Inc.',
#     u'end_date': u'2012-02-05T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'I process the pension benefit application of the planholder.\nI prepare the pension benefit check of the planholder to be released at the counter or mailed to our branches.\nI prepare the request for trustfund withdrawal from our trustee banks.\nI prepare monthly reports of the released pension benefit checks.\nI monitor the filing of the released pension benefit applications and send it to the warehouse for storage.\nI answer inquiries made the planholder regarding their pension benefit.',
#     u'job_title': u'Loan and Benefit Assistant',
#     u'start_date': u'2005-07-31T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Prudentialife Plans, Inc.',
#     u'end_date': u'2005-06-30T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'I received transmittal reports from our branches and distribute it to each designated staff for record keeping.',
#     u'job_title': u'Document Receiver',
#     u'start_date': u'2004-03-31T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Planters Development Bank',
#     u'end_date': u'2003-09-30T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u"I sort monetary bills according to depository bank's request.",
#     u'job_title': u'Money Sorter',
#     u'start_date': u'2003-06-30T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2961: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Centraluz Marketing Corporation',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'Encoding of Daily Sales Report and AR Monitoring',
#     u'job_title': u'AR Officer',
#     u'start_date': u'2010-01-17T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2969: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'camellahomes',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'manages peolpe in my taem',
#     u'job_title': u'sales manager',
#     u'start_date': u'2013-02-01T08:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2973: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Taiwan company',
#     u'end_date': u'2012-09-24T22:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Answering phone calls. Write report. Translate Chinese to English',
#     u'job_title': u'Secretary/Interpreter',
#     u'start_date': u'2003-06-30T22:00:00.000Z',
#     u'still_work_here': False,
#     u'type': 100}]},
#  2974: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'mister donut',
#     u'end_date': u'2013-12-01T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'to make a high quality donuts',
#     u'job_title': u'production crew',
#     u'start_date': u'2012-12-09T16:00:00.000Z',
#     u'still_work_here': False,
#     u'type': 100}]},
#  2975: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'metropolitan waterworks and sewerage system',
#     u'end_date': u'2001-01-01T00:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u"update customer's accounts,issuing notices such as disconnection,orders to disconnect water service having delinquent accounts.",
#     u'job_title': u'clerk',
#     u'start_date': u'1985-01-01T00:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2980: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'UnionBank of the Philippines',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'- Responsible for creating, testing, managing, and maintaining web applications using business process management for internal departments in the company. I obtain the requirements and specifications of these web applications through meetings, discussions, and interaction with all the stakeholders and end-users of the system being created.',
#     u'job_title': u'Associate Programmer',
#     u'start_date': u'2014-02-28T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2987: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'merre diners lounge',
#     u'end_date': u'2013-03-30T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'make a good service to costumer',
#     u'job_title': u'waitress/cashier',
#     u'start_date': u'2012-11-14T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'inner senses spa',
#     u'end_date': u'2009-03-17T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': None,
#     u'job_title': u'massage therapist',
#     u'start_date': u'2008-11-29T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2988: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'RVB Firenze Hot Beverage System',
#     u'end_date': u'2014-06-05T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u"Brew Coffee and Serve it to the costumer's fast with a smile",
#     u'job_title': u'Coffee Barista',
#     u'start_date': u'2013-09-13T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Figaro Coffee Company',
#     u'end_date': u'2011-05-13T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Keeping the dining area clean and serves coffee, food and deal with the customers concern.',
#     u'job_title': u'Food Attendant',
#     u'start_date': u'2010-09-13T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Mercantile Stores Groups, Inc. (SM City Sta. Mesa)',
#     u'end_date': u'2009-12-31T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Take care to the customers concern and help them find what they need and wanted to buy',
#     u'job_title': u'Sales Utility Clerk',
#     u'start_date': u'2009-03-05T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Greenwich Pizza Corp. (Kalentong) L D C FOOD CHAIN INCORPORATED',
#     u'end_date': u'2006-12-23T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Make and design a Pizza',
#     u'job_title': u'Pizza Maker',
#     u'start_date': u'2006-07-23T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  2993: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Elevation Partners',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'bla bla',
#     u'job_title': u'Head of Story Solutions',
#     u'start_date': u'2009-06-28T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2997: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u"gentrade int'l phils. inc",
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'more on collection and finacing',
#     u'job_title': u'branch accounting in charge',
#     u'start_date': u'2011-11-20T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  2998: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Sitel',
#     u'end_date': u'2014-04-14T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Processing orders of customers and calling them to inform of information about their bills, promotions and new products.',
#     u'job_title': u'Customer Service Representative',
#     u'start_date': u'2012-11-20T16:00:00.000Z',
#     u'still_work_here': False,
#     u'type': 100}]},
#  2999: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'P413 Enterprises',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'Supervises the daily operations of the company.\nMakes sure that all the products to be delivered are in good condition.\nReports to the General Manager and Vice President of the Company.',
#     u'job_title': u'Supervisor',
#     u'start_date': u'2014-04-13T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100},
#    {u'company_name': u'Blue Bean Inc',
#     u'end_date': u'2014-04-06T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u"Upselling the company's product through phone.\nGathers information about the customer to help them process their credit cards.",
#     u'job_title': u'Telesales Agent',
#     u'start_date': u'2014-03-07T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3000: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Forever Agape and Glory Inc.',
#     u'end_date': u'2013-12-30T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Receiving deliveries.\nProcessing all items.\nDispatching all processed items.',
#     u'job_title': u'Stock Associate',
#     u'start_date': u'2013-09-12T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3002: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'RGE Man Power Services',
#     u'end_date': u'2013-11-11T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Office Assistant',
#     u'job_title': u'Intern',
#     u'start_date': u'2013-03-18T16:00:00.000Z',
#     u'still_work_here': False,
#     u'type': 100}]},
#  3003: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'RACKS RESTAURANT',
#     u'end_date': u'2014-03-17T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'TAKING ORDERS, BUSSING-OUT DISHES, DELIVERING OF FOOD',
#     u'job_title': u'FOOD SERVER',
#     u'start_date': u'2013-10-06T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3004: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'shoppersville bake shop',
#     u'end_date': u'2014-02-27T23:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'decoraiting and baking',
#     u'job_title': u'production decoraitor',
#     u'start_date': u'2013-06-24T22:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3010: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Figaro Coffee Company',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'To supervise the operation in the absence of the Manager. Follow standard operating procedures and ensure the quality of service.',
#     u'job_title': u'Officer in Charge',
#     u'start_date': u'2010-06-17T07:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  3011: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Armada Hotel Manila',
#     u'end_date': u'2014-07-22T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Accepting Reservations by the guests\nAnswering phone calls by the guests',
#     u'job_title': u'Receptionist',
#     u'start_date': u'2014-01-31T16:00:00.000Z',
#     u'still_work_here': False,
#     u'type': 100}]},
#  3013: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Crowne Plaza Manila Galleria (JAMMAS Inc.)',
#     u'end_date': u'2014-03-14T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Grill and Vegetable station',
#     u'job_title': u'Kitchen Attendant',
#     u'start_date': u'2014-02-28T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3016: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'surway promotion',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'promoting product.',
#     u'job_title': u'promodizer',
#     u'start_date': u'2014-05-08T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100},
#    {u'company_name': u'surway promotion',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'promoting new product',
#     u'job_title': u'promodizer',
#     u'start_date': u'2014-05-07T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  3017: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'464 Jollibee Main Pagadian City',
#     u'end_date': u'2013-12-17T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'-  Assertive and fast learner\n-  Willing and able to work under pressure\n-  Computer Literate\n-  Bartending\n-  Cashier\n-  Food server',
#     u'job_title': u'Fast Food',
#     u'start_date': u'2012-11-07T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3018: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'House Atreides',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'Kick ass & take names',
#     u'job_title': u'Ruler of Dune',
#     u'start_date': u'2014-06-30T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  3019: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Solaire Hotel and Casino',
#     u'end_date': u'2014-07-02T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Performs routine duties in cleaning and servicing of guest rooms and baths under supervision of housekeeping supervisor. Room attendant promotes a positive image of the property to guests and must be pleasant, honest, friendly and should also able to address guest requests and problems.',
#     u'job_title': u'Guest Room Attendant',
#     u'start_date': u'2013-03-04T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Airport Casino Filipino',
#     u'end_date': u'2013-02-19T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Facilitate service of all food and beverages to guests and ensure compliance to all standards and manage all communication with customers and ensure satisfaction with all cocktail service.',
#     u'job_title': u'Cocktail Attendant',
#     u'start_date': u'2010-11-19T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3021: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Manila Grand Opera Hotel and Casino',
#     u'end_date': u'2013-12-06T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Assign at Cold kitchen department, Garde manger, salads, fruit platter and salads.',
#     u'job_title': u'Commis 3 (On-call)',
#     u'start_date': u'2013-09-06T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3026: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Sm land',
#     u'end_date': u'2014-03-30T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Meet the required sales quota every month/quarter/year',
#     u'job_title': u'Account Manager',
#     u'start_date': u'2013-10-31T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Megaworld',
#     u'end_date': u'2013-02-14T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Responsible for the effiicient and successful promotion and marketing of the projects',
#     u'job_title': u'Property consultant',
#     u'start_date': u'2012-08-31T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u"Robinson's Land",
#     u'end_date': u'2012-02-14T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Maintain good relationship with clients and keeping them happy by completing products and/or projects according to their satisfaction',
#     u'job_title': u'Account Manager',
#     u'start_date': u'2011-10-31T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Smart matic',
#     u'end_date': u'2012-02-14T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Managed and trained pcos machine operators',
#     u'job_title': u'Pcos Supervisor',
#     u'start_date': u'2010-06-30T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3027: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Steel Centre Philippines Inc.',
#     u'end_date': u'2013-08-02T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'\u2022\tEncoding and Printing of Daily Deliveries.\n\u2022\tCreate Monthly Reports.\n\u2022\tPosting, Monitoring of Materials.',
#     u'job_title': u'Materials Staff',
#     u'start_date': u'2013-05-14T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3029: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Rustan Marketing Specialists, Inc.',
#     u'end_date': u'2014-03-13T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Provide excellent customer service and generate sales.',
#     u'job_title': u'Sales Consultant',
#     u'start_date': u'2013-10-14T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3035: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'HOTEL SOGO SANTOLAN',
#     u'end_date': u'2012-05-11T19:30:00.000Z',
#     u'industry': None,
#     u'job_desc': u"to clean and prepair the room  and the other area of the hotel. specially to maintain cleanliness to our rooms and area.\nto check the items that they are missing or lost \nto deliver good quality and satisfaction to our customer's and guest.",
#     u'job_title': u'Room Attendant',
#     u'start_date': u'2012-01-08T19:30:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Next Door North Park',
#     u'end_date': u'2014-01-13T19:30:00.000Z',
#     u'industry': None,
#     u'job_desc': u'to serve food & beverages.\nto assisted cleaning and setting up table up setup.\nto assured food safety at all times.\nfacilitated and payment process.\nmonitoring stocks of our restaurant.',
#     u'job_title': u'Food Server',
#     u'start_date': u'2014-01-13T19:30:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3037: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u"McDonald's",
#     u'end_date': u'2013-04-08T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u"To help my customer, assisting them when they're going to their table. cleaning the the tables after my customers left.",
#     u'job_title': u'Service Crew',
#     u'start_date': u'2012-09-11T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3039: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Dairy Queen',
#     u'end_date': u'2014-06-04T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'cashier and do the production',
#     u'job_title': u'Team Member',
#     u'start_date': u'2013-11-07T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3043: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'HAVENLINK SOLUTIONS',
#     u'end_date': u'2007-04-28T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'PERFORM AN OUTBOUND CALL(SALES).',
#     u'job_title': u'CALL CENTER REPRESENTATIVE',
#     u'start_date': u'2006-11-09T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3051: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Negrense/ 2go travel Inc.',
#     u'end_date': u'2014-07-31T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Waiter, Rover, Food attendant',
#     u'job_title': u'Food and Beverage Attendant',
#     u'start_date': u'2013-06-03T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3052: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Taters Enterprises, Inc.',
#     u'end_date': u'2012-10-25T07:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'- Assist and report on the preparation, sale and serving of the products and to  check that the established standards, policies and procedures are strictly followed.                            \n- Assist and report on the Team players practices in receiving, food handling and storage in order to avoid wastages, breakage and spoilage.\n- Assist and report on the Team players operation of all equipment, kitchenware, tableware and utensils in order to produce the desired result, minimize breakdown and losses.\n- Assist and report on the cashiering and administrative procedures following established standards, policies and procedures.\n- Submit the required operation, cashiering, inventory and other administrative reports as required by the Management.\n- Monitor and ensure that the security and safety and procedures are followed at all times.',
#     u'job_title': u'Cashier Crew III / Team Captain Trainee (Shift Supervisor)',
#     u'start_date': u'2007-11-09T08:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Japan Franchise Corp.',
#     u'end_date': u'2005-09-11T07:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'- To strictly follow the established cashiering policies and procedures for recording accurately all transactions involving money, merchandise,materials and supplies.\n- To secure account and remit sales collections following established policies and procedures.\n- To submit the required cashiering reports.\n To operate the POS and other equipment properly by following standard order-taking and cashiering procedures in order to produce the desired result.\n- To attend to each customer with dispatch, courtesy and professional conduct with the aim of rendering excellent customer service.\n- To promote the sale of products at every opportunity.',
#     u'job_title': u'Service Crew / Cashier Crew',
#     u'start_date': u'2005-03-26T07:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Jollimart Phils. Corp.',
#     u'end_date': u'2004-04-15T07:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'- To attend to each customer with dispatch, courtesy and professional conduct with the aim of rendering excellent customer service.\n- To prepare cash, order slips and other forms and office supply requirement by following strictly the established standards, policies and procedures.\n- To follow carefully the established housekeeping procedures in order to maintain the store premises in a clean, tidy and orderly at all times.\n- To follow the established security and safety procedures at all times.\n- To perform the above duties and conduct oneself in the store in accordance with the established rules of conduct and behavior in the workplace.',
#     u'job_title': u'Service Crew/ Cashier Crew/ Stock Clerk',
#     u'start_date': u'2003-12-10T08:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3053: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Affliated Computer Services',
#     u'end_date': u'2013-12-30T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'giving assistance to our customers over the phone',
#     u'job_title': u'csr',
#     u'start_date': u'2013-05-12T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3059: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Philippine transmarine cariers Inc.',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'To ensures. The guest satisfaction, to assess. The guest what they need.',
#     u'job_title': u'stateroom attendant',
#     u'start_date': u'2010-10-10T00:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  3060: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'universal ruvina corporation',
#     u'end_date': u'2014-01-29T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'refiling the product and assist the costumer of the supermarket',
#     u'job_title': u'Merchandiser',
#     u'start_date': u'2013-11-29T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'universal Ruvina Corporation',
#     u'end_date': u'2014-01-28T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'refiling the products and assisting the costumer in supermarke',
#     u'job_title': u'Merchandiser',
#     u'start_date': u'2013-11-28T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3065: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u"Children's Little University",
#     u'end_date': u'2013-03-14T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Saving files, Documenting, helping to the teachers ..',
#     u'job_title': u'School Office Assistant',
#     u'start_date': u'2012-06-13T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3067: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'J.co Donuts and Coffee',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'*Packing donuts\n*Customer service\n*Cashiering\n*Making, mixing, serving coffee and frappe\n*Designing and serving frozen yogurt\n*pre-busing and busing tables\n*takes orders',
#     u'job_title': u'Frontliner/Barista',
#     u'start_date': u'2013-05-22T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  3070: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'TWG Tea Philippines',
#     u'end_date': u'2014-10-29T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Cashier - in charge of processing all transactions.\nPastry Personnel - was in charge of pastries daily inventory and attend to guest questions regarding the products.\nRetail Personnel -Studied the Teas and Tea Accessories to effectively suggest to customers their desired tea preference.\nDining Staff - Knowledgeable about the Menu to be able to explain and suggest to guest. Taking orders, delivering guest food, buzzing out.\nBarman- In charge of tea making made sue that is in its best quality when serve to the guest.',
#     u'job_title': u'F and B Associate',
#     u'start_date': u'2013-05-29T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3076: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Emerald Green Corporation',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'Manage the filing, storage and security of documents.\nRespond to inquiries.\nManage the repair and maintenance of the building.\nSupervise customer services and respond to customer inquiries.\nPerform other related duties as required.',
#     u'job_title': u'Administrative Staff',
#     u'start_date': u'2011-05-04T07:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100},
#    {u'company_name': u"Dunkin' Donuts",
#     u'end_date': u'2011-05-03T07:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Greeting customers while offering customer service attention, taking assembling and presenting food orders, requesting and receiving of payment, operating the cash register.\nCleaning in accordance to our company\u2019s sanitary standards including but not limited to: sweeping and mopping of floors, cleaning walls, tables, counters, kitchen and service equipment. Cleaning the customer service area, removing trash and cleaning restrooms.\nPreparing food for sale.\nChecking stock of products and insuring proper stock levels and rotation.',
#     u'job_title': u'Service Crew',
#     u'start_date': u'2009-01-18T08:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3077: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Jollibee Teresa Branch',
#     u'end_date': u'2014-02-08T15:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'We serve quality service and maintain store cleanliness.',
#     u'job_title': u'Dining Crew',
#     u'start_date': u'2012-09-17T15:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3078: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'NHOEL JR. CONSTRUCTION',
#     u'end_date': u'2013-12-04T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'RESPONSIBILITIES FOR MYSELF,MY CO-WORKERS AND THE MACHINE I OPERATE',
#     u'job_title': u'WELDER',
#     u'start_date': u'2013-08-27T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3097: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Marinolds Bar and Grill',
#     u'end_date': u'2008-07-19T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'address the customers needs and serve them with a smile on our face',
#     u'job_title': u'waitress',
#     u'start_date': u'2007-03-02T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3098: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'ACS - Xerox Phils.',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'IT Trouble shooting and analyst',
#     u'job_title': u'IT Helpdesk Analyst',
#     u'start_date': u'2013-06-23T20:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100},
#    {u'company_name': u'24[7] Customer Philippines Inc.',
#     u'end_date': u'2013-06-16T20:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Technical Support',
#     u'job_title': u'Technical Support Representative',
#     u'start_date': u'2009-10-11T20:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Teletech Management Phils.',
#     u'end_date': u'2009-09-29T20:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Technical Support',
#     u'job_title': u'Technical Support Representative',
#     u'start_date': u'2007-02-16T20:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3100: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Ama Group of Company',
#     u'end_date': u'2014-06-14T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'my responsibilities is to always find a positive buyer and make sure you have a knowledge about your project. And explain all the features about your project. Also, always treat your buyer special.',
#     u'job_title': u'PROPERTY CONSUTANT',
#     u'start_date': u'2013-05-07T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3101: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Green Global Solution',
#     u'end_date': u'2013-05-31T15:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Responsible to sell the product you are handling.. Get your costumers attention for them to be interested on what you are selling.Address all their concerns.',
#     u'job_title': u'Call Center Agent ( Outbound Representative )',
#     u'start_date': u'2012-10-31T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3134: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Extreme fitness center',
#     u'end_date': u'2013-10-31T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Front liner, attending to all guest needs & queries.\nAssist the gym-goers to their workout & develop an appropriate workout program for them.\nTo check & to operate electronic machines (i.e. Treadmill, stationary bike, & inverted machines etc.)\nBasic office administration, such as cashiering & daily sales report.',
#     u'job_title': u'Receptionist / gym instructor',
#     u'start_date': u'2011-05-15T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3142: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Toshiba Information Equipment Phil. Corporation',
#     u'end_date': u'2010-10-30T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Top Cover Cleaning and Removing the Seal-C',
#     u'job_title': u'Production Operator',
#     u'start_date': u'2010-05-24T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3143: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Telstra powered by Teletech',
#     u'end_date': u'2015-02-28T16:00:00.000Z',
#     u'industry': u'Customer Service',
#     u'job_title': u'Customer Service Representative',
#     u'start_date': u'2013-03-31T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100},
#    {u'company_name': u'Teleperformance',
#     u'end_date': u'2014-01-31T16:00:00.000Z',
#     u'industry': u'Customer Service',
#     u'job_title': u'Technical Support Representative',
#     u'start_date': u'2012-10-31T16:00:00.000Z',
#     u'type': 100},
#    {u'company_name': u'Convergys',
#     u'end_date': u'2013-09-30T16:00:00.000Z',
#     u'industry': u'Customer Service',
#     u'job_title': u'Customer Service Representative',
#     u'start_date': u'2010-09-30T16:00:00.000Z',
#     u'type': 100}]},
#  3144: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Pasig Catholic College',
#     u'end_date': u'2013-09-18T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'-\tCompleted 486 hours of Internship/ On-the-Job Training as per requirement for Graduation by Jose Rizal University\n\u2022\tTroubleshoots, upgrades, and repairs Computer Software and Hardware at computer laboratories, offices and departments.\n\u2022\tPerform other tasks as may assigned from time to time',
#     u'job_title': u'Technical Support Staff (Intern)',
#     u'start_date': u'2013-06-10T16:00:00.000Z',
#     u'still_work_here': False,
#     u'type': 100},
#    {u'company_name': u'BOJJ Construction & Interior Contractor',
#     u'end_date': u'2011-09-19T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'\u2022\tHandled Timekeeping and Prepares Payroll for construction site workers\n\u2022\tPrepared Daily Progress Report, Daily Weather Report, Monthly Progress Billing, Incident Reports, etc.\n\u2022\tPrepared Request for Quotation and Purchase Orders to the suppliers.\n\u2022\tPrepared correspondences to the Pasay City Government, suppliers and to the EDSES Administration. \n\u2022\tReceived correspondences as well as deliveries from the suppliers.\n\u2022\tPerformed other tasks as may assigned from time to time.',
#     u'job_title': u'Project Support Officer',
#     u'start_date': u'2011-04-06T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Monolith Construction & Development Corp.',
#     u'end_date': u'2010-02-18T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'\u2022\tSort files such as Reports, Correspondences, CERs, CFPs, Billings, Change Orders, Purchase Orders, blueprint of plans, etc\n\u2022\tReceived and delivered documents within the company and to its contractors, suppliers, government agencies, etc. \n\u2022\tEncoded data for Billing Monitoring, PO monitoring, Change Orders, etc. using Excel.\n\u2022\tPerformed other tasks as may assigned from time to time.',
#     u'job_title': u'Clerk/Messenger',
#     u'start_date': u'2008-06-06T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'A.G. Peralta Builders',
#     u'end_date': u'2006-06-09T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'\u2022\tHandled Timekeeping and Prepares Payroll for construction site workers\n\u2022\tIn-charge of supply and materials on warehouse.\n\u2022\tPrepared Daily Accomplishment Reports.',
#     u'job_title': u'Project Clerk',
#     u'start_date': u'2006-03-28T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  3154: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Straightarrow Corporation',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'Creating responsive Landing pages.\nCreating responsive HTML email campaigns.\nEnsuring all HTML email campaigns are rendering correctly in all major email client software before blasting.',
#     u'job_title': u'Web Developer Associate',
#     u'start_date': u'2014-06-01T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  3159: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Mcdonalds Company.',
#     u'end_date': u'2010-07-03T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Taking Orders of the customers.\nAssisting the customers.',
#     u'job_title': u'Service crew/ cashier',
# ...
#     u'end_date': u'2014-06-30T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'To ensure proper computer operations so that end\nusers can accomplish organizational tasks. This includes receiving, prioritizing,\ndocumenting and actively resolving end user help requests. Problem resolution may involve\nthe use of diagnostics and help request tracking tools, as well as require that the individual\ngive hands-on help at the desktop level.',
#     u'job_title': u'Technical Support Specialist',
#     u'start_date': u'2012-09-30T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  5890: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Jollibee',
#     u'end_date': u'2011-07-03T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Cleaning the dining area',
#     u'job_title': u'Jollibee Market Place',
#     u'start_date': u'2011-02-03T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  5891: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Holy Child Hospital Dumaguete City',
#     u'end_date': u'2009-11-23T12:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Assist admission and discharge of patients, take vital signs, assist during Intravenous insertion and removal. Perform other ward procedures such tube feeding and removal, sponge bath and tepid sponge bath, wound dressing, taking random blood sugar, inserting nasal cannula and  regulating, nebulization oxygen and other ward procedure as ordered by the doctor, take and send specimen for laboratory and lastly cater patients needs.',
#     u'job_title': u'Midwife/Nursing Aide',
#     u'start_date': u'2007-02-16T12:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Dr. Sulaiman Al Habib Medical Group Al Takhassusi',
#     u'end_date': u'2013-11-16T12:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Assist doctor in examining and performing procedures with the patients, do nurses notes, take vital signs and random blood sugar. Perform tympanometry, prepare and assist in endoscopy, audiogram, minor operations for ear, nose and throat, take and send specimen the laboratory, book and inform patients for any operation or laboratory test. Guide and assist patients needs.',
#     u'job_title': u'Nursing Assistant',
#     u'start_date': u'2011-11-16T12:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  5892: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Ready Call Center',
#     u'end_date': u'2014-05-18T06:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'To assist customers from the United States with mobile phone technicalities and also assist with the purchasing of phones or airtime cards.',
#     u'job_title': u'Customer Service Representative',
#     u'start_date': u'2014-02-13T06:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  5901: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'oDesk Online',
#     u'end_date': u'2014-08-01T06:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Freelancing including telemarketing, customer service, transcription, office assisting',
#     u'job_title': u'Online Freelancer',
#     u'start_date': u'2014-04-01T06:00:00.000Z',
#     u'still_work_here': False,
#     u'type': 100},
#    {u'company_name': u'Protel BPO',
#     u'end_date': u'2013-10-01T06:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Marketing, Sales & Customer Service',
#     u'job_title': u'Customer Interaction Specialist',
#     u'start_date': u'2013-06-01T06:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Transparent BPO',
#     u'end_date': u'2013-02-01T06:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Marketing, Sales & Customer Service',
#     u'job_title': u'Sales Agent',
#     u'start_date': u'2012-08-01T06:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  5904: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Atlas Max Marketing Corp.',
#     u'end_date': u'2009-03-10T04:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Selling Sim Cards and hit the quota.',
#     u'job_title': u'Direct Sales Agent',
#     u'start_date': u'2008-06-14T04:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  5906: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Excella Healthcare Services',
#     u'end_date': u'2014-08-10T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Helping geriatric patient/client to find physicians/consultants were they can make or have their consultation. Assist and/or address clients concern with their health problems and health promotion, medications, medical supplies and etc. Coordinates with the visiting nurse and pharmacist in order to address clients concern the soonest possible time. Make documentation every after calls and send reports to the managers after the shift.',
#     u'job_title': u'costumer service representative',
#     u'start_date': u'2013-09-22T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  5907: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Genesis Flower Shop',
#     u'end_date': u'1999-01-13T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'to clean the shop and make sure the high sale everyday and have a good connection with all costumer.',
#     u'job_title': u'Sales Clerck',
#     u'start_date': u'1998-01-13T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'The Gift Factory',
#     u'end_date': u'2000-01-28T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'make sure clean the shop before opening with hospitality to all the costumer',
#     u'job_title': u'Sales Lady',
#     u'start_date': u'1999-01-19T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Garment',
#     u'end_date': u'2000-09-14T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'to trim the fluff of cloths',
#     u'job_title': u'Trimmer',
#     u'start_date': u'2000-03-14T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Avon and Natasha Company',
#     u'end_date': u'2007-09-18T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'i offered in katalog and I convince her we have more beautiful products here in company. get the order and deliver it one by one then collect the payment and go buy the credit the company',
#     u'job_title': u'Independent Franchise Dealer',
#     u'start_date': u'2003-07-01T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'house',
#     u'end_date': u'2013-09-14T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'to taking care in and outside of this house and to take care the child as a guardian',
#     u'job_title': u'care taker and nanny',
#     u'start_date': u'2003-01-19T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  5912: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Zariba Ltd.',
#     u'end_date': u'2013-08-29T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'My tasks include the following:\n\n* creating test plans\n* creating use-cases \n* creating test case based on pre-made specification\n* lead QA Team\n* execute test cases\n* testing of various software products',
#     u'job_title': u'QA Engineer',
#     u'start_date': u'2013-01-31T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'PODD',
#     u'end_date': u'2012-11-29T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': None,
#     u'job_title': u'QA Specialist',
#     u'start_date': u'2011-02-28T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  5916: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'611 Global Services',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'I work as a chat support representative, recently promoted on May 2014.',
#     u'job_title': u'Senior Technical Chat Support Agent',
#     u'start_date': u'2013-01-30T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100}]},
#  5917: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Holy Child Hospital',
#     u'end_date': u'2011-09-23T12:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Assist patients during their admission and discharge, assist the doctor during ward rounds, take vital signs, perform and assist ward procedures such as nebulization, oxygen/ random blood sugar calibration,insertion of catheter and insertion/removal of IV (Intravenous), tubes and oral feeding for pedia patients, wound dressing, preparing the patients scheduled for operation. Collect and send specimen for laboratory test, keep the environment tidy and organize, train and orient new employee for the hospital routine. And above all cater and provide patients holistic care to the patients.',
#     u'job_title': u'Midwife/Nursing Aide',
#     u'start_date': u'2007-02-16T12:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Dr. Sulaiman Al Habib Medical Group',
#     u'end_date': u'2013-11-16T12:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Assist doctors in examining and performing procedure on patients such as endoscopy, biopsy, minor operation, of ENT ( Ear, Nose, Throat).Take vital signs, perform tympanometry and assist in audiogram. Collect/ submit specimen for laboratory, book patients for operation and other medical test.Instruct and orient the patient with the clinic flow and procedures done to them. Train and orient new employee, document patients data and other secretarial functions.',
#     u'job_title': u'Nursing Assistant',
#     u'start_date': u'2011-11-16T12:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  5918: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Seatrade Development Corporation',
#     u'end_date': u'1999-03-07T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'\u2022\tEncode Finished Products & Raw Materials using Fax Pro Software.\n\u2022\tPrepare Weekly and Monthly Production report.\n\u2022\tSubmit Report through email by the end of the month.',
#     u'job_title': u'Clerk/Encoder',
#     u'start_date': u'1998-09-30T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Philippine Charter Insurance Corp.',
#     u'end_date': u'2003-03-30T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'\u2022\tPrepare Fire, MotorCar, & Personal Accident Insurance policy. \n\u2022\tInspect buildings to be covered with fire insurance.\n\u2022\tPrepare Building and Motorcar Accident Inspection Report.\n\u2022\tIssue Certificate of Cover for MotorCar Insurance\n\u2022\tPrepare Monthly Production and Summary Report.\n\u2022\tBanking\n\u2022\tMarketing',
#     u'job_title': u'Clerk I/Underwriter',
#     u'start_date': u'2000-09-17T16:00:00.000Z',
#     u'still_work_here': False,
#     u'type': 100},
#    {u'company_name': u'Sunstar Davao Publishing',
#     u'end_date': u'2006-11-17T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'\u2022\tDevelop the market  within Socsksargen Area.\n\u2022\tReceive and record copies of newspapers and tabloids delivered from main office.\n\u2022\tReport to the General Manager the time of arrival and copies received from the main office.\n\u2022\tSupervise Newsboys in the delivery of copies to subscribers  advertisers and other complimentary copies recipients. \n\u2022\tRetrieve copies returned from dealers and news stands.\n\u2022\tPrepare daily orders of dealers.\n\u2022\tPrepare and submit reports.\n\u2022\tDistribution Report\n\u2022\tComparative Report\n\u2022\tCirculation Highlights',
#     u'job_title': u'Circulation In-charge',
#     u'start_date': u'2006-05-17T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Sykes Asia Inc.,',
#     u'end_date': u'2010-05-29T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': None,
#     u'job_title': u'Technical Support Representative',
#     u'start_date': u'2008-01-27T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Stream Global Services',
#     u'end_date': u'2012-04-28T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': None,
#     u'job_title': u'Technical Support Representative/Listener Care Representative',
#     u'start_date': u'2010-10-26T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Argis',
#     u'end_date': u'2013-05-22T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': None,
#     u'job_title': u'Chat Support/ Email Marketing Specialist for iContact',
#     u'start_date': u'2012-04-29T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Convergys Philippines',
#     u'end_date': u'2014-05-05T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': None,
#     u'job_title': u'Customer Care Representative',
#     u'start_date': u'2013-09-22T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  5919: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Perpetual Succour Hospital',
#     u'end_date': u'2013-01-31T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'\u2022\tPerform clinical laboratory test pertinent to blood banking, clinical chemistry, immunology, serology, hematology, microscopy (urinalysis, fecalysis and other body fluids) and histopathology.\n\u2022\tEvaluate quality control information against measurable data.\n\u2022\tSet up and maintain laboratory equipment.\n\u2022\tProper collection, transportation, handling and processing of test specimens.',
#     u'job_title': u'Medical Technologist Intern',
#     u'start_date': u'2012-10-31T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  5920: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'ePLDT-Ventus',
#     u'end_date': u'2009-07-01T07:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Service provider of dish network/ cable channels',
#     u'job_title': u'CSR',
#     u'start_date': u'2009-03-01T08:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  5921: {u'no_work_experience': False,
#   u'work_history': [{u'company_name': u'Chikka Philippines Inc.',
#     u'end_date': None,
#     u'industry': None,
#     u'job_desc': u'Develop design concepts and solutions for better User Experience both on Mobile and Web devices. Create Wireframes, pixel-perfect mockups and Integrate it to code with the use of HTML, CSS and Sass, Wordpress CMS, Basic PHP and Javascripting.',
#     u'job_title': u'UI Design and Visual Associate',
#     u'start_date': u'2013-12-01T16:00:00.000Z',
#     u'still_work_here': True,
#     u'type': 100},
#    {u'company_name': u'Ripplewerkz Inc',
#     u'end_date': u'2013-06-02T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Create high quality website mockups for sites like ecommerce and corporate.',
#     u'job_title': u'Web Designer',
#     u'start_date': u'2012-12-16T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'Moonline Inc.',
#     u'end_date': u'2012-12-13T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u'Responsible for creating email newsletter, integrate psd design to html and css.\nEditing visual images for content. Designing social media banner ads such as facebook, yahoo, twitter and google.',
#     u'job_title': u'Web Designer/Junior Content Officer',
#     u'start_date': u'2011-10-02T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100},
#    {u'company_name': u'iSnap Creatives Inc.',
#     u'end_date': u'2011-05-30T16:00:00.000Z',
#     u'industry': None,
#     u'job_desc': u"Event Photographer, Design graphic for marketing collaterals. Maintain company's website, Design high quality mockups for web and integrate it to front end.",
#     u'job_title': u'Multimedia Designer',
#     u'start_date': u'2010-07-18T16:00:00.000Z',
#     u'still_work_here': None,
#     u'type': 100}]},
#  ...}

# %%
def extract_fields_of_study(data):
    fields_map = {}
    for ID, educ in data.items():
        fields_map[ID] = ' / '.join(educ['education']['fields_of_study'])
    return fields_map

course_data = extract_fields_of_study(uid_course_data)

# %%
def extract_work_history(data, key='job_title'):
    def extract_single(map_list):
        return map(lambda item: item[key],filter(lambda item: key in item and item[key], map_list))
    fields_map = {}
    for ID, mapper in data.items():
        fields_map[ID] = ' / '.join(extract_single(mapper['work_history']))
    return fields_map

job_title_data = extract_work_history(uid_industry_data, 'job_title')

# %%
def merge_dicts(a, b):
    res = {}
    for key in a:
        if key in b:
            res[key] = (a[key], b[key])
    for key in b:
        if key in a:
            res[key] = (a[key], b[key])
    return res

course_job_title_data = merge_dicts(course_data, job_title_data).values()

# %%
def encode(data):
    return [s.encode('ascii', 'ignore') if isinstance(s, unicode) or isinstance(s, str) else '' for s in data]

courses, job_titles = zip(*course_job_title_data)
courses = encode(courses)
job_titles = encode(job_titles)

# %%
from cleaning import clean

clean_courses = clean(courses, style='course')
clean_job_titles = clean(job_titles, style='job title')

# %%
clean_data = zip(clean_courses, clean_job_titles)

# %%
clean_data
# Out:
# [('COMMERCE / MANAGEMENT', 'INVENTORY OFFICER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'CREW MEMBER / FOOD SERVER'),
#  ('APPLIED SOCIOLOGY',
#   'PROJECT MANAGER / RESEARCH ASSOCIATE / TECHNICAL STAFF & COMMUNICATIONS OFFICER / RESEARCH ASSOCIATE & CONSULTANT / RESEARCH ASSOCIATE / TECHNICAL ASSISTANT / TECHNICAL ASSISTANT'),
#  ('ACCOUNTING SCHOLARSHIP', 'ACCOUNTS PAYABLE STAFF'),
#  ('TOURISM GEOGRAPHY', 'BARISTA / CUSTOMER SERVICE REPRESENTATIVE'),
#  ('BUSINESS ENTREPRENEURSHIP',
#   'CUSTOMER SERVICE REPRESENTATIVE / TECHNICAL SUPPORT REPRESENTATIVE'),
#  ('BUSINESS ADMINISTRATION',
#   'SALES COORDINATOR / BILLING CLERK / CALL CENTER AGENT'),
#  ('CHEMICAL ENGINEERING',
#   'PROCESS DESIGN ENGINEER / CONTRACTUAL PROCESS DESIGN ENGINEER'),
#  ('NURSING',
#   'STAFF NURSE / ICU & SURGICAL STAFF NURSE / CUSTOMER SERVICE REPRESENTATIVE / QUALITY ASSURANCE ANALYST'),
#  ('COMPUTER SCIENCES', 'HEAD INFORMATION TECHNOLOGY'),
#  ('OFFICE MANAGEMENT',
#   'PHARMACY ASSISTANT & CASHIER / ACCOUNTING STAFF & CASHIER'),
#  ('AUTO DIESEL MECHANIC', 'HEAVY DUTY MECHANICAL'),
#  ('CRIMINAL PROCEDURE',
#   'CUSTOMER RELATIONS MANAGER SM AURA / LEGAL & INTELLIGENCE / ASSISTANT MANAGER FOR PROCUREMENT / COLLEGE PROFESSOR / SECURITY & INTELLIGENCE VIP / VOICE OFFICER'),
#  ('EDUCATION', 'TUTOR'),
#  ('PHYSICAL THERAPY',
#   'LEAD GENERATION SPECIALIST / COLLECTIONS AGENT / TELEMARKETER / SUPERVISOR / OUTBOUND AGENT / CUSTOMER SERVICE AGENT TRAINEE / OUTBOUND AGENT / OUTBOUND / INBOUND AGENT / FORESTER / LEAD GENERATION AGENT / OUTBOUND AGENT / SENIOR OUTBOUND AGENT / SENIOR OUTBOUND AGENT / QUALITY ASSURANCE AGENT'),
#  ('COMPUTER SECRETARIAL', 'CASHIER / CASHIER'),
#  ('ELEMENTARY EDUCATION', 'TEACHER / TEACHER / TEACHER / ADMISSION OFFICE'),
#  ('INDUSTRIAL ENGINEERING', 'PRODUCTION ENGINEER'),
#  ('BUSINESS ADMINISTRATION / ING MARKETING', 'PIT MANAGER / FONTANA'),
#  ('COMPUTER SCIENCE',
#   'EDUCATION / TEACHER / EDUCATION / TEACHER / MAIN SAFE OFFICER CASH DEPARTMENT / BACK OFFICE STAFF'),
#  ('MASS COMMUNICATION',
#   'HOMEBASED E EDUCATION / CUSTOMER SERVICE AGENT / CUSTOMER SERVICE AGENT / UNIVERSAL CUSTOMER SERVICE AGENT / SUPERVISOR'),
#  ('INFORMATION TECHNOLOGY', 'ADMIN OFFICER'),
#  ('ACCOUNTANCY', 'ACCOUNTING ASSOCIATE / BOOKKEEPER / ACCOUNTANT'),
#  ('ACCOUNTING', 'BANK OPERATIONS ASSISTANT'),
#  ('COMPUTER SCIENCES',
#   'DATABASE ADMINISTRATOR / PROJECT MANAGER / MANAGER SYSTEMS & DATABASE ADMINISTRATOR / DATABASE ADMINISTRATOR NETWORK SUPPORT / LOCALE DBA PROGRAMMER / SYSTEMS & PROCEDURES ASSISTANT'),
#  ('INFORMATION TECHNOLOGY', 'COMPUTER TECHNICIAN / COMPUTER TECHNICIAN'),
#  ('NURSING EDUCATION', 'ENUMERATOR'),
#  ('INFORMATION TECHNOLOGY', 'GRAPHIC ARTIST / INFORMATION TECHNOLOGY'),
#  ('BUSINESS ADMINISTRATION',
#   'CHANNEL ACCOUNT MANAGER / GENERAL BUSINESS EXECUTIVE'),
#  ('INFORMATION TECHNOLOGY', 'PROGRAMMER'),
#  ('INFORMATION TECHNOLOGY',
#   'INSTRUMENTATION & CONTROL TECHNICIAN / MANAGEMENT INFORMATION SYSTEM'),
#  ('INDUSTRIAL TECHNOLOGY', 'INSTRUMENT TECHNICIAN'),
#  ('COMPUTER PROGRAMMING', 'SERVICE CREW'),
#  ('COMPUTER ENGINEERING',
#   'DATA ENTRY / OFFICE CLERK / CIMS & I TOS OPERATOR / DOCUMENT CONTROLLER / PRESS MACHINE OPERATOR / MESSENGER'),
#  ('POLITICAL SCIENCE', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('COMMERCIAL ELECTRONIC SERVICE',
#   'MUAY THAI KICK BOOKING INSTRUCTOR / MUAY THAI KICK BOOKING INSTRUCTOR / MUAY THAI KICK BOOKING INSTRUCTOR / MUAY THAI KICK BOOKING INSTRUCTOR / PIZZA COOK ASSISTANT / PIZZA COOK ASSISTANT'),
#  ('COMPUTER ENGINEERING', 'REGIONAL COMPUTER TECHNICIAN TECHNICAL SUPPORT'),
#  ('CIVIL ENGINEERING', 'A / P OFFICER'),
#  ('TOURISM GEOGRAPHY', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('PHILOSOPHY EDUCATION EDUCATIONAL MANAGEMENT',
#   'PRINCIPAL / EXECUTIVE DIRECTOR / PART TIME UNIVERSITY LECTURER / PROJECT MANAGER CONSULTANT / SENIOR SPECIALIST / HEAD FLEXIBLE LEARNING SOLUTIONS / TEACHER PERSONAL INFORMATION COORDINATOR'),
#  ('TEACHING', 'SECONDARY SCHOOL TEACHER I'),
#  ('COMPUTER PROGRAMMING',
#   'CUSTOMER SERVICE REPRESENTATIVE / TECHNICAL SUPPORT REPRESENTATIVE / CUSTOMER SERVICE ASSISTANT B'),
#  ('COMPUTER SCIENCES', 'WEB DESIGNER / WEB DEVELOPER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'BARISTA'),
#  ('COMPUTER PROGRAMMING', 'SERVICE CREW'),
#  ('TOURISM GEOGRAPHY', 'LIFEGUARD / SENIOR ACCOUNT SPECIALIST'),
#  ('COMPUTER PROGRAMMING TECHNICIAN',
#   'SENIOR INFORMATION TECHNOLOGY / QUALITY ASSURANCE OL'),
#  ('DENTISTRY',
#   'MEDICAL TRANSCRIPTIONIST / MEDICAL TRANSCRIPTIONIST / MEDICAL TRANSCRIPTIONIST / MEDICAL TRANSCRIPTIONIST / DENTAL ASSISTANT'),
#  ('BUSINESS ADMINISTRATION', 'ACCOUNTING CLERK'),
#  ('PHILOSOPHY',
#   'LANE IN CHARGE / JOURNALIST TRAINEE / MERCHANDISER REVIEWER / PRODUCT BUILDER / AREA SALES COORDINATOR REVIEWER'),
#  ('ACCOUNTANCY', 'PAYROLL OFFICER / SENIOR COLLECTIONS SPECIALIST'),
#  ('BUSINESS ADMINISTRATION / MANAGEMENT', 'TELEPHONE OPERATOR'),
#  ('CHEMICAL ENGINEERING', 'TECHNICAL WASHING / DINING MANAGER'),
#  ('NURSING', 'VOLUNTEER NURSE / FIELD INTERVIEWER / TEAM SUPERVISOR'),
#  ('PSYCHOLOGY', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('NURSING', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('JOURNALISM', 'ADMIN SUPPORT STAFF TRAINEE'),
#  ('GENERAL SCIENCE', 'TEACHER'),
#  ('COMPUTER SCIENCES', 'RECEPTIONIST'),
#  ('INFORMATION TECHNOLOGY', 'DATA ENCODER'),
#  ('ACCOUNTANCY', 'TRADE & INDUSTRY DEVELOPMENT SPECIALIST'),
#  ('EDUCATION', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('ELEMENTARY EDUCATION',
#   'TEACHER / CUSTOMER SERVICE REPRESENTATIVE / TEACHER'),
#  ('INFORMATION TECHNOLOGY', ''),
#  ('ACCOUNTANCY', 'ACCOUNTING STAFF'),
#  ('ALTERNATIVE EDUCATION', 'CUSTOMER SERVICE'),
#  ('ADVERTISING PUBLIC RELATIONS / MARKETING',
#   'BRANCH MARKETING MANAGER / CUSTOMER SERVICE REPRESENTATIVE / ACCOUNT OFFICER'),
#  ('MASS COMMUNICATION', 'COPYEDITOR'),
#  ('INFORMATION TECHNOLOGY', 'TEAMLEADER'),
#  ('ELEMENTARY EDUCATION / SPECIAL EDUCATION',
#   'TEACHER ADVISER / TUTOR / SPED TEACHER / SUBSTITUTE TEACHER'),
#  ('INFORMATION TECHNOLOGY', 'WEB DEVELOPER'),
#  ('ARCHITECTURE', 'CAD OPERATOR'),
#  ('HOTEL RESTAURANT MANAGEMENT',
#   'FRONT OFFICE SUPERVISOR / SALES EXECUTIVE / EXECUTIVE ASSISTANT / TELEPHONE OPERATOR / SALES & RESERVATION OFFICER / FRONT OFFICE STAFF / CUSTOMER SERVICE AGENT EXPEDIA / BARISTA'),
#  ('MANAGEMENT ACCOUNTING',
#   'CUSTOMER SERVICE REPRESENTATIVE / LOANS PROCESS ASSOCIATE / MANAGER TRAINEE / DATA ANALYST SENIOR ASSOCIATE / SME DATA ANALYST EXECUTIVE / SHIFT LEAD AT BILLING & FEES MANAGEMENT EXECUTIVE'),
#  ('COMMUNICATION STUDIES', 'HRT MEMBER'),
#  ('JOURNALISM MEDIA STUDIES COMMUNICATION', 'PUBLIC RELATIONS OFFICER'),
#  ('ARCHITECTURE', 'PROJECT ARCHITECT / REGISTERED & LICENSED ARCHITECT'),
#  ('INFORMATION TECHNOLOGY', 'DATA ENTRY OPERATOR / DATA PROCESS'),
#  ('COMPUTER SCIENCE', 'OJT'),
#  ('COMPUTER SCIENCES',
#   'INFORMATION TECHNOLOGY ASSOCIATE / INFORMATION TECHNOLOGY SUPPORT ENGINEER / INFORMATION TECHNOLOGY OPERATION TEAM LEAD / INTERNAL INFORMATION TECHNOLOGY SUPPORT'),
#  ('EDUCATION', 'TEACHER'),
#  ('SECONDARY EDUCATION / TLE', 'STOCK CLERK'),
#  ('ELECTRONIC ENGINEERING', 'SERVICE TECHNICIAN / AUTOMOTIVE ELECTRICIAN'),
#  ('COMMUNICATION STUDIES', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('INFORMATION TECHNOLOGY', 'ADMINISTRATIVE STAFF / TECHNICAL SUPPORT'),
#  ('MECHANICAL ENGINEERING',
#   'TRAINING ASSISTANT / SHIFT SUPERVISOR / APPLICATION ENGINEER'),
#  ('ELECTRONIC ENGINEERING',
#   'TEST PROCESS ENGINEER / PROCESS ENGINEER / PART TIME FACULTY'),
#  ('COMPUTER TECHNICIAN',
#   'TECHNICAL SUPPORT REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE / TECHNICAL SUPPORT PROFESSIONAL II / OBJECT MASTER EXPERT / CUSTOMER SERVICE REPRESENTATIVE / SALES SUPERVISOR'),
#  ('POLITICAL SCIENCE', 'CASHIER / RECEPTIONIST'),
#  ('MANAGEMENT ACCOUNTING', 'ACCOUNTING STAFF'),
#  ('MARKETING', 'GENERAL MANAGER'),
#  ('CULINARY', 'FOOD PREPARER'),
#  ('BUSINESS MANAGEMENT', 'OFFICE CLERK'),
#  ('CHEMISTRY EDUCATION', 'TEACHER'),
#  ('ENTREPRENEURSHIP',
#   'CORPORATE ACCOUNTS OFFICER / CORPORATE ACCOUNTS TEAM LEADER / JUNIOR NEW ACCOUNTS TELLER'),
#  ('INFORMATION TECHNOLOGY', 'TECHNICAL SUPPORT'),
#  ('ECONOMICS', 'CONGRESSIONAL STAFF'),
#  ('POLITICAL SCIENCE',
#   'ADMIN & MARKETING OFFICER / JOB ORDER COMPLETION / TRIMMER / CUSTOMER SERVICE REPRESENTATIVE'),
#  ('CHEMISTRY', 'CLASSROOM TEACHER'),
#  ('COMPUTER SCIENCE', 'DOCUMENT CONTROLLER / WAREHOUSE ASSISTANT'),
#  ('CULINARY ARTS',
#   'CUSTOMER SERVICE REPRESENTATIVE / VIRTUAL ASSISTANT / VIRTUAL ASSISTANT / VIDEO MAKER FX'),
#  ('PRACTICAL NURSING', 'ESL TEACHER'),
#  ('ELEMENTARY EDUCATION TEACHING / THE EARLY GRADES', 'TEACHER'),
#  ('CRIMINOLOGY / CRIMINAL JUSTICE',
#   'CUSTOMER SERVICE REPRESENTATIVE / AREA MANAGER / DISTRIBUTORS / MANAGER'),
#  ('COMMUNITY NUTRITION',
#   'CHIEF DIETITIAN / NUTRITIONIST DIETITIAN I / THERAPEUTIC DIETITIAN / SHOP SUPERVISOR'),
#  ('BUSINESS ADMINISTRATION / MANAGEMENT', 'STUDENT INTERN'),
#  ('COMMERCE', 'SALES COORDINATOR / SALES ASSOCIATE'),
#  ('FOODSERVICE MANAGEMENT',
#   'CUSTOMER SERVICE ASSOCIATE / CUSTOMER SERVICE REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE / CUSTOMER CARE REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE / FINANCIAL ADVISOR'),
#  ('BUSINESS ADMINISTRATION',
#   'INFORMATION SERVICES ANALYST / SENIOR TECHNICAL ANALYST / SERVICE DESK SUPERVISOR / DESKTOP SYSTEMS SPECIALIST / TEAM LEADER / CUSTOMER SERVICE REPRESENTATIVE / TECHNICAL SUPPORT AGENT / INFORMATION TECHNOLOGY ASSISTANT / HUMAN RESOURCES CLERK'),
#  ('HUMAN RESOURCES', 'OPERATIONS SPECIALIST IV'),
#  ('ACCOUNTANCY',
#   'GENERAL ACCOUNTING SUPERVISOR / SENIOR ACCOUNTANT / ACCOUNTING STAFF / BRANCH ACCOUNTANT BANK CASHIER SENIOR TELLER ASSISTANT SUPERVISOR / SUPERVISOR STAFF'),
#  ('SOCIOLOGY', 'ON THE JOB TRAINEE'),
#  ('MARINE ENGINEERING', 'BAKER / WAITER'),
#  ('CIVIL ENGINEERING',
#   'WATER & WASTEWATER DESIGN ENGINEER / PRACTICE TRAINEE / CIVIL ENGINEERING ASSISTANT'),
#  ('COMPUTER SCIENCE', 'TECHNICAL SUPPORT STAFF'),
#  ('APPLIED PHILOSOPHY',
#   'OWNER / COMPUTER TECHNICIAN / PURCHASER / SECRETARY / PURCHASING SUPERVISOR / STORE SUPERVISOR / PURCHASING SUPERVISOR & ADMIN ASSISTANT / PURCHASER & ADMIN ASSISTANT / PRODUCT SPECIALIST / MARKETING SPECIALIST'),
#  ('POLITICAL SCIENCE', 'SENIOR ACCOUNT MANAGER'),
#  ('COMPUTER SCIENCES',
#   'TECHNICAL SUPPORT ASSOCIATE / TECHNICAL SUPPORT REPRESENTATIVE / BILLING ANALYST / BILLING ANALYST / SALES COORDINATOR / TECHNICAL SUPPORT REPRESENTATIVE'),
#  ('MARINE TRANSPORTATION', 'RESTAURANT WAITER'),
#  ('DEVELOPMENT COMMUNICATION', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('INFORMATION TECHNOLOGY', 'ANALYST'),
#  ('INFORMATION TECHNOLOGY', 'BRANCH MANAGER'),
#  ('PSYCHOLOGY',
#   'GUIDANCE COUNSELOR / PUBLISHING SALES CONSULTANT / FIELD OFFICER'),
#  ('INFORMATION TECHNOLOGY',
#   'CUSTOMER SERVICE ASSOCIATE / DOCUMENTATION ASSISTANT'),
#  ('MECHANICAL ENGINEERING', 'OPERATIONS SUPERVISOR'),
#  ('HOTEL RESTAURANT INSTITUTION MANAGEMENT', 'ENCODER / LEASE ASSISTANT'),
#  ('COMMERCE', 'HEAD'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'PRODUCTION OPERATOR'),
#  ('NURSING', 'MARKETING MANAGER SALES MAN BUSINESS'),
#  ('ECONOMICS PUBLIC ADMINISTRATION',
#   'CUSTOMER SERVICE REPRESENTATIVE / IN HOUSE PROPERTY CONSULTANT / FREELANCE / SALES CATERING COORDINATOR'),
#  ('INFORMATION TECHNOLOGY', 'STORE SUPERVISOR'),
#  ('ELEMENTARY EDUCATION',
#   'TEACHER / TEACHER IN NURSE / SECRETARY OF VPAA VICE PRESIDENT / TEACHER'),
#  ('INDUSTRIAL EDUCATION / COMPUTER EDUCATION', 'FINANCE PERSONNEL'),
#  ('BUSINESS EDUCATION', 'CHEMICAL'),
#  ('PHILOSOPHY / SOCIAL SCIENCE', 'ON THE JOB TRAINING'),
#  ('COMPUTER SCIENCE', 'SERVICE CREW'),
#  ('APPLIED PHYSICS', 'STUDENT RESEARCHER / LECTURER / TUTOR'),
#  ('COMPUTER COMMUNICATIONS NETWORKS', 'RECEIVING INCHARGE'),
#  ('NURSING', 'ENGLISH INSTRUCTOR / HR GENERALIST / ASST HR MANAGER'),
#  ('CLINICAL PSYCHOLOGY', 'VARIOUS POSITIONS'),
#  ('COMMERCE / MANAGEMENT', 'TEACHER AIDE / DOMESTIC HELPER'),
#  ('TOURISM',
#   'RECEPTIONIST / HAIR STYLIST / ACCOUNT SPECIALIST / SALES EXECUTIVE / MANAGER / FRANCHISE DEALER / EXECUTIVE SECRETARY / MARKETING OFFICER / MERCHANDISER / PROMODIZER'),
#  ('BUSINESS ADMINISTRATION / FINANCIAL MANAGERIAL ACCOUNTING',
#   'DEPARTMENT SUPERVISOR'),
#  ('INFORMATION TECHNOLOGY', 'SALES STAFF / ENCODER'),
#  ('INDUSTRIAL MANAGEMENT ENGINEERING / INFORMATION TECHNOLOGY',
#   'SEO LINK SPECIALIST'),
#  ('PUBLIC ADMINISTRATION', 'ADMINISTRATIVE AIDE'),
#  ('EDUCATION', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('HOSPITALITY RESTAURANT SERVICES', 'TELEPHONE OPERATOR'),
#  ('POLITICAL ECONOMY', 'ADMINISTRATION SUPERVISOR'),
#  ('CIVIL ENGINEERING', 'MASON'),
#  ('INDUSTRIAL ENGINEERING', 'INTERN'),
#  ('COMPUTER HARDWARE SERVICING NC II', 'INSTALLER'),
#  ('NURSING', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('HOTEL RESTAURANT MANAGEMENT',
#   'SERVICE CREW / STORE IN CHARGE / SUPERVISOR'),
#  ('NURSING', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('NURSING', 'MEDICAL TRANSCRIPTIONIST'),
#  ('BUSINESS ADMIN / MARKETING',
#   'INTERNAL / INTERNAL COMMUNICATIONS & CUSTOMER SERVICE REPRESENTATIVE ON THE JOB TRAINEE'),
#  ('INFORMATION TECHNOLOGY',
#   'INFORMATION TECHNOLOGY STAFF / DATA ENTRY PERSONNEL'),
#  ('HUMAN RESOURCES', 'ACCOUNT MANAGEMENT OFFICER'),
#  ('ELEMENTARY EDUCATION', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('COMPUTER SCIENCE', 'FRONT END DEVELOPER'),
#  ('BUSINESS ADMINISTRATION', 'REAL TIME ANALYST'),
#  ('GEODETIC ENGINEERING', ''),
#  ('BUSINESS', 'TECHNICAL PROFESSIONAL 2'),
#  ('AGRIBUSINESS', 'FIELD RESEARCHER'),
#  ('MAN / MEDICAL SURGICAL NURSING', 'CLINICAL INSTRUCTOR'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'CATERING & CONFERENCE COORDINATOR'),
#  ('FOOD BEV SERVICES', 'SERVICE CREW'),
#  ('BUSINESS ADMINISTRATION',
#   'BANK TELLER / AP ANALYST / FINANCE ASSOCIATE / SHIFT MANAGER / ASST CAFE MANAGER TRAINEE'),
#  ('INFORMATION TECHNOLOGY',
#   'MERCHANDISER / LARGE FOREMAN PAINTER OPERATOR / GRAPHIC DESIGNER'),
#  ('ELEMENTARY EDUCATION', 'CASHIER / TEACHER'),
#  ('BUSINESS ADMINISTRATION', 'AVP / BRANCH MANAGER'),
#  ('JOURNALISM MEDIA STUDIES COMMUNICATION',
#   'MARKETING STAFF / GENERAL BUSINESS SALES EXECUTIVE / ACCOUNT EXECUTIVE'),
#  ('NURSING', 'PROJECT COORDINATOR SUPPORT'),
#  ('BUSINESS ADMINISTRATION', 'FINANCE ASSISTANT'),
#  ('HEALTH CARE SERVICES', 'PRODUCTION OPERATOR'),
#  ('ACCOUNTANCY',
#   'GENERAL MANAGER / INVENTORY MANAGER / GENERAL MANAGER / ACCOUNTING SUPERVISOR / ACCOUNTING SUPERVISOR'),
#  ('PSYCHOLOGY',
#   'SENIOR ADMINISTRATIVE OFFICER / BILLER TEACHER & GYMNASTICS COACH'),
#  ('BUSINESS ADMINISTRATION', 'COORDINATOR'),
#  ('OR ARTS / PSYCHOLOGY',
#   'SENIOR SOURCING SPECIALIST FOR ASIA PACIFIC / SENIOR RECRUITMENT CONSULTANT / HR ADMINISTRATOR'),
#  ('BIOLOGY', 'CONSULTANT'),
#  ('ACCOUNTANCY',
#   'CORPORATE ACCOUNTANT / INTERNAL AUDIT ASSOCIATE / INTERNAL AUDIT STAFF / PROPERTY ACCOUNTANT'),
#  ('MATHEMATICS / COMPUTER SCIENCE',
#   'SECURITY ADMINISTRATOR FOR DATA & INFRASTRUCTURE / SECURITY ADMINISTRATOR FOR SUCCESS CONTROL / INFORMATION TECHNOLOGY SERVICE DELIVERY STAFF / CUSTOMER SERVICE ASSOCIATE TELLER'),
#  ('BIOLOGY',
#   'EXECUTIVE SECRETARY / OFFICE ADMINISTRATOR / SECTION SUPERVISOR / COMPUTER / TALISMAN OPERATOR / MEDICAL REPORTS ADMINISTRATOR / BRANCH MANAGER'),
#  ('COMPUTER HARDWARE SERVICING', 'SALES CLERK'),
#  ('DEVELOPMENT STUDIES', 'HUMAN RESOURCES MANAGER'),
#  ('STATISTICS', 'INTERN'),
#  ('COMPUTER SCIENCES', 'RESIDENT ARTIST'),
#  ('MICROBIOLOGY', 'MICROBIOLOGIST / QA ANALYST'),
#  ('COMPUTER OFFICE MANAGEMENT', 'TELEMARKETING'),
#  ('INFORMATION TECHNOLOGY',
#   'INFORMATION TECHNOLOGY STAFF INTERNSHIP / TECHNICAL SUPPORT ENGINEER / TECHNICAL SALES ENGINEER'),
#  ('INFORMATION TECHNOLOGY', 'SECURITY OFFICER'),
#  ('BUSINESS ADMINISTRATION', 'PRODUCTION ASSISTANT'),
#  ('MASS COMMUNICATION', 'OPERATIONS MANAGER / SECRETARY / SECRETARY'),
#  ('INDUSTRIAL DESIGN PRODUCT',
#   'QUALITY MANAGEMENT SENIOR ASSOCIATE / SENIOR QUALITY ASSURANCE ANALYST / QUALITY ASSURANCE ANALYST / CUSTOMER SERVICE REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE / GRAPHIC ARTIST'),
#  ('BUSINESS ADMINISTRATION', 'FINANCE OFFICER'),
#  ('OFFICE MANAGEMENT', 'CASHIER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'WAITRESS / BANQUET BEVERAGE ATTENDANT'),
#  ('INFORMATION TECHNOLOGY', 'SCAFFOLDER'),
#  ('NURSING', 'PROFESSIONAL MEDICAL REPRESENTATIVE'),
#  ('INFORMATION TECHNOLOGY', 'OFFICE STAFF / ENCODER'),
#  ('INFORMATION TECHNOLOGY', 'SOFTWARE ENGINEER / SOFTWARE QA ANALYST'),
#  ('BUSINESS ADMINISTRATION', 'ENGINE TEACHER'),
#  ('TOURISM', 'INTERN / INTERN / INTERN CORPORATE AFFAIRS'),
#  ('BUSINESS ADMINISTRATION', 'MARKETING ASSISTANT / MARKETING ASSISTANT'),
#  ('MIDWIFERY', 'ACCOUNTING STAFF'),
#  ('NURSING', 'MARKETING COORDINATOR / MEDICAL SPECIALIST REPRESENTATIVE'),
#  ('BUSINESS ADMINISTRATION', 'TEAM LEADER'),
#  ('SOFTWARE DEVELOPMENT', 'AUTOCAD OPERATOR ENCODER / COMPUTER COSTUDIAN'),
#  ('ENVIRONMENTAL SCIENCE', 'STUDENT AIDE'),
#  ('INFORMATION TECHNOLOGY', 'CLOUD SECURITY ENGINEER'),
#  ('SECONDARY EDUCATION', 'CUSTOMER SERVICE'),
#  ('NURSING', 'NURSE / NURSE'),
#  ('INFORMATION TECHNOLOGY', 'TECHNICAL SUPPORT'),
#  ('TRANSLATION STUDIES',
#   'CUSTOMER SERVICE REPRESENTATIVE / TECHNICAL SUPPORT REPRESENTATIVE'),
#  ('ELECTRONIC ENGINEERING',
#   'DESKTOP SUPPORT / CHAT SUPPORT REPRESENTATIVE / ENCODER STAFF'),
#  ('COMPUTER SYSTEMS TECHNOLOGY',
#   'WORKFORCE CAPACITY ANALYST ASSISTANT MANAGER / WORKFORCE SPECIALIST / WORKFORCE ANALYST AETNA / GLOBAL WORKFORCE MANAGEMENT SPECIALIST I / GLOBAL WORKFORCE MANAGEMENT SPECIALIST II / MATERIAL ENABLER CHECK / HACKER'),
#  ('COMPUTER ENGINEERING TECHNOLOGY', 'DUCT FITTER / DUCT FITTER'),
#  ('BUSINESS ADMINISTRATION', 'ACCOUNT OFFICER / SUPERVISOR'),
#  ('ELECTRONIC ENGINEERING', 'PRODUCT TEST ENGINEER'),
#  ('INFORMATION TECHNOLOGY',
#   'DESKTOP SUPPORT ENGINEER / INFORMATION TECHNOLOGY SPECIALIST / DESKTOP SUPPORT ENGINEER'),
#  ('FOODSERVICE MANAGEMENT',
#   'SERVICE CREW / CASHIER & WAITRESS / CASHIER & SERVER / SHIFT MANAGER'),
#  ('MECHANICAL ENGINEERING', 'LABORATORY STUDENT ASSISTANT'),
#  ('OS SCIENCE / OFFICE ADMINISTRATION',
#   'TECHNICAL SUPPORT REPRESENTATIVE / COUNTER CASHIER / PRODUCT ASSISTANT / COUNTER IN CHARGE'),
#  ('COMMUNICATION ARTS / MASS COMMUNICATION',
#   'CUSTOMER SERVICES MANAGER / QUALITY ANALYSTS SUPERVISOR / LEVEL'),
#  ('FINE ARTS',
#   'WEB SUPPORT SPECIALIST / EBAY FRAUD SPECIALIST / GRAPHIC DESIGN'),
#  ('INFORMATION TECHNOLOGY', 'OFFICE STAFF'),
#  ('NURSING', 'TUTOR'),
#  ('BROADCAST COMMUNICATION',
#   'ACCOUNT MANAGER MANAGEMENT / SALES & SERVICE REPRESENTATIVE 2 / ENGLISH AS A SECOND LANGUAGE / ESL TEACHER / ENGLISH AS A FOREMAN LANGUAGE / EFL TEACHER FREE LANCE / INSTRUCTOR'),
#  ('INFORMATION TECHNOLOGY', 'QA TESTER'),
#  ('BUSINESS ADMINISTRATION / FINANCIAL ACCOUNTING',
#   'ORDER TO CASH JUNIOR ANALYST'),
#  ('INFORMATION TECHNOLOGY', ''),
#  ('CREATIVE ARTS', 'SALES & MARKETING MANAGER'),
#  ('SECONDARY EDUCATION', 'VIRTUAL ASSISTANT / TUTOR'),
#  ('COMPUTER SCIENCE', 'OFFICE ASSISTANT / EXECUTIVE ASSISTANT / SECRETARY'),
#  ('BUSINESS ADMINISTRATION',
#   'ASSISTANT MANAGER / FLOOR ATTENDANT / LAWN CARE ATTENDANT'),
#  ('MASS COMMUNICATION', 'CUSTOMER SERVICE REP / CUSTOMER SERVICE REP'),
#  ('INFORMATION SYSTEMS BUSINESS INFORMATICS',
#   'AUSTRALIAN COUNTER PROCESS EXPERT DISPUTE'),
#  ('BUSINESS ECONOMICS', 'JOB ORDER'),
#  ('BROADCAST COMMUNICATION',
#   'SALES TRAINING & APAC RESOURCE MANAGER / APAC SALES SUPPORT MANAGER / RECOGNITION MANAGER / INDEPENDENT REPRESENTATIVE ASSISTANT MANAGER / SALES SUPPORT PROGRAM SPECIALIST / BRANCH SALES TRAINER / DOMESTICS CABIN CREW'),
#  ('LIBERAL ARTS / POLITICAL SCIENCE', 'SCHOOL TEACHER'),
#  ('INFORMATION TECHNOLOGY', 'PROGRAMMER'),
#  ('COMMUNICATION ARTS / MASS COMMUNICATION',
#   'CUSTOMER SERVICE AGENT / RETAIL SHOP SPECIALIST'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'PRODUCTION CREW'),
#  ('MARKETING MANAGEMENT',
#   'FEMALE OFFICE STAFF / ACCOUNTING CLERK / APPRAISER'),
#  ('ACCOUNTING', 'INTERN'),
#  ('ENTREPRENEURSHIP', 'CASHIER'),
#  ('INFORMATION TECHNOLOGY', 'OJT TRAINEE'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'MARKET RESEARCHER / RECEPTIONIST'),
#  ('MARINE ENGINEER', 'ENGINE CADET'),
#  ('BUSINESS ADMINISTRATION / MARKETING MANAGEMENT',
#   'CUSTOMER SERVICE REPRESENTATIVE / ACCOUNTING CLERK / BOOKKEEPERS AUDIT'),
#  ('OFFICE ADMINISTRATION', 'EXECUTIVE SECRETARY'),
#  ('ENGLISH', 'CUSTOMER SERVICE REPRESENTATIVE / CHAT SUPPORT'),
#  ('BANKING FINANCE', 'MARKETING ASSISTANT / CALL CENTER AGENT'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'DECK ATTENDANT'),
#  ('NURSING', 'ENGINE ENGLISH TUTOR'),
#  ('SPECIAL EDUCATION', 'SPECIAL EDUCATION COORDINATOR / SCHOOL TEACHER'),
#  ('INFORMATION TECHNOLOGY',
#   'CUSTOMER SERVICE REPRESENTATIVE / SALES REPRESENTATIVE / TECHNICAL SUPPORT REPRESENTATIVE 2'),
#  ('APPLIED PSYCHOLOGY', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('MARKETING MANAGEMENT',
#   'MARKETING INTERN TRADE DEPT / MARKETING INTERN SALES & OPERATIONS DEPT / RAMP AGENT / MARKETING INTERN GALAS QC BRANCH'),
#  ('STANDARD ENGLISH', 'SECONDARY SCHOOL TEACHER'),
#  ('COMMERCE', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('COMPUTER TECHNOLOGY', '2ND ASSISTANT MANAGER'),
#  ('BUSINESS ADMINISTRATION', 'GENERAL SALES ASSISTANT'),
#  ('HEALTH SCIENCES', 'INTERN MD'),
#  ('COMPUTER PROGRAMMING / COMPUTER SECRETARIAL', 'SECRETARY'),
#  ('PSYCHOLOGY',
#   'VOLUNTEER STAFF / CUSTOMER SERVICE REPRESENTATIVE / JUNIOR SUPERVISOR / CUSTOMER SERVICE REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE / EVENT PLANNER / ENGINE ENGLISH TUTOR / TEACHER'),
#  ('BUSINESS INFORMATION MANAGEMENT', 'SALE STAFF'),
#  ('OFFICE ADMINISTRATION',
#   'LISTENER CARE REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE'),
#  ('NURSING', 'STAFF NURSE'),
#  ('BUSINESS ADMINISTRATION', 'CENTER PARTNER / CEO / MANAGING DIRECTOR'),
#  ('INFORMATION TECHNOLOGY', 'SOCIAL MEDIA MANAGER'),
#  ('INFORMATION TECHNOLOGY', 'SYSTEMS OPERATOR / INTERN'),
#  ('BUSINESS',
#   'MANAGEMENT TRAINEE / STUDENT DJ / MARKETING INTERN / CHURN MARKETING INTERN INTERIOR MANAGER POSITION'),
#  ('COMPUTER SECRETARIAL', 'SECRETARY'),
#  ('BUSINESS ADMINISTRATION',
#   'PROPERTY SPECIALIST / SALES PROFESSIONAL / TECHNICAL SUPPORT REPRESENTATIVE'),
#  ('ART MANAGEMENT', 'FASHION DESIGNER'),
#  ('EDUCATION', 'TUTOR'),
#  ('COMPUTER PROGRAMMING', 'CHECK'),
#  ('COMPUTER SCIENCE',
#   'ACCOUNT OFFICER / CREDIT & COLLECTION ASST / DOCS SPECIALIST'),
#  ('COMPUTER SCIENCE', 'DATA TRANSITION PROCESS'),
#  ('ECONOMICS', 'ACCOUNT EXECUTIVE / OFFICER IN CHARGE RESTAURANT MANAGER'),
#  ('COMPUTER ENGINEERING', 'POST ACCOUNT DATA ENTRY'),
#  ('COMPUTER ENGINEERING',
#   'EXECUTIVE SECRETARY / HR OFFICER / SECRETARY / RECEPTIONIST / PURCHASER / SALES SECRETARY / ADMINISTRATION OFFICER / JUNIOR SPECS PROGRAMMER / ADMIN OFFICER'),
#  ('INFORMATION TECHNOLOGY', 'SALES CLERK'),
#  ('COMPUTER PROGRAMMING NCII', 'PRODUCTION CREW'),
#  ('BUSINESS ADMINISTRATION', 'QUALITY ANALYST / APPROVER'),
#  ('POLITICAL SCIENCE', 'OFFICE CLERK JOB ORDER'),
#  ('CIVIL ENGINEERING',
#   'SECTION SUPERVISOR / TRUCKING SUPERVISOR / PRODUCTION SUPERVISOR'),
#  ('CRIMINOLOGY / CRIMINAL JUSTICE', 'INSTRUCTOR'),
#  ('COMPUTER SECRETARIAL', 'SALESLADY'),
#  ('BUSINESS ADMINISTRATION', 'ADMIN ASSISTANT'),
#  ('CIVIL ENGINEERING',
#   'TEAM LEADER / ARCHITECTURAL COORDINATOR / CADD OPERATOR / SITE ENGINEER'),
#  ('PROGRAMMING', 'OFFICE STAFF'),
#  ('HEALTH CARE SERVICES', 'SALES LADY'),
#  ('INDUSTRIAL PSYCHOLOGY', 'CASHIER'),
#  ('MACHINE SHOP', 'MIXER DETECTION MACHINE OPERATOR BUILDING DIE TECH GENDER'),
#  ('INFORMATION TECHNOLOGY',
#   'TIME HELPER / SERVICE CREW / PROPERTY CUSTODIAN / SALES AGENT / SALES REPRESENTATIVE'),
#  ('COMMERCE / BANKING FINANCE', 'CASHIER'),
#  ('BUSINESS ADMINISTRATION', 'BRANCH SECRETARY / STORE MERCHANDISING'),
#  ('EDUCATION / FOOD TRADES', 'PURCHASER & ENCODER'),
#  ('NURSING', 'PROPERTY CONSULTANT / TECHNICAL SUPPORT REPRESENTATIVE'),
#  ('ELECTRONICS COMMUNICATIONS ENGINEERING',
#   'PLC COMPUTER / SCADA / CONTROL ROOM OPERATOR / PLC COMPUTER / SCADA / CONTROL ROOM OPERATOR'),
#  ('AGRICULTURAL ENGINEERING', 'FIELD COLLECTOR'),
#  ('BOOKKEEPING COMPUTER', 'LIAISON OFFICER'),
#  ('COMMUNICATION ARTS', 'SEGMENT PRODUCT WRITER EDITOR'),
#  ('COMPUTER TECHNOLOGY', 'ACCOUNT OFFICER'),
#  ('COMPUTER PROGRAMMING', 'DATA CODING / PRODUCTION OPERATOR / STAFF'),
#  ('AUTO DIESEL TECHNOLOGY', 'SERVICE TECHNICIAN / SERVICE TECHNICIAN'),
#  ('PSYCHOLOGY',
#   'CLIENT TECHNICAL SUPPORT ASSOCIATE / OBJECT MASTER EXPERT / OBJECT MASTER EXPERT'),
#  ('COMPUTER SCIENCES',
#   'PROGRAMMER / COMPUTER OPERATOR / INFORMATION TECHNOLOGY OPERATIONS SPECIALIST / SOFTWARE DEVELOPER / TECHNICAL SUPPORT SPECIALIST'),
#  ('ARCHITECTURE',
#   'PROJECT SUPERVISOR / ESTIMATOR / CONTRACT ARCHITECT / BOOKING BUSINESS'),
#  ('KINESIOLOGY / EXERCISE SCIENCE / HUMAN PERFORMANCE',
#   'SUPERVISOR / PROJECT MANAGER / SUPERVISOR / FACILITIES MANAGER / DELIVERY & ASSEMBLY TECHNICIAN'),
#  ('COMPUTER SCIENCE', 'INTERNATIONAL SALES EXECUTIVE'),
#  ('PUBLIC ADMINISTRATION',
#   'TECHNICAL SUPPORT REPRESENTATIVE / TECHNICAL SUPPORT REPRESENTATIVE'),
#  ('BUSINESS ADMINISTRATION', 'DEPARTMENT STORE COUNTER CHECK'),
#  ('BUSINESS ADMINISTRATION', 'OFFICE CLERK'),
#  ('PSYCHOLOGY', 'MARKETING OFFICER / MARKETING & SALES ASSISTANT'),
#  ('ELECTRICAL ENGINEERING', 'MAINTENANCE EQUIPMENT TECHNICIAN'),
#  ('COMPUTER TECHNICIAN', 'FACTORY WORKER'),
#  ('MARKETING MANAGEMENT',
#   'STUDENT TRAINEE / MARKETING & LINKAGES COMMITTEE SPONSORSHIP'),
#  ('AIRCRAFT MAINTENANCE TECHNOLOGY', 'COSTUMER SERVICE REPRESENTATIVE'),
#  ('INFORMATION TECHNOLOGY', 'FIELD COORDINATOR / SAFETY OFFICER'),
#  ('HOTEL RESTAURANT MANAGEMENT',
#   'SERVICE CREW / CUSTOMER SERVICE REPRESENTATIVE'),
#  ('BUSINESS ADMINISTRATION', 'SALES CLERK / STORE SUPERVISOR'),
#  ('NURSING', 'TECHNICAL SUPPORT REPRESENTATIVE'),
#  ('BUSINESS ADMINISTRATION', 'FINANCIAL ADVISOR / INTERN / SERVICE CREW'),
#  ('COMPUTER ENGINEERING',
#   'SOLUTIONS DELIVERY ENGINEER / SOURCING QUALITY ENGINEER'),
#  ('MANAGEMENT / FINANCIAL INSTITUTIONS',
#   'FINANCE SPECIALIST / FINANCIAL ADVISOR / TREASURY ASSOCIATE'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'MANUFACTURING OPERATOR'),
#  ('NURSING EDUCATION',
#   'CASHIER GUEST RELATIONS OFFICER WAITRESS SALES AGENT TEAM LEADER'),
#  ('INFORMATION TECHNOLOGY', 'EMPLOYEE'),
#  ('HUMAN RESOURCES', ''),
#  ('FISHERIES / FISH PROCESSING', 'QUALITY CONTROL INSPECTOR'),
#  ('ELECTRONICS COMMUNICATIONS ENGINEERING', 'OFFICE STAFF'),
#  ('INFORMATION TECHNOLOGY', 'INTERN'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'MESSMAN'),
#  ('INFORMATION TECHNOLOGY', 'PHP BACK END DEVELOPER INTERN'),
#  ('COMMUNICATION', 'CUSTOMER CARE ASSOCIATE'),
#  ('MASS COMMUNICATION', 'CHANNEL MARKETING & PARTNER ACQUISITION SPECIALIST'),
#  ('ACCOUNTANCY',
#   'ENGINE TEACHER / CUSTOMER SERVICE REPRESENTATIVE / TECHNICAL SUPPORT REPRESENTATIVE / FLOOR SUPPORT / LIVE CHAT / GLOBAL COMMUNITY CHAMPION / CUSTOMER RELATIONS OFFICER'),
#  ('LAGUNA / BUSINESS ARTS',
#   'OPERATIONS TRAINING ASSISTANT / FACILITIES & CONTRACT MANAGEMENT STAFF / TELLER / TRANSACT ANALYST'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'WAITRESS'),
#  ('INFORMATION TECHNOLOGY',
#   'TECHNICAL SUPPORT REP 1 / PHOTO AGENT / DOCUMENT SPECIALIST / PROOF LEADERS / ACCOUNT EXECUTIVES / HR CLERK / PRODUCTION OPERATOR / Q A'),
#  ('MECHANICAL ENGINEERING', 'SALES CREW / CASHIER / OIC'),
#  ('BUSINESS ADMINISTRATION',
#   'RESEARCH SPECIALIST / RESEARCH ANALYST / INTERN'),
#  ('NURSING', 'HUMAN RESOURCE ASSISTANT'),
#  ('MARKETING MANAGEMENT', 'SALES AGENT'),
#  ('INFORMATION TECHNOLOGY', 'GRAPHIC DESIGNER'),
#  ('WEB APPLICATION DEVELOPMENT',
#   'CUSTOMER SERVICE REPRESENTATIVE / PRODUCTION STAFF / SK CHAIRMAN'),
#  ('BUSINESS ADMINISTRATION', 'PRODUCTION SECRETARY / ADMIN ASST'),
#  ('COMMUNICATION ARTS / MASS COMMUNICATION',
#   'SOURCING MANAGER / SR TALENT ACQUISITION SPECIALIST / SR RECRUITMENT SPECIALIST / CUSTOMER SERVICE REPRESENTATIVE / TEAM MANAGER'),
#  ('BUSINESS ADMINISTRATION', 'MARKETING MANAGER / MARKETING INTERN'),
#  ('COMPUTER ENGINEERING', 'DATA ENCODER & INVENTORY STAFF'),
#  ('TECHNICAL AUTOMOTIVE', 'QC INSPECTOR / QC TANK INSPECTOR / QC INSPECTOR'),
#  ('INFORMATION TECHNOLOGY', 'BUSINESS ASSOCIATE'),
#  ('COMPUTER SCIENCE',
#   'MEAT PROCESS / BUTCHERING CUT MAN / COMPUTER TECHNICIAN & CONSULTANT'),
#  ('XPAC / COREL DRAW WEB STUDIO PHOTOSHOP',
#   'ADMIN ASSISTANT / GRAPHIC ARTIST / SHOP SUPERVISOR / GRAPHIC ARTIST / GRAPHIC ARTIST / MAINTENANCE CUSTODIAN / GRAPHIC ARTIST / GRAPHIC ARTIST'),
#  ('POLITICAL SCIENCE',
#   'EDUCATION SECRETARY & PROGRAM OFFICER / SEXUAL & GENDER BASED VIOLENCE INTERN / MEDIA SERVER / JOURNALIST & RADIO ANCHOR'),
#  ('INFORMATION TECHNOLOGY', 'SECRETARY / SECRETARY'),
#  ('SEAFARERS RATING COARSE', 'BAKER'),
#  ('COMPUTER ENGINEERING',
#   'SOFTWARE & HARDWARE TECHNOLOGIST ENGINEER / FREELANCE AUTOCAD / DATA CONTROLLER / PROGRAMMER'),
#  ('OFFICE ADMINISTRATION', 'LOANS COORDINATOR'),
#  ('CRIMINOLOGY / CRIMINAL JUSTICE', 'CASHIER & PUMP ATTENDANT'),
#  ('INFORMATION TECHNOLOGY', 'FLIERS'),
#  ('COMPUTER SCIENCE', 'PROJECT OFFICER'),
#  ('CAREGIVING', 'ADS & PROMO CLERK / SERVICE CREW'),
#  ('TOURISM', 'DOCUMENTATION CLERK / ADMIN ASSISTANT'),
#  ('ECONOMICS', 'MANAGING DIRECTOR'),
#  ('ACCOUNTANCY', 'REVENUE AUDITOR'),
#  ('INFO MANAGEMENT', 'OFFICE SECRETARY'),
#  ('DATA MANAGEMENT', 'OFFICE CLERK'),
#  ('ELECTRONIC ENGINEERING', 'CASHIER'),
#  ('COMPUTER ENGINEERING',
#   'SYSTEMS & NETWORK ADMINISTRATOR / SOFTWARE TESTER OJT'),
#  ('BAKING PASTRY', 'PORTER AS ONCALL / BUTCHER'),
#  ('AUTOMOTIVE TECHNOLOGY', 'SECURITY GUARD'),
#  ('COMPUTER SCIENCE', 'PROJECT MANAGER'),
#  ('INFORMATION TECHNOLOGY', 'WEB DESIGNER / FRONT END'),
#  ('BUSINESS ADMINISTRATION', 'HR & ADMIN MANAGER'),
#  ('COMPUTER TECHNICIAN',
#   'COMPUTER TECHNICIAN / NETWORK & COMPUTER TECHNICIAN'),
#  ('AGRIBUSINESS', 'COUNTRY FARM SUPERVISOR'),
#  ('SPEECH COMMUNICATION',
#   'CAMPUS COORDINATOR / JUNIOR RECRUITMENT CONSULTANT / SOURCING ASSOCIATE / ENGLISH LANGUAGE SCREENER'),
#  ('BUSINESS ADMINISTRATION', 'AREA APPRAISER'),
#  ('COMMERCE', 'ACCOUNT EXECUTIVE'),
#  ('MARKETING MANAGEMENT',
#   'CUSTOMER SERVICE REPRESENTATIVE / DATA ENTRY OPERATOR / WEB HOSTING SPECIALIST'),
#  ('CLINICAL PSYCHOLOGY', 'BEHAVIOR THERAPIST'),
#  ('COMMUNICATION ARTS / MASS COMMUNICATION', 'COLLEGE FACULTY / ESL TUTOR'),
#  ('INFORMATION TECHNOLOGY',
#   'PATIENT BUSINESS STAFF / NETWORK SUPPORT ASSOCIATE'),
#  ('FINANCE', 'CREDIT & COLLECTION ASSISTANT'),
#  ('INFORMATION TECHNOLOGY', 'REMOTE INFRASTRUCTURE MANAGEMENT BOOTCAMP'),
#  ('MAJORS / BEHAVIORAL SCIENCE BUSINESS MANAGEMENT',
#   'SME / CSAT COACH / INSURANCE AGENT / SME / CSAT COACH / MORTGAGE ANALYST / SME / ADVANCED CUSTOMER SERVICE REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE / CLIENT EXECUTIVE / ACCOUNT EXECUTIVE'),
#  ('POLITICAL SCIENCE', 'GENERAL MANAGER & MANAGING DIRECTOR'),
#  ('COMPUTER TECHNOLOGY', 'HACKER'),
#  ('NURSING',
#   'GUEST SERVICE AGENT / CALL CENTER AGENT / FRONT OFFICE ASSOCIATE / CLINICAL NURSE'),
#  ('EUROPEAN LANGUAGES',
#   'QUALITY ASSURANCE TECHNICAL WRITER / MULTILINGUAL RESEARCH ANALYST SENIOR ASSOCIATE / RESEARCH ANALYST SPANISH / ENGINE ENGLISH TUTOR / PROJECT BASED CUSTOMER SERVICE REPRESENTATIVE SALES'),
#  ('MATHEMATICS SCIENCE TEACHING',
#   'EXECUTIVE ASSISTANT / SALES SECRETARY / TRAINING COORDINATOR'),
#  ('ELECTRICAL ENGINEERING TECHNOLOGY', 'ELECTRICAL TECHNICIAN'),
#  ('ELECTRONICS COMPUTER TECHNOLOGY',
#   'ASSEMBLER / INSPECTOR / FACTORY WORKER / TELE MARKETING / SALES ASSOCIATE / CASHIER / LOGISTIC COORDINATOR / BRANCH PERSONNEL / HR ASSISTANT'),
#  ('NURSING', 'DIRECTOR OF STUDENT AFFAIRS / CLINICAL INSTRUCTOR'),
#  ('BUSINESS ADMINISTRATION', 'SERVICE CREW'),
#  ('BUSINESS MANAGEMENT', 'ENGINE MARKETING SALES STAFF / RECEPTIONIST'),
#  ('INFORMATION TECHNOLOGY', 'SYSTEM DESIGNER ASSISTANT PROGRAMMER'),
#  ('OFFICE ADMINISTRATION',
#   'ENGLISH TUTOR / CUSTOMER SERVICE REPRESENTATIVE / ETHERNET CIRCUIT PROVISIONER'),
#  ('BUSINESS ADMINISTRATION',
#   'INTERN FOR ANALYTICS & COMMERCIAL EFFECTIVENESS DEPARTMENT'),
#  ('ACCOUNTANCY',
#   'ACCOUNTING ASSISTANT / COMMERCIAL STAFF / ACCOUNTING ASSISTANT'),
#  ('AGRICULTURAL ENGINEERING', 'ASSISTANT STORE MANAGER'),
#  ('NURSING', 'ACCOUNT MANAGER'),
#  ('HOTEL RESTAURANT SERVICES', 'SALESLADY'),
#  ('COMPUTER SECRETARIAL', 'CREDIT & COLLECTIONS STAFF / OFFICE STAFF'),
#  ('VALUES EDUCATION', 'SERVICE CREW'),
#  ('COMPUTER SCIENCES',
#   'CUSTOMER SERVICE REPRESENTATIVE CASHIER ENCODER SUPERVISOR'),
#  ('BIOLOGY', 'PHARMAACY ASSISTANT / MERCHANDISER'),
#  ('ADVERTISING PUBLIC RELATIONS', 'INTERN / INTERN'),
#  ('BUSINESS ADMINISTRATION', 'CASHIER / PROPERTY SPECIALIST'),
#  ('BUSINESS ECONOMICS', 'WAREHOUSE STAFF / DATA ENCODER'),
#  ('COMMUNICATIONS TECHNOLOGY MANAGEMENT', 'COMMUNITY MANAGER'),
#  ('APPLIED PSYCHOLOGY', 'ADVERTISING & PROMOTION STAFF'),
#  ('INFORMATION TECHNOLOGY', 'PHP DEVELOPER / PHP DEVELOPER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'PROMODISER / SALES ASSISTANT'),
#  ('MANAGEMENT INFORMATION SYSTEMS', 'RESEARCH DEPARTMENT INTERN'),
#  ('SOCIAL SCIENCES', 'HR ASSOCIATE'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'TELE SERVICE REPRESENTATIVE / MANAGER'),
#  ('BUSINESS ADMINISTRATION', 'SERVICE CREW'),
#  ('DEVELOPMENT COMMUNICATION', 'INSTRUCTOR I / ADMINISTRATIVE OFFICER IV'),
#  ('COMPUTER ENGINEERING', 'WRITER'),
#  ('COMPUTER SCIENCE', 'SECRETARY'),
#  ('ADVERTISING',
#   'COLLEGE INSTRUCTOR / FREELANCE ILLUSTRATOR COPY WRITER LAYOUT ARTIST'),
#  ('MECHANICAL ENGINEERING', 'PART TIMER'),
#  ('HUMAN ECOLOGY',
#   'JUNIOR ACCOUNT MANAGER / EXECUTIVE SECRETARY / ABSTRACTOR'),
#  ('FOODSERVICE MANAGEMENT',
#   'MACHINE OPERATOR / PROPERTY CONSULTANT / HEALTH COUNSELOR / MARKETING PROFESSIONAL'),
#  ('MASS COMMUNICATION',
#   'RESEARCHER SPECIAL PROJECT COORDINATOR / CORPORATE COMMUNICATIONS OFFICER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'FASHION CONSULTANT / FINANCIAL CONSULTANT'),
#  ('BUSINESS ADMINISTRATION', 'EXECUTIVE ASSISTANT'),
#  ('BIOLOGY', 'HIGH SCHOOL TEACHER / COLLEGE INSTRUCTOR'),
#  ('BUSINESS ADMINISTRATION / HUMAN RESOURCE', 'OFFICE WORK'),
#  ('E MATHEMATICS', 'SERVICE CREW / FOODCOURT CREW / FOODCOURT CREW'),
#  ('ELECTRICAL ENGINEERING', 'FOREMAN ELECTRICAL'),
#  ('INFORMATION TECHNOLOGY', 'DATA ENCODER / WEB DESIGNING DEVELOPING'),
#  ('PSYCHOLOGY MARKETING MANAGEMENT',
#   'TRADE MARKETING REPRESENTATIVE / KEY ACCOUNTS MANAGER'),
#  ('FOOD BEVERAGE', 'SERVICE CREW / MASSAGE THERAPHYS'),
#  ('ACCOUNTANCY', ''),
#  ('MASS COMMUNICATION',
#   'HR ASSOCIATE / QUALITY ASSURANCE / QUALITY ASSURANCE / EBAY COACH / ADMIN STAFF / ACCOUNTING STAFF'),
#  ('FINANCIAL ACCOUNTING', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('COMMERCE / BUSINESS MANAGEMENT', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('NURSING', 'DISPUTES SPECIALIST / SENIOR RECRUITER'),
#  ('INFORMATION TECHNOLOGY', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('ENGLISH LINGUISTICS LITERATURE', 'TRAVEL EXECUTIVE'),
#  ('BUSINESS ADMINISTRATION',
#   'COLLECTIONS / CUSTOMER SERVICE REP / CUSTOMER SERVICE & OFFICE ADMINISTRATOR / CUSTOMER SERVICE OFFICE MANAGER'),
#  ('SOCIOLOGY',
#   'TRAVEL TRAINER / CLIENT SERVICES REPRESENTATIVE II / STORE MANAGER'),
#  ('INFORMATION TECHNOLOGY', ''),
#  ('COMPUTER SCIENCE',
#   'E COMMERCE ASSOCIATE / SEM COORDINATOR / SENIOR PPC SPECIALIST / SENIOR PPC SPECIALIST'),
#  ('INFORMATION TECHNOLOGY',
#   'TECHNICAL SUPPORT REPRESENTATIVE / TRAINING & QUALITY COORDINATOR / TECHNICAL SUPPORT REPRESENTATIVE / QUALITY ASSURANCE REPRESENTATIVE / QUALITY ASSURANCE ANALYST / TEAM LEADER / BACK OFFICE'),
#  ('FOOD BEVERAGE', 'ESL TEACHER'),
#  ('APPLIED MATHEMATICS',
#   'DATA PROCESS / ADMINISTRATIVE AIDE / COLLEGE INSTRUCTOR'),
#  ('TOURISM MANAGEMENT',
#   'ENGLISH TEACHER / GENERAL MANAGER / LANGUAGE INSTRUCTOR'),
#  ('BROADCAST COMMUNICATION', 'PROJECT SPECIALIST'),
#  ('TARLAC STATE UNIVERSITY', 'PRODUCTION MANAGEMENT TRAINEE'),
#  ('EDUCATION',
#   'SENIOR PERSONNEL SPECIALIST / TEAM HEAD PUBLICATION & MEDIA RELATIONS DIVISION / PROJECT OFFICER III POLICY RESEARCH OFFICE'),
#  ('PHILIPPINE STUDIES',
#   'FREELANCE SEO WRITER / MARKETING ASSISTANT / OPERATIONS MANAGER & CONSULTANT'),
#  ('CRIMINOLOGY', 'SALES CLERK'),
#  ('COGNITIVE PSYCHOLOGY',
#   'CUSTOMER SERVICE REPRESENTATIVE / GUIDANCE COUNSELOR'),
#  ('COMPUTER SECRETARIAL', 'MASSAGE THERAPIST'),
#  ('INFORMATION TECHNOLOGY',
#   'REPORTS ANALYST / CUSTOMER SERVICE REPRESENTATIVE / TECHNICAL SUPPORT REPRESENTATIVE'),
#  ('SOCIOLOGY',
#   'NAIL TECHNICIAN / NAIL TECHNICIAN / RETENTION / DENTAL ASSISTANT'),
#  ('BUSINESS ADMINISTRATION',
#   'EDITOR & DATA SPECIALIST / WEB RESEARCHER / ADMINISTRATIVE ASSISTANT'),
#  ('BUSINESS ADMINISTRATION / MANAGEMENT ACCOUNTING',
#   'ADMINISTRATIVE JUNIOR SUPERVISOR'),
#  ('HOTEL RESTAURANT MANAGEMENT',
#   'RESTAURANT TEAM MEMBER / LOCAL STORE MARKETING'),
#  ('HOME ECONOMICS', 'SITE CLERK'),
#  ('CHEMICAL ENGINEERING', 'ON THE JOB TRAINEE'),
#  ('ORGANIZATIONAL COMMUNICATION', ''),
#  ('APPLIED PSYCHOLOGY', 'ASSISTANT TEACHER'),
#  ('INFORMATION TECHNOLOGY', 'HEALTH CONSULTANT'),
#  ('COMPUTER SCIENCE', 'COLLEGE INSTRUCTOR / ASSISTANT REGISTRY'),
#  ('NURSING',
#   'TALENT COORDINATOR / EXECUTIVE ASSISTANT / REAL ESTATE VA / HARD MONEY LEADERS ASSISTANT / GAME TESTER / HR MANAGER / QA MANAGER / STAFFING COORDINATOR / QA / PERSONAL ASSISTANT / SECRETARY / VIRTUAL ASSISTANT / CALL CENTER AGENT'),
#  ('BUSINESS ADMINISTRATION',
#   'ADMINISTRATIVE ASSISTANT / ADMINISTRATIVE ASSISTANT'),
#  ('PSYCHOLOGY', ''),
#  ('MUSIC EDUCATION',
#   'PURCHASING AGENT / SUBSTITUTE TEACHER / CUSTOMER SERVICE / SALES REPRESENTATIVE'),
#  ('EMERGENCY MEDICAL TECHNICIAN BASIC', 'HEMODIALYSIS NURSE'),
#  ('BIOLOGY', 'ENGINE WRITER / LEAD RESEARCHER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'BARISTA / BARISTA / DC OFFICER'),
#  ('INFORMATION TECHNOLOGY',
#   'SENIOR ACCOUNT SPECIALIST / TECHNICAL SUPPORT REPRESENTATIVE / SALES REPRESENTATIVE'),
#  ('HEALTHCARE SCIENCE', 'DENTAL HEALTH TECHNICIAN / JANITORIAL DUTIES'),
#  ('EDUCATION', 'TEACHER / TECHNICAL SERVICE REPRESENTATIVE'),
#  ('AGRICULTURE', 'GUEST SERVICE OFFICER'),
#  ('CRIMINOLOGY', 'CREDIT VERIFIERS / CUSTOMER SERVICE OFFICER'),
#  ('POLITICAL SCIENCE',
#   'COPYEDITOR / HOME BASED ENGINE ENGLISH TUTOR / ADMINISTRATIVE ASSISTANT'),
#  ('NURSING', 'FREELANCE SEO CONTENT WRITER / HEAD WRITER'),
#  ('COMPUTER TECHNOLOGY',
#   'STUDENT SUPPORT REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE'),
#  ('INDUSTRIAL ENGINEERING', 'QUALITY ASSURANCE'),
#  ('NURSING',
#   'CUSTOMER SERVICE & SALES REPRESENTATIVE / TECHNICAL SUPPORT SPECIALIST / FINANCIAL ADVISOR / CUSTOMER SERVICE SPECIALIST'),
#  ('BUSINESS ADMINISTRATION',
#   'WAREHOUSE ASSISTANT / INTERNAL CONTROL OFFICER / ROOM ATTENDANT & KITCHEN CREW'),
#  ('AHRM', 'WAITER / WAITER'),
#  ('COMPUTER SCIENCES',
#   'GLOBAL INNOVATIONS HEAD / DIRECTOR OF DEVELOPMENT / WEB TEAM LEAD / ARCHITECT / SENIOR PHP DEVELOPER / PHP DEVELOPER / FREELANCE WEB APPLICATION DEVELOPER / DIRECTOR OF TECHNOLOGY AVP / SENIOR NETWORK ADMIN / WEB DEVELOPER / LINUX SYSTEMS ADMINISTRATOR / NETWORK ADMINISTRATOR / WEB DEVELOPER'),
#  ('COMPUTER SECRETARIAL', 'RECEPTIONIST'),
#  ('COMPUTER TECHNOLOGY', 'DATA CONTROLLER'),
#  ('CE COMPUTER INFORMATION MANAGEMENT TECHNOLOGY',
#   'ADMINISTRATIVE / LOGISTIC ASST / ADMINISTRATIVE / LOGISTICS ASST'),
#  ('PSYCHOLOGY', 'INTERN / TRAINEE'),
#  ('SOCIAL SCIENCES NURSING',
#   'PROJECT ASSISTANT IV / COACH / CONSULTANT / RESEARCH CONSULTANT / SEO / CONTENT WRITER'),
#  ('COMMERCE',
#   'CASH CLERK / DOCUMENT EXAMINER / BUDGETING ASSISTANT / RESERVE OFFICER TRAINING CORPS ROTC INSTRUCTOR / SHIFT IN CHARGE / DETACHMENT COMMANDER / AGENT INVESTIGATOR / DETACHMENT COMMANDER / AREA COMMANDER / DETACHMENT COMMANDER / ASSOCIATE SECURITY OFFICER AGENT CONTRACT / RIGHT OF WAY OFFICER AGENT CONTRACT'),
#  ('MARKETING MANAGEMENT', 'AGENT / AGENT / AGENT / SALES CLERK'),
#  ('MANAGEMENT ACCOUNTING', 'PRODUCT DEMONSTRATOR'),
#  ('NURSING', 'ENGINE MEDICAL DATA ENTRY PROFESSIONAL'),
#  ('BUSINESS ADMINISTRATION', 'SENIOR WEB DEVELOPER'),
#  ('INFORMATION TECHNOLOGY', 'ON THE JOB TRAINING'),
#  ('NURSING',
#   'NICU STAFF NURSE / MEDICAL SURGICAL NURSE / MATERIAL & CHILD STAFF NURSE / NICU STAFF NURSE'),
#  ('ENGLISH', 'ASST BRANCH MANAGER'),
#  ('COMMUNICATION ARTS',
#   'BACK OFFICE CUSTOMER SERVICE ASSOCIATE SEASONAL / PERSONAL BANKING SPECIALIST / CUSTOMER SERVICE REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE'),
#  ('COMPUTER NETWORK ADMINISTRATION', 'NETWORK ADMINISTRATOR'),
#  ('BUSINESS ADMINISTRATION',
#   'HUMAN RESOURCES ADMIN OFFICER / AREA SUPERVISOR / MARKETING STAFF'),
#  ('BUSINESS ADMINISTRATION',
#   'CLIENT SERVICE ASSOCIATE / CUSTOMER SERVICE REPRESENTATIVE'),
#  ('MANAGEMENT ACCOUNTING', 'BILLING ASSOCIATE'),
#  ('NURSING', 'ESL ENGLISH AS SECOND LANGUAGE TEACHER / NURSE'),
#  ('TOURISM', 'COUNTER CHECK / RECEPTIONIST'),
#  ('EDUCATION', 'RISK OPERATIONS ANALYST'),
#  ('ELECTRICAL ENGINEERING', 'ELECTRICAL ENGINEER'),
#  ('MASS COMMUNICATION',
#   'CREATIVE DIRECTOR / VIDEO PRODUCTION / PRODUCTION INTERN'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'HR / ADMIN ASSISTANT'),
#  ('INTERNATIONAL STUDIES', 'MANAGER'),
#  ('MASS COMMUNICATION', 'INTERN'),
#  ('ART EDUCATION', 'PRODUCTION OPERATOR / TEAM MEMBER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'FRONT DESK OFFICER'),
#  ('COMMUNICATION STUDIES', 'CONSULTANT / TECHNICAL SUPPORT REPRESENTATIVE'),
#  ('NURSING',
#   'RESEARCH ANALYST / ENUMERATOR / SURVEYOR / RESEARCHER / NURSING ASSISTANT / PRIVATE DUTY NURSE / PHARMACY ASSISTANT'),
#  ('MECHANICAL ENGINEERING TECHNOLOGY', 'MARKETING OFFICER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'ENGINE MASON DEALER'),
#  ('BUSINESS ADMINISTRATION',
#   'LABORATORY HEAD PHOTOGRAPHER LAYOUT ARTIST SALES STAFF / SALESMAN / SALES EXECUTIVE / SALES PROMOTER PRODUCT CONSULTANT'),
#  ('STATISTICS', 'VICE PRESIDENT FOR EXTERNALS / LYFE PROJECT PARTICIPANT'),
#  ('POLITICAL SCIENCE', 'PARALEGAL / EXECUTIVE ASSISTANT'),
#  ('HOTEL RESTAURANT MANAGEMENT',
#   'CUSTOMER SERVICE REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE'),
#  ('OFFICE ADMINISTRATION', 'INTERN / INTERN'),
#  ('COMPUTER SCIENCE',
#   'TECHNICAL SUPPORT ANALYST / TECHNICAL SUPPORT REPRESENTATIVE / CUSTOMER CARE REPRESENTATIVE / TECHNICAL & HELPDESK SUPPORT / SENIOR TECHNICAL CUSTOMER CARE REPRESENTATIVE / TECHNICAL SUPPORT REPRESENTATIVE'),
#  ('INFORMATION TECHNOLOGY', 'SALARY LOANS PROCESS'),
#  ('COMPUTER SCIENCE / PROGRAMMING',
#   'COMPUTER TEACHER / CASHIER / SALES REPRESENTATIVE / LADY'),
#  ('ACCOUNTANCY', 'ACCOUNTING STAFF / ACCOUNTING STAFF'),
#  ('CHEMISTRY / MATERIALS SCIENCE ENGINEERING',
#   'JUNIOR MEMBER / SUMMER VOLUNTEER INTERN / UNDERGRADUATE RESEARCH / DISCOVERY CAMP HEAD'),
#  ('CIVIL ENGINEERING', 'TECHNICAL SUPPORT REPRESENTATIVE'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'FRONT DESK CLERK INTERN'),
#  ('COMPUTER SECRETARIAL', 'MATERIAL BILLING COORDINATOR LIAISON'),
#  ('STATISTICS', 'INSTRUCTOR'),
#  ('BUSINESS ADMINISTRATION', 'AGENT'),
#  ('ELEMENTARY EDUCATION', 'STORE OFFICE INCHARGE'),
#  ('MARKETING MANAGEMENT', 'DIGITAL MARKETING INTERN / LOGISTICS ASSISTANT'),
#  ('AGRICULTURE TECHNOLOGY',
#   'AGRICULTURE COFFEE TECHNICIAN / RESEARCH ASSISTANCE'),
#  ('TEACHER', 'SALES LADY / CASHIER / SALES LADY'),
#  ('PSYCHOLOGY', 'WRITER FOR CANDY MAGAZINE'),
#  ('MANAGEMENT PSYCHOLOGY COUNSELING',
#   'ENGINE ESL TEACHER / HR MANAGER / COORDINATOR / RESEARCH ASSISTANT'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'GRAND HYATT HOTEL KUALA PUMPER MALAYSIA'),
#  ('ACCOUNTANCY',
#   'CUSTOMER SUPPORT REPRESENTATIVE / JUNIOR AUDIT ASSOCIATE / ENGINE SMS RESEARCHER / ACCOUNTING STAFF OJT'),
#  ('MARINE TRANSPORTATION', 'ELECTRICIAN'),
#  ('CONSUMER ECONOMICS', 'EXECUTIVE ASSISTANT TO CEO / SALES MANAGER'),
#  ('BUSINESS ADMINISTRATION', 'FINANCE OFFICER'),
#  ('COMPUTER HARDWARE SERVICING', 'WELDERS / IRON WORKER / IRON WORKER'),
#  ('BUSINESS MANAGEMENT', 'OWNER / MANAGER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'WAITRESS COOK UTILITY'),
#  ('NURSING', 'FIRST AID & BLS INSTRUCTOR'),
#  ('PHYSICAL EDUCATION', 'TELLER CASHIER'),
#  ('BUSINESS ADMINISTRATION', 'COLLECTOR / FIELD CLERK'),
#  ('PART TIME INTEGRATION', 'TELECOM ENGINEER / COORDINATOR / PROJECT MANAGER'),
#  ('SOCIAL SCIENCES',
#   'VOLUNTEER TEACHER / EXCHANGE PARTICIPANT / VOLUNTEER TEACHER / EXCHANGE PARTICIPANT / CORE TEAM MEMBER OF PROJECT MALAYSIA 2014 / VOLUNTEER / FIELD RESEARCHER / VOLUNTEER / RESEARCHER / PROJECT MANAGER / VICE PRESIDENT OF RESEARCH & DEVELOPMENT'),
#  ('NURSING', 'CUSTOMER SERVICE REPRESENTATIVE / NURSE I'),
#  ('NURSING EDUCATION', 'ESL TUTOR'),
#  ('HOTEL RESTAURANT SERVICES', 'SERVICE CREW'),
#  ('ACCOMPANYING', 'VEHICLES SALES BOOKKEEPER'),
#  ('INFORMATION SYSTEMS', 'GRAPHIC DESIGNER / GRAPHIC DESIGNER / WEB DESIGNER'),
#  ('INTERNATIONAL RELATIONS',
#   'HERITAGE ADVOCACY / CULTURAL CREATIVE / COMMITTEE ON CUTTER & ARTS CHAIR / DEPUTY FOR DOCUMENTATION / WEB STAFF / DEPUTY FOR SECRETARIAT'),
#  ('ACCOUNTANCY', 'ACCOUNTING CLERK'),
#  ('COMPUTER BASED ACCOUNTING', 'PALACE STFF'),
#  ('FOODSERVICE MANAGEMENT',
#   'SERVICE CREW / KITCHEN CREW / FRONT LINER / FOOD ATTENDANT'),
#  ('COMPUTER TECHNOLOGY', 'TSV & WSV OPERATOR / EQUIPMENT OPERATOR'),
#  ('COMPUTER GRAPHICS', 'SERVICE CREW / SERVICE CREW'),
#  ('BUSINESS ADMINISTRATION', 'CUSTOMER SALES SPECIALIST / FRONT LINER'),
#  ('ELEMENTARY EDUCATION', 'TEACHER'),
#  ('TECHNICAL TEACHER EDUCATION / FOOD SERVICE MANAGEMENT', 'SALES ASSOCIATES'),
#  ('MECHANICAL ENGINEERING', 'DESIGN ENGINEER'),
#  ('BUSINESS ADMINISTRATION / MANAGEMENT',
#   'ON THE JOB TRAINEE / ON THE JOB TRAINEE'),
#  ('ACCOUNTANCY', 'TRAINEE'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'SERVICE CREW'),
#  ('INFORMATION TECHNOLOGY', 'LIVE CHAT SUPPORT'),
#  ('BUSINESS MANAGEMENT', 'SERVICE CREW'),
#  ('MARINE ENGINEERING', 'LINEMAN 1 / C'),
#  ('HOTEL RESTAURANT MANAGEMENT',
#   'COLLECTION SPECIALIST / HOME BASED TELEMARKETER / SALES REPRESENTATIVE'),
#  ('PSYCHOLOGY', 'RECRUITMENT ASSISTANT'),
#  ('MANAGEMENT INFORMATION SYSTEMS',
#   'JR SYSTEMS ANALYST / JR SYSTEMS DEVELOPER'),
#  ('ENTREPRENEURIAL MANAGEMENT', 'CUSTOMER SERVICE SPECIALIST'),
#  ('MANAGEMENT', 'CO OWNER CHIEF MARKETING OFFICER'),
#  ('BUSINESS ADMINISTRATION',
#   'SENIOR CUSTOMER SERVICE REPRESENTATIVE / DIRECTOR ASSISTANT'),
#  ('BIOLOGY', 'SENIOR RECRUITER LEVEL II'),
#  ('MASS COMMUNICATION', 'RETENTION OFFICER II / EXECUTIVE OFFICER'),
#  ('BUSINESS INFORMATION MANAGEMENT', 'JUNIOR DATA ANALYST'),
#  ('BUSINESS ADMINISTRATION / ENTREPRENEURSHIP',
#   'CHAT SUPPORT REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE / TEAM LEADER'),
#  ('OFFICE ADMINISTRATION', 'PROMODISER'),
#  ('PHYSICAL THERAPY',
#   'TECHNICAL SUPPORT REPRESENTATIVE II / TECHNICAL CHAT SUPPORT REPRESENTATIVE'),
#  ('BUSINESS ADMINISTRATION',
#   'EDEN CHINESE BRAND ASSOCIATE / MARKETING & SALES INTERN'),
#  ('PHILOSOPHY HUMAN RESOURCES DEVELOPMENT',
#   'CUSTOMER CARE REPRESENTATIVE II / SENIOR CUSTOMER SERVICE ASSOCIATE'),
#  ('TOURISM GEOGRAPHY', 'RECEPTIONIST'),
#  ('MATHEMATICS', 'TECHNICAL SERVICE REPRESENTATIVE'),
#  ('MARKETING', 'ADMINISTRATIVE ASSISTANT'),
#  ('COMPUTER SCIENCES', 'LEAD GENERATION SPECIALIST'),
#  ('APPLIED LINGUISTICS', 'LISTENER CARE REPRESENTATIVE / SENIOR RECRUITER'),
#  ('INFORMATION TECHNOLOGY', 'SOFTWARE ENGINEER'),
#  ('ACCOUNTING', 'FINANCIAL ANALYST'),
#  ('SOFTWARE DEVELOPMENT',
#   'TECHNICAL SUPPORT REPRESENTATIVE / CUSTOMER SERVICE & SALES EXPERT / RECRUITMENT ASSOCIATE'),
#  ('COMPUTER TECHNICIAN', 'ASST SUPERVISOR / COOK / PRODUCTION SUPERVISOR'),
#  ('NURSING',
#   'MEDICAL REPRESENTATIVE / INTERNAL MEDICINE OUT PATIENT DEPARTMENT NURSE'),
#  ('MASS COMMUNICATION', 'TALENT ACQUISITION'),
#  ('FINANCIAL MANAGEMENT', 'BILLING CLERK / INTERN'),
#  ('NURSING EDUCATION', 'SENIOR CUSTOMER CARE SPECIALIST'),
#  ('INFORMATION TECHNOLOGY', 'INTERN / INTERNAL STAFF'),
#  ('JOURNALISM', 'TALENT ACQUISITION'),
#  ('TOURISM',
#   'SENIOR RECRUITER TALENT ACQUISITION / HUMAN RESOURCES PRACTITIONER CUSTOMER SERVICE REPRESENTATIVE'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'OPERATIONS EXECUTIVE'),
#  ('BUSINESS ADMINISTRATION',
#   'SENIOR CUSTOMER SERVICE SPECIALIST / BACK OF HOUSE PROCESS SPECIALIST'),
#  ('SPEECH COMMUNICATION', 'CUSTOMER SERVICE PROFESSIONAL'),
#  ('INFORMATION TECHNOLOGY', 'PROCESS DEVELOPER'),
#  ('BUSINESS / HOTEL RESTAURANT MANAGEMENT', 'KITCHEN CREWW'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'LIBERAL CLERK / LIBERAL CLERK'),
#  ('COGNITIVE PSYCHOLOGY', 'BILLING ADVISOR'),
#  ('BUSINESS ADMINISTRATION', 'HR SPECIALIST'),
#  ('BANKING FINANCE', 'CHECK / TICKET SELLERS'),
#  ('BUSINESS ADMINISTRATION / MARKETING', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('AUTOMOTIVE SERVICE MECHANIC', '5S SERVICES'),
#  ('NURSING', 'SENIOR CODE COMPLIANCE SPECIALIST / CLIENT RELATIONS ASSOCIATE'),
#  ('COMPUTER SECRETARIAL', 'DH'),
#  ('COMMERCE', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('MARKETING MANAGEMENT',
#   'SUPERVISOR / ACCOUNT EXECUTIVE / PART TIME ACCOUNTS EXECUTIVE / PRODUCTION SUPERVISOR / FINANCIAL ADVISOR'),
#  ('HOSPITALITY MANAGEMENT', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('CHEMISTRY', 'RESEARCH & DEVELOPMENT ASSISTANT / QUALITY CONTROL ANALYST'),
#  ('BUSINESS',
#   'PROJECT DEVELOPMENT OFFICER III / PROGRAM MANAGER / ASSISTANT SALES MANAGER / SALES EXECUTIVE TRAVEL & LEISURE SECTION / NATION YOUTH PROGRAM COORDINATOR'),
#  ('ELECTRICAL ENGINEERING',
# ...
#   'ESCALATED AGENT / KINDERGARTEN TEACHER / RECEPTIONIST / RESEARCH TEAM LEAD / OWNER / TEACHER'),
#  ('COMMERCIAL COOKING', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('MIDWIFERY OBSTETRICS', 'RURAL HEALTH MIDWIFE'),
#  ('PUBLIC RELATIONS', 'FRONT DESK AGENT / SALES AGENT'),
#  ('JOURNALISM MEDIA STUDIES COMMUNICATION',
#   'CUSTOMER SUPPORT / CREDIT MANAGEMENT REPRESENTATIVE'),
#  ('INFORMATION TECHNOLOGY', 'INFORMATION TECHNOLOGY SUPPORT HARDWARE UNIT'),
#  ('BUSINESS ADMINISTRATION', 'STAFF / CLERK'),
#  ('COMPUTER SCIENCE', 'LOGISTICS ASSISTANT / OPERATION PERSONNEL'),
#  ('COMPUTER HARDWARE SERVICING NC2', 'FOOD ATTENDANT'),
#  ('COMMUNICATIONS TECHNOLOGY / MANAGEMENT', 'SALES STAFF'),
#  ('COMPUTER SECRETARIAL', 'FINANCE PERSONNEL / CASHIER / PAYROLL CLERK'),
#  ('ELECTRICAL INSTALLATION MAINTENANCE',
#   'PRODUCTION OPERATOR / PRODUCTION OPERATOR / ON THE JOB TRAINING'),
#  ('ENTREPRENEURSHIP', 'SERVICE CREW'),
#  ('COMPUTER SCIENCE', ''),
#  ('ACCOUNTANCY',
#   'APPOINTMENT SETTER / TELEMARKETER / HOMEBASED TELEMARKETER / ACCOUNTANT / FREELANCE WRITER / JUNIOR AUDITOR / HOME BASED MEDICAL / GENERAL TRANSCRIPTIONIST / MEDICAL TRANSCRIPTIONIST / ACCOUNTING STAFF / SALES ACCOUNTING PROCESS / ACCOUNTS RECEIVABLE RECONCILIATION'),
#  ('NURSING', 'ESL TEACHER'),
#  ('GENERAL RADIO COMMUNICATION', 'SECURITY SYSTEM TECHNICIAN'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'OBJECT MASTER EXPERT'),
#  ('COMPUTER PROGRAMMING',
#   'TECHNICAL HEAD SUPERVISOR / MACHINE OPERATOR PRODUCTION'),
#  ('BUSINESS ADMINISTRATION', 'OPERATIONS MANAGER / ASSISTANT STORE MANAGER'),
#  ('DYNATECH INDUSTRIAL INSTITUTE', 'ELECTRICAL FOREMAN'),
#  ('INFORMATION TECHNOLOGY',
#   'TECHNICAL SUPPORT REPRESENTATIVE / TECHNICAL SUPPORT REPRESENTATIVE / ENGINE FREELANCE'),
#  ('COMMUNICATIONS', 'FIELD SALES REPRESENTATIVE / SALES REPRESENTATIVE'),
#  ('INFORMATION SCIENCE', 'HR HEAD / PHOTOGRAPHER PICTURE EDITOR'),
#  ('AUTOMOTIVE DIESEL MECHANIC', 'DELIVERY DRIVER OF CABLE TILES'),
#  ('COMPUTER SCIENCE', 'ANALYST PROGRAMMER'),
#  ('HOSPITALITY MANAGEMENT', 'CASHIER'),
#  ('CIVIL ENGINEERING', 'ENGG ASST'),
#  ('BUSINESS ADMINISTRATION', 'SAFETY OFFICER DISPATCHER'),
#  ('DEVELOPMENT COMMUNICATION',
#   'PROJECT FACILITATOR / CASHIER / SERVICE CREW RECEPTIONIST / OFFICE STAFF / SALES ASSISTANT'),
#  ('SCIENCE / NUTRITION DIETETICS', 'EXECUTIVE OPERATIONS'),
#  ('COMPUTER SCIENCE', ''),
#  ('COMMERCE / INFORMATION MANAGEMENT',
#   'AUDIT STAFF / ACCOUNTING CLERK / ADMIN STAFF'),
#  ('NURSING', 'NURSE'),
#  ('ACCOUNTANCY',
#   'RISK ADVISOR ASSOCIATE / FINANCIAL ASSURANCE SERVICES ASSOCIATE'),
#  ('CIVIL ENGINEERING', 'WAITRESS / CASHIER / OFFICE STAFF'),
#  ('HOTEL RESTAURANT SERVICES', 'OFFICE STAFF / OFFICE CLERK / OFFICE CLERK'),
#  ('SECONDARY EDUCATION', 'WAITRESS'),
#  ('PHARMACY', 'LOCATION MANAGER'),
#  ('HOTEL RESTAURANT SERVICES', 'WAITER / HOUSEKEEPING'),
#  ('FORESTRY EDUCATION', 'BEAUTICIAN'),
#  ('MARKETING MANAGEMENT', 'AREA ACTIVATION SPECIALIST'),
#  ('COMPUTER HARDWARE SERVICING', 'STEWARD'),
#  ('COMPUTER SCIENCES', 'BRAND AMBASSADOR'),
#  ('PHILOSOPHY HUMAN RESOURCE DEVELOPMENT',
#   'HR INTERN / CUSTOMER SERVICE REPRESENTATIVE / OBJECT MASTER EXPERT TEAM CSAT COACH / BUSINESS OWNER / GENERAL MANAGER / RADIO DJ PART TIME / PART OWNER / GENERAL MANAGER / SENIOR RECRUITER LEVEL II / BACKGROUND CHECK SPECIALIST LEVEL II / PREMIER FINANCIAL ADVISOR WEALTH PORTFOLIO MANAGER / UNIT MANAGER / SENIOR EXECUTIVE UNIT MANAGER / INVESTMENT CONSULTANT / CERTIFIED INVESTMENT SOLICITOR CIS / RECRUITMENT OFFICER UNIT BASED / RECRUITMENT OFFICER AGENT WIDE / FOUNDER DIRECTOR OF OPERATIONS & HEAD BUSINESS DEVELOPMENT'),
#  ('BUSINESS ADMINISTRATION',
#   'TECHNICAL SUPPORT REP CUSTOMER SERVICE QA SUPERVISOR THEN BECAME A TEAM LEAD'),
#  ('AIRCRAFT MAINTENANCE', 'AUTO MECHANICAL / MECHANICAL'),
#  ('TOURISM',
#   'DATA MANAGER / DATA ANALYST / DATA SERVER / DATA ENCODER / MERCHANDISER / MERCHANDISER / ENCODER ADMIN STAFF'),
#  ('MULTIMEDIA ARTS', ''),
#  ('INFORMATION TECHNOLOGY', 'TECHNICAL SUPPORT REPRESENTATIVE'),
#  ('INFORMATION TECHNOLOGY', 'INSTRUCTOR'),
#  ('DENTISTRY', 'DENTIST'),
#  ('INFORMATION TECHNOLOGY', 'PRIVATE ENGLISH TUTOR'),
#  ('BROADCAST COMMUNICATION', 'ARTICLE WRITER'),
#  ('PSYCHOLOGY',
#   'RESERVATION SALES AGENT / RESERVATION SALES AGENT / ADMINISTRATIVE ASSISTANT'),
#  ('BUSINESS ADMINISTRATION',
#   'FRONTLINE MANAGER / TEAM MANAGER / SALES PERFORMANCE MANAGER'),
#  ('ELECTRICAL ENGINEER', 'CONTROL & INSTRUMENTATION TECHNICIAN'),
#  ('COMPUTER SCIENCES', 'PROGRAMMER / PROGRAMMER / PROGRAMMER'),
#  ('MARKETING MANAGEMENT', 'INTERN'),
#  ('NURSING',
#   'CUSTOMER SERVICE REPRESENTATIVE / SALES & CUSTOMER SERVICE SPECIALIST / VIRTUAL ASSISTANT'),
#  ('SECONDARY EDUCATION', 'LINK ASSOCIATE / SOCIAL MEDIA MARKETER'),
#  ('EDUCATION',
#   'ELEMENTARY TEACHER / ELEMENTARY SUBSTITUTE TEACHER / ELEMENTARY TEACHER / ESL TEACHER / EXPAT ENGLISH TEACHER / ENGLISH TEACHER / ESL TEACHER / ENGINE ENGLISH TEACHER'),
#  ('COMPUTER ENGINEERING', 'PROMOTER'),
#  ('PSYCHOLOGY', 'VIRTUAL ASSISTANT'),
#  ('CHEMICAL ENGINEERING', 'ODESK FREELANCE'),
#  ('APPLIED PSYCHOLOGY',
#   'CONTRIBUTING WRITER / COMMUNITY & CONTENT MANAGER / BAZAAR E COMMERCE MANAGER'),
#  ('ELECTRONICS COMMUNICATIONS ENGINEERING',
#   'PURCHASING SPECIALIST / INFORMATION TECHNOLOGY SPECIALIST / ASSISTANT ACCOUNTING SUPERVISOR / PRODUCTION HEAD / ACCOUNTING STAFF'),
#  ('JOURNALISM MEDIA STUDIES COMMUNICATION',
#   'DEPUTY HEAD OF CONTENT & CREATIVE / ASSOCIATE ACCOUNT DIRECTOR / INDEPENDENT MARKETING CONSULTANT & CONTENT DEVELOPER'),
#  ('ARCHITECTURE / COMPUTER PROGRAMMING',
#   'CUSTOMER SERVICE REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE'),
#  ('ACCOUNTANCY',
#   'ACCOUNT RECEIVABLE STAFF / TECHNICAL SUPPORT REPRESENTATIVE / ANZ WARRANTY CONTRACTS ADMINISTRATOR / ANZ SERVICE DELIVERY SPECIALIST'),
#  ('BUSINESS ADMINISTRATION MARKETING MANAGEMENT',
#   'GOVERNMENT INTERNSHIP PROGRAM'),
#  ('PSYCHOLOGY', 'MONEY PORTER'),
#  ('MECHANICAL ENGINEERING', 'PIPI FITTER STATION TECHNICIAN'),
#  ('COMPUTER ENGINEERING', 'LOGISTICS ASSOCIATE'),
#  ('NURSING', 'NURSE / NURSE'),
#  ('CRIMINAL JUSTICE',
#   'BACK OFFICE CREDIT SUPPORT / HUMAN RESOURCES BUSINESS PARTNER'),
#  ('MARKETING MANAGEMENT', 'CHANNEL SALES ASSOCIATE LUZON AREA'),
#  ('INFORMATION TECHNOLOGY', 'DRIVER'),
#  ('MARKETING MANAGEMENT', 'MARKETING ASSOCIATE'),
#  ('MASS COMMUNICATION', 'SOCIAL MEDIA ASSOCIATE'),
#  ('BUSINESS ADMINISTRATION', 'INTERN / PROJECT EXECUTIVE'),
#  ('BUSINESS ADMINISTRATION', 'CHECK & AUDIT STAFF'),
#  ('ORGANIZATIONAL COMMUNICATION',
#   'STRATEGY RESEARCH ASSISTANT / GENERAL VA MARKETER / PROJECT MANAGER / ASSISTANT TO PROFESSOR BOB BOYD / FULFILLMENT ASSISTANT / VIRTUAL EXECUTIVE ASSISTANT / SEO WRITER / VIRTUAL ASSISTANT'),
#  ('INFORMATION TECHNOLOGY', 'DATA ANALYST'),
#  ('BUSINESS ADMINISTRATION', 'ADMINISTRATIVE ASSISTANT'),
#  ('HOSPITALITY MANAGEMENT', 'RECEPTIONIST / SURVEYOR / ALL AROUND'),
#  ('ADVERTISING', 'TECHNICAL SUPPORT II'),
#  ('NURSING',
#   'CUSTOMER SERVICE REPRESENTATIVE / COMMUNITY NURSE RNHEALS BATCH 5'),
#  ('HOTEL RESTAURANT MANAGEMENT',
#   'CUSTOMER SERVICE / HOTEL & RESTAURANT SERVICE'),
#  ('FORESTRY',
#   'CHIEF OPERATING OFFICER / CONCURRENT WITH CHIEF OPERATING OFFICER EXECUTIVE ASSISTANT / ADMINISTRATIVE CLERK / ADMINISTRATIVE OFFICER / COMMUNITY ORGANIZER FOR BALOG WATERSHED SUBPROJECT'),
#  ('MANAGEMENT ENGINEERING', 'RESEARCH INTERN'),
#  ('FINANCIAL MANAGEMENT', 'INTERN'),
#  ('STATISTICS', 'DATA ANALYST OJT'),
#  ('TOURISM / HOTEL RESTAURANT MANAGEMENT',
#   'TECHNICAL SUPPORT REPRESENTATIVE / TECHNICAL SUPPORT REPRESENTATIVE'),
#  ('NURSING', 'OFFICE WORK'),
#  ('NURSING', 'NURSE / CLINIC NURSE'),
#  ('FILM', 'APM DESIGN'),
#  ('MANAGEMENT PSYCHOLOGY COUNSELING', 'PROFESSIONAL TEACHER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'CASHIER / DINING CREW'),
#  ('COSTUMER SERVICE', 'MACHINE OPERATOR SALES CLERK'),
#  ('HOTEL RESTAURANTS MANAGEMENT', 'FRONT OFFICE CLERK'),
#  ('CONCURRENT PROGRAMMING', 'CITY TECH ENTERPRISES'),
#  ('BUSINESS MANAGEMENT / FINANCIAL MANAGEMENT', 'CASHIER'),
#  ('ORGANIC AGRICULTURE PRODUCTION', 'DANCE CHOREOGRAPHER'),
#  ('NURSING',
#   'CUSTOMER SERVICE REPRESENTATIVE / MICROSOFT HELP DESK TECH SUPPORT'),
#  ('FOOD TECHNOLOGY', 'TEAM LEADER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'ENGLISH TEACHER'),
#  ('HOTEL RESTAURANT SERVICES', 'STORE SUPERVISOR / STORE SUPERVISOR'),
#  ('COMPUTER COMMUNICATIONS NETWORKS', 'PROCESS DOCUMENT'),
#  ('ELECTRICAL INSTALLATION MAINTENANCE', 'FACTORY WORKER / MACHINE OPERATOR'),
#  ('HISTORY / COMPUTER HARDWARE', 'ELECTRONICS COMPANY'),
#  ('COMPUTER SCIENCE', 'DATA ENCODER QUALITY CONTROL'),
#  ('PRACTICALNURSING', 'THEGENERICSPHARMACY'),
#  ('COMPUTER SECRETARIAL', 'OFFICE STAFF'),
#  ('ELECTRONICS COMMUNICATIONS ENGINEERING',
#   'GRAPHICS SPECIALIST / GLOBE BROADBAND SALES AGENT'),
#  ('ACCOUNTANCY', 'ACCOUNTING SUPERVISOR'),
#  ('COMPUTER ENGINEERING', ''),
#  ('FOOD BEVERAGE', 'CASHIER'),
#  ('GEOLOGY', 'SALES REPRESENTATIVE'),
#  ('INFORMATION TECHNOLOGY', 'CUSTOMER SERVICE ASSISTANT'),
#  ('FOOD TECHNOLOGY', 'QUALITY CONTROL'),
#  ('SOCIAL WORK', 'SOCIAL WORKER'),
#  ('INTERIOR DESIGN ARCHITECTURE',
#   'CUSTOMER SERVICE REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE'),
#  ('ELECTRICAL ENGINEERING',
#   'ELECTRICAL ENGINEER / TESTING & COMMISSIONING ENGINEER / ELECTRICAL SUPERVISOR'),
#  ('CRIMINOLOGY',
#   'FCAW WELDERS / MECHANICAL TECHNICIAN / MECHANICAL TECHNICIAN / WELDERS SMAW / WELDERS'),
#  ('COMPUTER SCIENCE', 'OFFICE CLERK'),
#  ('JOURNALISM',
#   'ASSOCIATE PRODUCT / WRITER / EDITOR / WRITER / EDITOR / CONTRIBUTING WRITER / EDITORIAL ASSISTANT'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'FRONT OFFICE RECEPTIONIST'),
#  ('INFORMATION TECHNOLOGY',
#   'WEB DESIGNER / GRAPHIC DESIGNER / FREELANCE WEB GRAPHIC DESIGNER'),
#  ('BUSINESS ADMINISTRATION',
#   'POSTAL SERVICE EMPLOYEE / COORDINATOR TIER 1 / CUSTOMER SERVICE REP / CUSTOMER SERVICE REPRESENTATIVE / CUSTOMER SERVICE REP / METRO'),
#  ('COMPUTER SCIENCES', 'TEAM LEADER SUPERVISOR'),
#  ('NURSING', 'QUALITY ASSURANCE OFFICER / PRIVATE NURSE'),
#  ('NURSING EDUCATION', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('MARKETING',
#   'SALES REPRESENTATIVE / LIFECYCLE MARKETING COORDINATOR / EMAIL MARKETING PLANNER / BUSINESS BAKER / PERSONAL BAKER / SALES & SERVICES SUPERVISOR'),
#  ('SECONDARY EDUCATION', 'CUSTOMER SERVICE REPRESENTATIVE'),
#  ('INFORMATION TECHNOLOGY ELECTRONICS', 'COMPANY DRIVER'),
#  ('HUMAN RESOURCES', 'CUSTOMER SERVICE'),
#  ('COMPUTER SCIENCES', 'SUMMER INTERN DEVELOPER'),
#  ('COMPUTER ENGINEERING', 'COSTUMER SUPPORT / RMA INCHARGE / PURCHASER'),
#  ('MASSAGE THERAPY',
#   'MASSAGE THERAPIST / SHIPPING MANAGER / CUSTOMER SERVICE & CASHIER'),
#  ('COMPUTER HARDWARE SERVICING NC II', 'PRODUCTION OPERATOR'),
#  ('SECONDARY EDUCATION',
#   'BACK OFFICE SUPPORT AGENT / PART TIME ENGINE ENGLISH TUTOR'),
#  ('BUSINESS ADMINISTRATION / FINANCIAL MANAGEMENT', 'INTERN / CHECK / PORTER'),
#  ('FINANCE', 'PAYABLE REVIEWER & VERIFICATIONS'),
#  ('INFORMATION TECHNOLOGY', 'FACTORY WORKER'),
#  ('ACCOUNTING', 'CASHIER / CUSTOMER SERVICE REPRESENTATIVE / SALES ASSOCIATE'),
#  ('AUTOMOTIVE MECHANICAL ASSEMBLY', 'WAX SHOP PERSONAL'),
#  ('BUSINESS ADMINISTRATION / BANKING FINANCE',
#   'ADMINISTRATIVE & ACCOUNTING ASSISTANT'),
#  ('MASS COMMUNICATION',
#   'TELEMARKETER PROMOTER TO OFFICE MANAGER / PROPRIETOR / EXECUTIVE SECRETARY'),
#  ('COMPUTER TECHNOLOGY',
#   'PRODUCTION OPERATOR / FRONT OFFICE CLERK / MARKETING ASSISTANT / SALES ASSISTANT'),
#  ('BUSINESS ADMINISTRATION', 'BRGY REVENUE CLERK / ASSEMBLER / LINE AUDITOR'),
#  ('BUSINESS ADMINISTRATION', 'CASHIER'),
#  ('FINANCIAL MANAGEMENT', 'TRAINEE / ASSISTANT INSTRUCTOR'),
#  ('ELECTRICAL ENGINEERING', 'ELECTRICAL TECHNICIAN / INDUSTRIAL ELECTRICIAN'),
#  ('INDUSTRIAL LABOR RELATIONS',
#   'TALENT MANAGEMENT SPECIALIST / MANAGER THE DEVELOPMENT OF ORGANIZATIONS COMPETENCY FRAMEWORK JANITORS PROGRESS BOOKING GROUP IN CREATOR PLANS & STRATEGIES TO ENSURE MONTH IMPLEMENTATION HCMS OBJECTIVES & INITIATIVES WITH REWARDS PROFILING CAREER PLANNING SOFTWARE ENGINEERS LEVEL ACT'),
#  ('PHILOSOPHY', 'HR STAFF / PRODUCT CONSULTANT / VIRTUAL SECRETARY'),
#  ('INFORMATION TECHNOLOGY', 'WAITRESS'),
#  ('COMMUNICATION ARTS / MASS COMMUNICATION', 'ROCKWELL TENT COORDINATOR'),
#  ('CIVIL ENGINEERING',
#   'DELIVERY IN CHARGE / XEROX MACHINE OPERATOR SALESLADY'),
#  ('BANKING FINANCE', 'STUDENT ASSISTANT / TRAINEE'),
#  ('NURSING EDUCATION', 'PROJECT MANAGER / PROJECT MANAGER'),
#  ('BROADCAST COMMUNICATION', 'CHAIRMAN / INTERN / INTERN'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'FRONT DESK'),
#  ('BUSINESS MANAGEMENT / BUSINESS ECONOMICS', 'HR STAFF'),
#  ('PSYCHOLOGY', 'HR ASSISTANT'),
#  ('BUSINESS ADMINISTRATION / MARKETING MANAGEMENT',
#   'COUNTER DEPARTMENT CASHIER'),
#  ('COMPUTER SCIENCE',
#   'LEAD UX SPECIALIST / LEAD UX ENGINEER / SR UX / UI DESIGNER'),
#  ('BUSINESS ADMINISTRATION', 'RISK MANAGEMENT ANALYST'),
#  ('LIBERAL ARTS / ENGLISH', 'COLLEGE PROFESSOR'),
#  ('MARKETING MANAGEMENT',
#   'EXPERT / AIRPORT DOCUMENTATION OFFICER / ACCOUNTING CLERK / SERVICE CREW'),
#  ('ELEMENTARY EDUCATION', 'SENIOR SALES ASSOCIATE / SALES ASSOCIATE'),
#  ('EUROPEAN LANGUAGES', 'ABSTRACTOR / INDEXER'),
#  ('COMMERCE / ENTREPRENEURSHIP', ''),
#  ('INFORMATION TECHNOLOGY', 'TECHNICAL SUPPORT DATA ENCODER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'KITCHEN ASSISTANT'),
#  ('INFORMATION TECHNOLOGY',
#   'COUNTRY MANAGER / HEAD OF MOBILE PRODUCTS & SERVICES / COUNTRY MANAGER / BUSINESS MANAGER / PRODUCT DEVELOPMENT MANAGER'),
#  ('BUSINESS ADMINISTRATION', 'ENGINE MASON DEALER / ENGINE MASON DEALER'),
#  ('TOURISM', 'INTERN / INTERN'),
#  ('BUSINESS ADMINISTRATION',
#   'SALES UTILITY CLERK / ENCODER / PURCHASER / SERVICE CREW / STOCK MAN'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'SALES ASSISTANT'),
#  ('FOODSERVICE MANAGEMENT', 'ACCOUNTING STAFF'),
#  ('COMPUTER TECHNICIAN', 'QUALITY ASSURANCE / SUPERVISOR'),
#  ('INDUSTRIAL ORGANIZATION', 'PROCESS OPERATOR'),
#  ('JOURNALISM',
#   'RESIDENT HOTEL MANAGER / RESIDENT RETORT MANAGER / ADMINISTRATIVE ASSISTANT / BAR GENDER'),
#  ('FINANCE', 'PAYROLL OFFICER'),
#  ('ACCOUNTANCY', 'ASST ACCOUNTING HEAD'),
#  ('PSYCHOLOGY', 'PSYCHOMETRICIAN / GUIDANCE COUNSELOR'),
#  ('GRAPHIC DESIGN', 'LIAISON OFFICER / OFFICE STAFF'),
#  ('INFORMATION TECHNOLOGY', 'MESSENGER / PURCHASER'),
#  ('COMPUTER ENGINEERING', 'PRODUCTION OPERATOR'),
#  ('BUSINESS ADMINISTRATION / MANAGEMENT', 'BRANCH MANAGER'),
#  ('NURSING EDUCATION', 'RETORT NURSE / FRONT OFFICE ASSOCIATE'),
#  ('INFORMATION TECHNOLOGY', 'CASHIER'),
#  ('INFORMATION TECHNOLOGY', 'INTERN / TELLER'),
#  ('ACCOUNTANCY', 'FINANCIAL ANALYST'),
#  ('COMMUNICATION ARTS / MASS COMMUNICATION', ''),
#  ('MARINE ENGINEERING', 'OILER / ENGINE CADET'),
#  ('LAWS', 'LEGAL AID'),
#  ('BUSINESS ADMINISTRATION / ENTREPRENEURSHIP', 'BRANCH MANAGER'),
#  ('AUTOMOTIVE ENGINEERING', 'ENGINEER'),
#  ('INFORMATION TECHNOLOGY', 'CASHIER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'PERFORMING ARTIST / CULTURAL DANCE'),
#  ('CHEMICAL ENGINEERING', 'ASSISTANT PLANT MANAGER / QA SUPERVISOR'),
#  ('CABLE / ENGLISH',
#   'CONTENT DEVELOPER TECHNICAL WRITER / TECHNICAL SUPPORT REPRESENTATIVE AUSTRALIAN MOBILE ACCOUNT / CUSTOMER RELATIONS OFFICER UK TELCO ACCOUNT / RESTAURANT TEAM MEMBER'),
#  ('INFORMATION TECHNOLOGY',
#   'ADMINISTRATIVE AIDE / INFORMATION TECHNOLOGY LECTURER PART TIME'),
#  ('NONE', 'SM GENSAN'),
#  ('INFORMATION TECHNOLOGY', 'JUNIOR WEB DEVELOPER'),
#  ('BUSINESS MANAGEMENT', 'OJT'),
#  ('NURSING', 'PUBLISHING CONSULTANT / SALES SUPERVISOR'),
#  ('ARCHITECTURAL TECHNOLOGY', 'AUTOCADD OPERATOR'),
#  ('OFFICE ADMINISTRATION',
#   'DATA ENCODER FIELD RESEARCHER / INTERVIEWER / CUSTOMER SERVICE REPRESENTATIVE / TECHNICAL SUPPORT / CUSTOMER SERVICE REPRESENTATIVE / BACK OFFICE SUPPORT / CUSTOMER SERVICE REPRESENTATIVE / CUSTOMER SERVICE REPRESENTATIVE'),
#  ('COMPUTER SCIENCES', 'R & D ENGINEER / ASSOCIATE SOFTWARE DEVELOPER'),
#  ('HOTEL RESTAURANT MANAGEMENT', 'DATA PROCESS'),
#  ('COMPUTER SCIENCES', 'OFFICE STAFF'),
#  ('', 'CABLE TECHNICIAN / DRIVER SECURITY VIP'),
#  ('COMPUTER SCIENCES', 'RENUMERATION OFFICER / ADMINISTRATIVE ASSISTANT'),
#  ('OFFICE ADMINISTRATION / OFFICE MANAGEMENT',
#   'CUSTOMER SERVICE REPRESENTATIVE INVOICER O SALES & RETAIL CREW AT FOOD CHAIN JOLLIBBE'),
#  ('ACCOUNTING MANAGEMENT',
#   'AUDIT AIDE / CHEMICAL AIDE / STATISTICIAN AIDE / ACCOUNTING & AUDITING AIDE'),
#  ('ENGLISH', 'DATA GATHERER'),
#  ...]

# %%
from clustering import stem_cluster

course_clusters = stem_cluster(clean_courses, mode=8)
job_title_clusters = stem_cluster(clean_job_titles, mode=8, length_at_least=4)

# %%
from analysis import LikelihoodMatrix

CourseJob = LikelihoodMatrix(course_clusters, job_title_clusters)

# %%
# %%time
# %%timeit

for course, job in zip(clean_courses, clean_job_titles):
    CourseJob.add_match(course, job)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-7548811304fd> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'%%timeit\n\nfor course, job in zip(clean_courses, clean_job_titles):\n    CourseJob.add_match(course, job)')
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2262             magic_arg_s = self.var_expand(line, stack_depth)
#    2263             with self.builtin_trap:
# -> 2264                 result = fn(magic_arg_s, cell)
#    2265             return result
#    2266
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1160         if mode=='eval':
#    1161             st = clock2()
# -> 1162             out = eval(code, glob, local_ns)
#    1163             end = clock2()
#    1164         else:
#
# <timed eval> in <module>()
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2262             magic_arg_s = self.var_expand(line, stack_depth)
#    2263             with self.builtin_trap:
# -> 2264                 result = fn(magic_arg_s, cell)
#    2265             return result
#    2266
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in timeit(self, line, cell)
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in timeit(self, line, cell)
#    1034             number = 1
#    1035             for _ in range(1, 10):
# -> 1036                 time_number = timer.timeit(number)
#    1037                 worst_tuning = max(worst_tuning, time_number / number)
#    1038                 if time_number >= 0.2:
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in timeit(self, number)
#     130         gc.disable()
#     131         try:
# --> 132             timing = self.inner(it, self.timer)
#     133         finally:
#     134             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# /home/kb-user/kalibrr-analysis/abelian-analysis/ML/matching/analysis.pyc in add_match(self, row_text, column_text)
#     132
#     133         def add_match(self, row_text, column_text):
# --> 134                 self.dataframe += self.delta(row_text, column_text, with_labels=False)
#     135
#     136 	'''
#
# /home/kb-user/kalibrr-analysis/abelian-analysis/ML/matching/analysis.pyc in delta(self, row_text, column_text, with_labels)
#     236                 # note: downward for rows, rightward for columns
#     237                 SV1 = self.similarity_vector(row_text, on_rows=True, with_labels=False, percentage=False)
# --> 238                 SV2 = self.similarity_vector(column_text, on_rows=False, with_labels=False, percentage=False)
#     239
#     240
#
# /home/kb-user/kalibrr-analysis/abelian-analysis/ML/matching/analysis.pyc in similarity_vector(self, text, on_rows, with_labels, percentage)
#     213                 Y = self.row_vectors if on_rows else self.column_vectors
#     214
# --> 215                 cos_sim = cosine_similarity(X, Y)[0]
#     216                 cache[text] = cos_sim
#     217
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in linear_kernel(X, Y)
#     688     Gram matrix : array of shape (n_samples_1, n_samples_2)
#     689     """
# --> 690     X, Y = check_pairwise_arrays(X, Y)
#     691     return safe_sparse_dot(X, Y.T, dense_output=True)
#     692
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in check_pairwise_arrays(X, Y)
#      91     else:
#      92         X = atleast2d_or_csr(X)
# ---> 93         Y = atleast2d_or_csr(Y)
#      94     if X.shape[1] != Y.shape[1]:
#      95         raise ValueError("Incompatible dimension for X and Y matrices: "
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/sklearn/utils/validation.pyc in atleast2d_or_csr(X, dtype, order, copy, force_all_finite)
#     163     return _atleast2d_or_sparse(X, dtype, order, copy, sp.csr_matrix,
#     164                                 "tocsr", sp.isspmatrix_csr,
# --> 165                                 force_all_finite)
#     166
#     167
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/sklearn/utils/validation.pyc in _atleast2d_or_sparse(X, dtype, order, copy, sparse_class, convmethod, check_same_type, force_all_finite)
#     140     else:
#     141         X = array2d(X, dtype=dtype, order=order, copy=copy,
# --> 142                     force_all_finite=force_all_finite)
#     143     return X
#     144
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/sklearn/utils/validation.pyc in array2d(X, dtype, order, copy, force_all_finite)
#     118         raise TypeError('A sparse matrix was passed, but dense data '
#     119                         'is required. Use X.toarray() to convert to dense.')
# --> 120     X_2d = np.asarray(np.atleast_2d(X), dtype=dtype, order=order)
#     121     if force_all_finite:
#     122         _assert_all_finite(X_2d)
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/numpy/core/shape_base.pyc in atleast_2d(*arys)
#      97     res = []
#      98     for ary in arys:
# ---> 99         ary = asanyarray(ary)
#     100         if len(ary.shape) == 0 :
#     101             result = ary.reshape(1, 1)
#
# /home/kb-user/kml/local/lib/python2.7/site-packages/numpy/core/numeric.pyc in asanyarray(a, dtype, order)
#     510
#     511     """
# --> 512     return array(a, dtype, copy=False, order=order, subok=True)
#     513
#     514 def ascontiguousarray(a, dtype=None):
#
# KeyboardInterrupt:

# %%
# find which jobs are prominent in the computer science course
CourseJob.find_column_matches('COMPUTER SCIENCE').nlargest(15)
# Out:
# REPRESENTATIVE     3.132575
# REPRESENTATIVES    2.957152
# SERVICE            2.188538
# CUSTOMER           1.985622
# SERVICES           1.871663
# ASSISTANT          1.860379
# TECHNICAL          1.562450
# TECHNICIAN         1.376424
# ASSISTANCE         1.360648
# MANAGER            1.311552
# DEVELOPER          1.280839
# CASHIER            1.279195
# OFFICER            1.176158
# OPERATOR           1.173683
# SPECIALIST         1.171439
# dtype: float64

# %%
# find which jobs are prominent in the business administration course
CourseJob.find_column_matches('BUSINESS ADMINISTRATION').nlargest(15)
# Out:
# REPRESENTATIVE     3.747742
# REPRESENTATIVES    3.489811
# SERVICE            2.504137
# CUSTOMER           2.481831
# ASSISTANT          2.471142
# SERVICES           2.005840
# MANAGER            1.941704
# ASSISTANCE         1.881207
# OFFICER            1.594930
# OFFICE             1.472586
# INTERN             1.302661
# SALES              1.249814
# ACCOUNT            1.218282
# CUSTOMS            1.215310
# ACCOUNTING         1.179339
# dtype: float64

# %%
# find which courses are prominent in nurse jobs
CourseJob.find_row_matches('NURSE').nlargest(15)
# Out:
# NURSING       82.375061
# OBSTETRICS     1.710928
# MIDWIFERY      1.674018
# BIOLOGY        1.348360
# BIOLOGICAL     0.820021
# SOCIOLOGY      0.744801
# HEALTHCARE     0.617392
# ECOLOGY        0.588521
# GEOLOGY        0.578818
# TECHNICIAN     0.521239
# THEOLOGY       0.507302
# RADIOLOGIC     0.494877
# EDUCATION      0.474361
# PATHOLOGY      0.456814
# TECHNOLOGY     0.447961
# dtype: float64

# %%
# find which jobs are prominent in the sales agent jobs
CourseJob.find_row_matches('SALES AGENT').nlargest(15)
# Out:
# TECHNOLOGY        4.865088
# BUSINESS          4.723356
# COMPUTER          4.426041
# ADMINISTRATION    4.173285
# INFORMATION       3.756388
# MANAGEMENT        3.564001
# AGRIBUSINESS      3.549196
# INFORMATICS       3.158802
# EDUCATION         3.011539
# EDUCATIONAL       2.837268
# COMPUTING         2.757552
# SCIENCE           2.734391
# SCIENCES          2.424937
# ENGINEERING       2.254137
# ENGINEER          1.850891
# dtype: float64
