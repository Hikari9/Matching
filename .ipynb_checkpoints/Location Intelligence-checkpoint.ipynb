# %%
# %pylab
# %matplotlib inline
from mpltools import style
style.use('ggplot')

from abelian import db
from abelian.models import User, Job, ProfilerAnswer, Profiler, Company
from collections import defaultdict
from cleaning import clean

db.configure("main", "postgresql://kalibrr:password@localhost/kalibrr")
session = db.get_session()
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib
# /home/kb-user/kml/local/lib/python2.7/site-packages/mpltools/style/__init__.py:42: FutureWarning:
#
#     The style-sheet functionality in mpltools has been integrated into
#     Matplotlib >= 1.4. This module will be removed in a future release.
#
#     Note that style-sheets used by `matplotlib.style` use the standard
#     Matplotlib rc-file syntax instead of the INI format used by `mpltools`.
#     This mostly means un-quoting strings and changing '=' to ':'.
#
#
#   """, FutureWarning)

# %%
locations = session.query(User.location_lonlat).filter(~User.is_test, User.location_geog != None).all()

# %%
locations = map(lambda pair: pair[0], locations)

# %%
longitude, latitude = zip(*locations)
plot(longitude, latitude, '.')
plt.xlim(100, 150)
plt.ylim(0, 20)
fig = plt.figure()
fig.axes
# Out:
# []

# %%
import csv
import numpy as np
import scipy as sp
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %%
bmap = Basemap(
    projection='ortho',
    lon_0 = 122,
    lat_0 = 12.7,
    resolution = 'l',
    llcrnrx = -1000000,
    llcrnry = -1000000,
    urcrnrx = 1000000,
    urcrnry = 1000000
)

fig = plt.figure(figsize=(12,8))
bmap.drawcoastlines()

bmap.drawcountries()
bmap.fillcontinents(color='coral', lake_color='aqua')
bmap.drawmapboundary(fill_color='aqua')
bmap.drawmeridians(np.arange(100, 150, 4), labels=[1, 0, 0, 1])
bmap.drawparallels(np.arange(5, 30, 4), labels=[1, 0, 0, 1])

x, y = bmap(longitude, latitude)
def transform(x, y):
    xr, yr = xlim(), ylim()
    arr = []
    for nx, ny in zip(x, y):
        bx = (nx - xr[0]) / (xr[1] - xr[0])
        by = (ny - yr[0]) / (yr[1] - yr[0])
        if bx >= 0 and bx <= 1 and by >= 0 and by <= 1:
            arr.append((bx, by))
    return arr
# hx, hy = zip(*transform(x, y))
plt.plot(x, y, 'bo', markersize=1.5)

# %%
bmap = Basemap(
    projection='cyl',
    #lon_0 = 122,
    #lat_0 = 12.7,
    resolution = 'l',
    #llcrnrx = -1000000,
    #llcrnry = -1000000,
    #urcrnrx = 1000000,
    #urcrnry = 1000000
)



fig = plt.figure(figsize=(12,8))

bmap.drawcoastlines()
bmap.drawcountries()
bmap.fillcontinents(color='coral', lake_color='aqua')
bmap.drawparallels(np.arange(-90.,120.,30.), labels=[1,0,0,1])
bmap.drawmeridians(np.arange(0.,420.,60.), labels=[1,0,0,1])
bmap.drawmapboundary(fill_color='aqua')
x,y = bmap(longitude, latitude)
plt.plot(x, y, 'go')
