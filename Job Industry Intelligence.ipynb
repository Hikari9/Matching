# %% [markdown]
# c/o Matthew

# %%
from __future__ import print_function
from __future__ import unicode_literals

from abelian import db
from abelian.models import User, Job, ProfilerAnswer, Profiler
from collections import defaultdict
from sqlalchemy.sql import func
from json import dumps

db.configure("postgresql://kalibrr:password@localhost/kalibrr", False)
session = db.get_session()

# %%
industries = (session.query(Job.industry, func.count(Job.id).label('count'))
                .filter_by(active=True, is_test=False, visibility='public')
                .group_by(Job.industry)
#                 .having(func.count(Job.id) > 5)
                .order_by(func.count(Job.id).desc())
                .all()
             )

industries = filter(lambda x : x[0] is not None, industries)

# list of '<industry> (<job count>)'
industries2 = list()
# dict mapping '<industry> (<job count>)' to '<job name> (<count>)'
industry_jobs = defaultdict(list)

for industry, job_count in industries:
    jobs = (session.query(Job.name, func.count(Job.id).label('count'))
                .filter_by(industry=industry)
                .filter_by(active=True, is_test=False, visibility='public')
                .group_by(Job.name)
                .order_by(func.count(Job.id).desc())
                .all()
           )
    industry_with_job_count = '{} ({})'.format(industry, job_count)
    industries2.append(industry_with_job_count)
    
    print(industry_with_job_count)
    for job in jobs:
        job_with_count = '{} ({})'.format(job[0], job[1])
        print('\t', job_with_count)
        industry_jobs[industry_with_job_count].append(job_with_count)
# Out:
# Customer Service (529)
# 	 Customer Service Representative (27)
# 	 Technical Support Representative (8)
# 	 Customer Service Representatives (7)
# 	 Technical Service Representative (5)
# 	 Call Center Agent (4)
# 	 Tech Consumer Concerns Agent (Cable Provider Account) (3)
# 	 Technical Support Representative (Telco Account) (3)
# 	 Tech Consumer Concerns Agent (Internet Provider) (2)
# 	 Call Center Representative (2)
# 	 Customer Service Representative (Credit Card Account) (2)
# 	 Customer Support Representative (2)
# 	 Customer Care Specialist (2)
# 	 Tech Support Agent (2)
# 	 TELEPERFORMANCE ROCKWELL| Experienced Technical Support Officer (Healthcare) (2)
# 	 TELEPERFORMANCE CEBU| (HOTELS ACCOUNT) Customer Service Executives (CSR) (2)
# 	 Customer Service Agent (2)
# 	 Sales Representative Agents (2)
# 	 Customer Service Consultant (Travel Account) (2)
# 	 ELEPERFORMANCE CEBU IT PARK| Customer Service Consultant (BANKING ACCOUNT) (1)
# 	 Clerk (1)
# 	 Company Nurse (1)
# ...

# %%
from IPython.html import widgets
from IPython.display import display

def select_industry(industry):
    job_widget.options = industry_jobs[industry]

def print_job(job):
    print(job)

industry_widget = widgets.Select(options=industries2)
initial_industry = industry_widget.value
job_widget = widgets.Select(options=industry_jobs[initial_industry])

i = widgets.interactive(select_industry, industry=industry_widget)
j = widgets.interactive(print_job, job=job_widget)
display(i, j)

# industry_widget.on_trait_change(select_industry, 'value')
# job_widget.on_trait_change(print_job, 'value')
# container = widgets.Box()
# container.children = [industry_widget, job_widget]
# display(container)
# Out:
# Property Specialist (5)

# %%
industry_jobs['Data Entry & Admin (50)']
# Out:
# [u'Administrative Assistant (7)',
#  u'Executive Assistant (2)',
#  u'Data Encoder (2)',
#  u'Encoder (Contractual) (2)',
#  u'Accounting Staff (2)',
#  u'Office Assistant (2)',
#  u'Personal Assistant (1)',
#  u'Secretary (1)',
#  u'Receptionist (1)',
#  u'Electrician (1)',
#  u'Secretary (Male) (1)',
#  u'Billing Assistant (1)',
#  u'Admininstrative Assistant (1)',
#  u'Data Entry Virtual Assistant for Jewelry Products Account (1)',
#  u'Data Entry/Email Customer Support (1)',
#  u'Executive Secretary (1)',
#  u'Office Staff (1)',
#  u'Data Entry / Administrative Assistant (1)',
#  u'Admin Staff (Human Resources, Data Encoder, Compensation & Benefits) (1)',
#  u'Admin Assistant/Receptionist (1)',
#  u'Inhouse Marketing Staff (1)',
#  u'Internship for Business Administration/Management Students (1)',
#  u'Compliance Officer (Contractual) (1)',
#  u'Office Clerk (1)',
#  u'Bookkeeper / Admin. Staff (1)',
#  u'Statistician (1)',
#  u'Data Entry (1)',
# ...
